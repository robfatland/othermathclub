# %% [markdown]
# # Leech Trees
#
# This appendix concerns a little corner of graph theory called Leech Trees. Before getting to that however
# I needed to copy some instructional code on generating graphs. This code relis on NetworkX being installed
# so it is actually three cells: The NetworkX install, a first example and a second example that is complete
#     graphs I think.

# %%
# !conda install networkx -y
# Out:
# Collecting package metadata: done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/noarch::attrs==19.1.0=py_0
#   - conda-forge/noarch::backcall==0.1.0=py_0
#   - conda-forge/noarch::bleach==3.1.0=py_0
#   - conda-forge/linux-64::certifi==2019.3.9=py36_0
#   - conda-forge/noarch::decorator==4.4.0=py_0
#   - conda-forge/noarch::defusedxml==0.5.0=py_1
#   - conda-forge/linux-64::entrypoints==0.3=py36_1000
#   - conda-forge/linux-64::ipython==7.5.0=py36h24bf2e0_0
#   - conda-forge/noarch::ipython_genutils==0.2.0=py_1
#   - conda-forge/noarch::ipywidgets==7.4.2=py_0
#   - conda-forge/linux-64::jedi==0.13.3=py36_0
#   - conda-forge/noarch::jinja2==2.10.1=py_0
#   - conda-forge/linux-64::jsonschema==3.0.1=py36_0
#   - conda-forge/noarch::jupyter_client==5.2.4=py_3
#   - conda-forge/noarch::jupyter_core==4.4.0=py_0
#   - conda-forge/linux-64::jupyterlab==0.35.4=py36_0
#   - conda-forge/noarch::jupyterlab_server==0.2.0=py_0
#   - conda-forge/linux-64::libffi==3.2.1=he1b5a44_1006
#   - defaults/linux-64::libgcc-ng==8.2.0=hdf63c60_1
#   - conda-forge/linux-64::libsodium==1.0.16=h14c3975_1001
#   - conda-forge/linux-64::markupsafe==1.1.1=py36h14c3975_0
#   - conda-forge/linux-64::mistune==0.8.4=py36h14c3975_1000
#   - conda-forge/noarch::nbconvert==5.4.1=py_2
#   - conda-forge/noarch::nbformat==4.4.0=py_1
#   - conda-forge/linux-64::ncurses==6.1=hf484d3e_1002
#   - conda-forge/linux-64::notebook==5.7.8=py36_0
#   - conda-forge/linux-64::openssl==1.1.1b=h14c3975_1
#   - conda-forge/noarch::pandocfilters==1.4.2=py_1
#   - conda-forge/noarch::parso==0.4.0=py_0
#   - conda-forge/linux-64::pexpect==4.7.0=py36_0
#   - conda-forge/linux-64::pickleshare==0.7.5=py36_1000
#   - conda-forge/linux-64::pip==19.1=py36_0
#   - conda-forge/noarch::prometheus_client==0.6.0=py_0
#   - conda-forge/noarch::prompt_toolkit==2.0.9=py_0
#   - conda-forge/noarch::ptyprocess==0.6.0=py_1001
#   - conda-forge/noarch::pygments==2.3.1=py_0
#   - conda-forge/linux-64::pyrsistent==0.15.1=py36h516909a_0
#   - conda-forge/linux-64::python==3.6.7=h381d211_1004
#   - conda-forge/linux-64::pyzmq==18.0.1=py36hc4ba49a_1
#   - conda-forge/linux-64::readline==7.0=hf8c457e_1001
#   - conda-forge/noarch::send2trash==1.5.0=py_0
#   - conda-forge/linux-64::setuptools==41.0.1=py36_0
#   - conda-forge/linux-64::six==1.12.0=py36_1000
#   - conda-forge/linux-64::sqlite==3.26.0=h67949de_1001
#   - conda-forge/linux-64::terminado==0.8.2=py36_0
#   - conda-forge/linux-64::tk==8.6.9=h84994c4_1001
#   - conda-forge/linux-64::traitlets==4.3.2=py36_1000
#   - conda-forge/noarch::wcwidth==0.1.7=py_1
#   - conda-forge/noarch::webencodings==0.5.1=py_1
#   - conda-forge/linux-64::wheel==0.33.1=py36_0
#   - conda-forge/linux-64::widgetsnbextension==3.4.2=py36_1000
#   - conda-forge/linux-64::xz==5.2.4=h14c3975_1001
#   - conda-forge/linux-64::zeromq==4.3.1=hf484d3e_1000
#   - conda-forge/linux-64::zlib==1.2.11=h14c3975_1004
#   - conda-forge/noarch::amqp==2.4.2=py_0
#   - conda-forge/linux-64::awscli==1.16.167=py36_0
#   - conda-forge/linux-64::bcrypt==3.1.4=py36h470a237_0
#   - conda-forge/linux-64::billiard==3.6.0.0=py36h516909a_0
#   - conda-forge/linux-64::blas==2.10=openblas
#   - conda-forge/noarch::boto3==1.9.157=py_0
#   - conda-forge/noarch::botocore==1.12.157=py_0
#   - conda-forge/noarch::celery==4.3.0=py_1
#   - conda-forge/noarch::colorama==0.3.9=py_1
#   - conda-forge/linux-64::conda==4.6.14=py36_0
#   - conda-forge/noarch::dask==1.1.1=py_0
#   - conda-forge/noarch::dask-core==1.1.1=py_0
#   - conda-forge/noarch::datacube==1.6.2=py_1
#   - conda-forge/noarch::datashader==0.6.9=py_0
#   - conda-forge/linux-64::distributed==1.25.3=py36_0
#   - conda-forge/noarch::geocube==0.0.4=py_0
#   - conda-forge/noarch::geopandas==0.4.1=py_1
#   - conda-forge/linux-64::graphviz==2.38.0=hf68f40c_1011
#   - conda-forge/linux-64::ipykernel==5.1.1=py36h24bf2e0_0
#   - conda-forge/noarch::kombu==4.5.0=py_0
#   - conda-forge/linux-64::liblapacke==3.8.0=10_openblas
#   - conda-forge/linux-64::matplotlib==3.0.3=py36_1
#   - conda-forge/linux-64::matplotlib-base==3.0.3=py36h5f35d83_1
#   - conda-forge/linux-64::nb_conda_kernels==2.2.2=py36_0
#   - defaults/linux-64::nomkl==3.0=0
#   - conda-forge/linux-64::pandas==0.24.2=py36hb3f55d8_0
#   - conda-forge/linux-64::paramiko==2.4.2=py36_1000
#   - conda-forge/linux-64::psycopg2==2.8.2=py36h72c5cf5_0
#   - conda-forge/linux-64::pycosat==0.6.3=py36h14c3975_1001
#   - conda-forge/linux-64::pynacl==1.3.0=py36h14c3975_1000
#   - conda-forge/linux-64::pypeg2==2.15.2=py36_0
#   - conda-forge/linux-64::pyyaml==3.13=py36h14c3975_1001
#   - conda-forge/noarch::redis-py==3.2.1=py_0
#   - conda-forge/noarch::regionmask==0.4.0=py_0
#   - conda-forge/linux-64::requests==2.21.0=py36_1000
#   - conda-forge/noarch::rioxarray==0.0.3=py_0
#   - conda-forge/linux-64::ruamel_yaml==0.15.71=py36h14c3975_1000
#   - conda-forge/linux-64::simplejson==3.16.1=py36h470a237_0
#   - conda-forge/linux-64::singledispatch==3.4.0.3=py36_1000
#   - conda-forge/noarch::sshtunnel==0.1.4=1
#   - conda-forge/noarch::vine==1.3.0=py_0
#   - conda-forge/noarch::zarr==2.2.0=py_1
#   - conda-forge/linux-64::absl-py==0.7.1=py36_0
#   - conda-forge/noarch::affine==2.2.2=py_0
#   - conda-forge/linux-64::antlr-python-runtime==4.7.2=py36_1000
#   - conda-forge/noarch::appdirs==1.4.3=py_1
#   - conda-forge/noarch::asciitree==0.3.3=py_2
#   - conda-forge/noarch::astor==0.7.1=py_0
#   - conda-forge/noarch::attrdict==2.0.1=py_0
#   - conda-forge/linux-64::beautifulsoup4==4.7.1=py36_1001
#   - conda-forge/linux-64::blosc==1.16.3=hf484d3e_0
#   - conda-forge/linux-64::boost-cpp==1.68.0=h11c811c_1000
#   - conda-forge/noarch::branca==0.3.1=py_0
#   - conda-forge/linux-64::bzip2==1.0.6=h14c3975_1002
#   - conda-forge/linux-64::c-ares==1.15.0=h14c3975_1001
#   - conda-forge/linux-64::cartopy==0.17.0=py36h0aa2c8f_1004
#   - conda-forge/linux-64::cf-units==2.1.1=py36h3010b51_1000
#   - conda-forge/linux-64::cftime==1.0.3.4=py36hd352d35_1001
#   - conda-forge/noarch::click-plugins==1.1.1=py_0
#   - conda-forge/noarch::cligj==0.5.0=py_0
#   - conda-forge/linux-64::climlab==0.7.3=py36h4c70da7_0
#   - conda-forge/noarch::colorcet==2.0.1=py_0
#   - conda-forge/noarch::configobj==5.0.6=py_0
#   - conda-forge/linux-64::curl==7.64.1=hf8cf82a_0
#   - conda-forge/noarch::cycler==0.10.0=py_1
#   - conda-forge/noarch::dask-glm==0.1.0=0
#   - conda-forge/noarch::dask-ml==0.13.0=py_0
#   - conda-forge/noarch::datashape==0.5.4=py_1
#   - conda-forge/noarch::descartes==1.1.0=py_3
#   - conda-forge/noarch::docopt==0.6.2=py_1
#   - conda-forge/noarch::docrep==0.2.6=py_0
#   - conda-forge/linux-64::docutils==0.14=py36_1001
#   - conda-forge/noarch::eofs==1.4.0=py_0
#   - conda-forge/linux-64::esmf==7.1.0=hdfb41a0_1004
#   - conda-forge/linux-64::esmpy==7.1.0=py36h24bf2e0_3
#   - conda-forge/noarch::fasteners==0.14.1=py_3
#   - conda-forge/linux-64::fiona==1.8.6=py36hf242f0b_3
#   - conda-forge/linux-64::freexl==1.0.5=h14c3975_1002
#   - conda-forge/linux-64::future==0.17.1=py36_1000
#   - conda-forge/noarch::gast==0.2.2=py_0
#   - conda-forge/noarch::gcsfs==0.2.2=py_0
#   - conda-forge/linux-64::gdal==2.4.1=py36hf242f0b_0
#   - conda-forge/linux-64::geos==3.7.1=hf484d3e_1000
#   - conda-forge/linux-64::geotiff==1.4.3=h1105359_1000
#   - conda-forge/noarch::geoviews==1.6.2=py_0
#   - conda-forge/noarch::geoviews-core==1.6.2=py_0
#   - conda-forge/linux-64::giflib==5.1.7=h516909a_1
#   - conda-forge/noarch::google-auth-oauthlib==0.3.0=py_0
#   - defaults/linux-64::grpcio==1.16.1=py36hf8bcb03_1
#   - conda-forge/linux-64::gsw==3.3.1=py36h516909a_0
#   - conda-forge/noarch::h5netcdf==0.7.3=py_0
#   - conda-forge/linux-64::h5py==2.9.0=nompi_py36hf008753_1102
#   - conda-forge/linux-64::hdf4==4.2.13=h9a582f1_1002
#   - conda-forge/linux-64::hdf5==1.10.4=nompi_h3c11f04_1106
#   - conda-forge/noarch::holoviews==1.12.3=py_0
#   - conda-forge/noarch::hvplot==0.4.0=py_1
#   - conda-forge/linux-64::imageio==2.5.0=py36_0
#   - conda-forge/noarch::intake-esm==2019.5.11=py_0
#   - conda-forge/noarch::intake-xarray==0.3.0=py_0
#   - conda-forge/linux-64::ipyleaflet==0.10.2=py36_0
#   - conda-forge/linux-64::iris==2.2.0=py36_1003
#   - conda-forge/noarch::jmespath==0.9.4=py_0
#   - conda-forge/noarch::joblib==0.13.2=py_0
#   - conda-forge/linux-64::json-c==0.13.1=h14c3975_1001
#   - conda-forge/linux-64::kealib==1.4.10=h1978553_1003
#   - conda-forge/linux-64::keras==2.2.4=py36_1
#   - conda-forge/noarch::keras-applications==1.0.7=py_1
#   - conda-forge/noarch::keras-preprocessing==1.0.9=py_1
#   - conda-forge/linux-64::kiwisolver==1.1.0=py36hc9558a2_0
#   - conda-forge/linux-64::libdap4==3.19.1=hd48c02d_1000
#   - conda-forge/linux-64::libgdal==2.4.1=hdb8f723_0
#   - conda-forge/linux-64::libgpuarray==0.7.6=h14c3975_1003
#   - conda-forge/linux-64::libkml==1.3.0=h328b03d_1009
#   - conda-forge/linux-64::libnetcdf==4.6.2=hbdf4f91_1001
#   - conda-forge/linux-64::libpq==11.3=h4e4e079_0
#   - conda-forge/linux-64::libprotobuf==3.7.1=h8b12597_0
#   - conda-forge/linux-64::libspatialindex==1.9.0=he1b5a44_1
#   - conda-forge/linux-64::libspatialite==4.3.0a=hb5ec416_1026
#   - conda-forge/linux-64::libxslt==1.1.32=h4785a14_1002
#   - conda-forge/linux-64::llvmlite==0.28.0=py36hdbcaa40_0
#   - conda-forge/noarch::locket==0.2.0=py_2
#   - conda-forge/linux-64::lxml==4.3.3=py36h7ec2d77_0
#   - conda-forge/linux-64::lz4==2.1.6=py36hd79334b_1001
#   - conda-forge/linux-64::lz4-c==1.8.3=he1b5a44_1001
#   - conda-forge/noarch::mapclassify==2.0.1=py_0
#   - conda-forge/noarch::markdown==2.6.11=py_0
#   - conda-forge/noarch::mechanicalsoup==0.11.0=py_0
#   - conda-forge/linux-64::metpy==0.10.0=py36_1001
#   - conda-forge/linux-64::mock==3.0.5=py36_0
#   - conda-forge/noarch::monotonic==1.5=py_0
#   - conda-forge/linux-64::mpich==3.2.1=h1c2f66e_1008
#   - conda-forge/noarch::msgpack-numpy==0.4.4.3=py_0
#   - conda-forge/noarch::multipledispatch==0.6.0=py_0
#   - conda-forge/noarch::munch==2.3.2=py_0
#   - conda-forge/linux-64::netcdf-fortran==4.4.5=hea25ff8_1000
#   - conda-forge/linux-64::netcdf4==1.5.1.2=py36had58050_0
#   - conda-forge/noarch::networkx==2.3=py_0
#   - conda-forge/linux-64::ninja==1.9.0=h6bb024c_0
#   - conda-forge/linux-64::numba==0.43.1=py36hf2d7682_0
#   - conda-forge/linux-64::numcodecs==0.6.3=py36hf484d3e_0
#   - conda-forge/linux-64::openjpeg==2.3.1=h58a6597_0
#   - conda-forge/noarch::owslib==0.17.1=py_0
#   - conda-forge/noarch::panel==0.5.1=h24bf2e0_2
#   - conda-forge/noarch::param==1.9.0=py_0
#   - conda-forge/noarch::partd==0.3.9=py_0
#   - conda-forge/linux-64::pint==0.9=py36_2
#   - conda-forge/linux-64::pooch==0.2.1=py36_1000
#   - conda-forge/linux-64::poppler==0.67.0=h2ad7f00_6
#   - conda-forge/linux-64::postgresql==11.3=hbeee2d4_0
#   - conda-forge/linux-64::proj4==5.2.0=he1b5a44_1002
#   - conda-forge/linux-64::protobuf==3.7.1=py36he1b5a44_0
#   - conda-forge/noarch::pyct==0.4.6=py_0
#   - conda-forge/noarch::pyct-core==0.4.6=py_0
#   - conda-forge/linux-64::pydap==3.2.2=py36_1000
#   - conda-forge/noarch::pyepsg==0.4.0=py_0
#   - conda-forge/linux-64::pygpu==0.7.6=py36h3010b51_1000
#   - conda-forge/linux-64::pykdtree==1.3.1=py36h3010b51_1002
#   - conda-forge/linux-64::pyke==1.1.1=py36_1000
#   - conda-forge/noarch::pyorbital==1.5.0=py_0
#   - conda-forge/linux-64::pyproj==1.9.6=py36h516909a_1001
#   - conda-forge/linux-64::pyresample==1.12.3=py36hf2d7682_0
#   - conda-forge/noarch::pyshp==2.1.0=py_0
#   - conda-forge/noarch::pyspectral==0.8.8=py_0
#   - conda-forge/linux-64::pyspharm==1.0.9=py36h6091dcd_1003
#   - conda-forge/linux-64::python-blosc==1.8.1=py36hf484d3e_0
#   - conda-forge/linux-64::python-geotiepoints==1.1.8=py36hd352d35_0
#   - conda-forge/linux-64::python-snappy==0.5.4=py36hee44bf9_0
#   - conda-forge/linux-64::pytorch-cpu==1.0.1=py36hf484d3e_0
#   - conda-forge/noarch::pytz==2019.1=py_0
#   - conda-forge/noarch::pyviz_comms==0.7.2=py_0
#   - conda-forge/linux-64::pywavelets==1.0.3=py36hd352d35_1
#   - conda-forge/linux-64::rasterio==1.0.23=py36h5b3f9e8_0
#   - conda-forge/linux-64::rtree==0.8.3=py36h666c49c_1002
#   - conda-forge/linux-64::ruamel==1.0=py36_0
#   - conda-forge/linux-64::ruamel.yaml==0.15.96=py36h516909a_0
#   - conda-forge/noarch::s3fs==0.2.1=py_0
#   - conda-forge/linux-64::s3transfer==0.2.0=py36_0
#   - conda-forge/noarch::satpy==0.15.2=pyh326bf55_0
#   - conda-forge/linux-64::scikit-image==0.15.0=py36he1b5a44_0
#   - conda-forge/linux-64::scikit-learn==0.21.1=py36h627018c_0
#   - conda-forge/linux-64::scipy==1.3.0=py36hab63836_0
#   - conda-forge/linux-64::shapely==1.6.4=py36h2afed24_1004
#   - conda-forge/linux-64::snappy==1.1.7=hf484d3e_1002
#   - conda-forge/noarch::snuggs==1.4.6=py_0
#   - conda-forge/linux-64::soupsieve==1.9.1=py36_0
#   - conda-forge/linux-64::tensorboard==1.13.1=py36_0
#   - conda-forge/linux-64::tensorflow==1.13.1=py36_0
#   - defaults/noarch::tensorflow-estimator==1.13.0=py_0
#   - conda-forge/noarch::termcolor==1.1.0=py_2
#   - conda-forge/linux-64::testpath==0.3.1=py36_1
#   - conda-forge/linux-64::theano==1.0.3=py36_0
#   - conda-forge/noarch::tqdm==4.32.1=py_0
#   - conda-forge/noarch::traittypes==0.2.1=py_1
#   - conda-forge/noarch::trollimage==1.8.0=py_0
#   - conda-forge/noarch::trollsift==0.3.2=py_0
#   - conda-forge/linux-64::tzcode==2018g=h14c3975_1001
#   - conda-forge/linux-64::udunits2==2.2.27.6=h4e0c4b3_1001
#   - conda-forge/noarch::webob==1.8.5=py_0
#   - conda-forge/noarch::werkzeug==0.15.4=py_0
#   - conda-forge/linux-64::windspharm==1.7.0=py36_1000
#   - conda-forge/noarch::xarray==0.12.1=py_0
#   - conda-forge/linux-64::xerces-c==3.2.2=hac72e42_1001
#   - conda-forge/linux-64::xesmf==0.1.1=py36_1
#   - conda-forge/noarch::xgcm==0.2.0=py_0
#   - conda-forge/noarch::xrft==0.2.0=py_0
#   - conda-forge/noarch::adal==1.2.1=py_0
#   - conda-forge/noarch::alembic==1.0.10=py_0
#   - conda-forge/linux-64::asn1crypto==0.24.0=py36_1003
#   - conda-forge/noarch::async_generator==1.10=py_0
#   - conda-forge/noarch::blinker==1.4=py_1
#   - conda-forge/linux-64::bokeh==1.1.0=py36_0
#   - conda-forge/noarch::cachetools==2.1.0=py_0
#   - conda-forge/linux-64::cairo==1.16.0=ha4e643d_1000
#   - conda-forge/noarch::certipy==0.1.3=py_0
#   - conda-forge/linux-64::cffi==1.12.3=py36h8022711_0
#   - conda-forge/linux-64::chardet==3.0.4=py36_1003
#   - conda-forge/noarch::click==7.0=py_0
#   - conda-forge/noarch::cloudpickle==1.0.0=py_0
#   - conda-forge/linux-64::configurable-http-proxy==1.3.0=0
#   - conda-forge/linux-64::cryptography==2.6.1=py36h72c5cf5_0
#   - conda-forge/linux-64::cytoolz==0.9.0.1=py36h14c3975_1001
#   - conda-forge/noarch::dask-kubernetes==0.8.0=py_0
#   - conda-forge/linux-64::dbus==1.13.6=he372182_0
#   - conda-forge/linux-64::expat==2.2.5=hf484d3e_1002
#   - conda-forge/linux-64::fontconfig==2.13.1=he4413a7_1000
#   - conda-forge/linux-64::freetype==2.10.0=he983fc9_0
#   - conda-forge/linux-64::gettext==0.19.8.1=hc5be6a0_1002
#   - conda-forge/linux-64::glib==2.58.3=hf63aee3_1001
#   - conda-forge/noarch::google-auth==1.6.3=py_0
#   - conda-forge/linux-64::graphite2==1.3.13=hf484d3e_1000
#   - conda-forge/linux-64::gst-plugins-base==1.14.4=hdf3bae2_1001
#   - conda-forge/linux-64::gstreamer==1.14.4=h66beb1c_1001
#   - conda-forge/linux-64::harfbuzz==2.4.0=h37c48d4_0
#   - conda-forge/linux-64::heapdict==1.0.0=py36_1000
#   - conda-forge/linux-64::icu==58.2=hf484d3e_1000
#   - conda-forge/linux-64::idna==2.8=py36_1000
#   - conda-forge/linux-64::jpeg==9c=h14c3975_1001
#   - conda-forge/noarch::jupyter==1.0.0=py_2
#   - conda-forge/noarch::jupyter_console==6.0.0=py_0
#   - conda-forge/linux-64::jupyterhub==1.0.0=py36_0
#   - conda-forge/linux-64::krb5==1.16.3=h05b26f9_1001
#   - conda-forge/linux-64::libblas==3.8.0=10_openblas
#   - conda-forge/linux-64::libcblas==3.8.0=10_openblas
#   - conda-forge/linux-64::libcurl==7.64.1=hda55be3_0
#   - conda-forge/linux-64::libedit==3.1.20170329=hf8c457e_1001
#   - conda-forge/linux-64::libiconv==1.15=h516909a_1005
#   - conda-forge/linux-64::liblapack==3.8.0=10_openblas
#   - conda-forge/linux-64::libpng==1.6.37=hed695b0_0
#   - conda-forge/linux-64::libssh2==1.8.2=h22169c7_2
#   - conda-forge/linux-64::libtiff==4.0.10=h648cc4a_1001
#   - conda-forge/linux-64::libtool==2.4.6=h14c3975_1002
#   - conda-forge/linux-64::libuuid==2.32.1=h14c3975_1000
#   - conda-forge/linux-64::libxcb==1.13=h14c3975_1002
#   - conda-forge/linux-64::libxml2==2.9.9=h13577e0_0
#   - conda-forge/noarch::mako==1.0.10=py_0
#   - conda-forge/linux-64::msgpack-python==0.6.1=py36h6bb024c_0
#   - conda-forge/noarch::nbserverproxy==0.8.8=py_1000
#   - conda-forge/linux-64::nodejs==11.14.0=he1b5a44_1
#   - conda-forge/linux-64::numpy==1.16.3=py36he5ce36f_0
#   - conda-forge/noarch::oauthlib==3.0.1=py_0
#   - conda-forge/noarch::olefile==0.46=py_0
#   - conda-forge/linux-64::openblas==0.3.6=h6e990d7_2
#   - conda-forge/noarch::packaging==19.0=py_0
#   - conda-forge/noarch::pamela==1.0.0=py_0
#   - conda-forge/linux-64::pango==1.40.14=h4ea9474_1004
#   - conda-forge/linux-64::pcre==8.41=hf484d3e_1003
#   - conda-forge/linux-64::pillow==6.0.0=py36he7afcd5_0
#   - conda-forge/linux-64::pixman==0.34.0=h14c3975_1003
#   - conda-forge/linux-64::psutil==5.6.2=py36h516909a_0
#   - conda-forge/linux-64::pthread-stubs==0.4=h14c3975_1001
#   - conda-forge/noarch::pyasn1==0.4.5=py_0
#   - conda-forge/noarch::pyasn1-modules==0.2.5=py_0
#   - conda-forge/linux-64::pycparser==2.19=py36_1
#   - conda-forge/linux-64::pycurl==7.43.0.2=py36h16ce93b_0
#   - conda-forge/noarch::pyjwt==1.7.1=py_0
#   - conda-forge/linux-64::pyopenssl==19.0.0=py36_0
#   - conda-forge/noarch::pyparsing==2.4.0=py_0
#   - conda-forge/linux-64::pyqt==5.9.2=py36hcca6a23_0
#   - conda-forge/linux-64::pysocks==1.7.0=py36_0
#   - conda-forge/noarch::python-editor==1.0.4=py_0
#   - conda-forge/linux-64::python-kubernetes==9.0.0=py36_0
#   - conda-forge/linux-64::qt==5.9.7=h52cfd70_1
#   - conda-forge/noarch::qtconsole==4.4.4=py_0
#   - conda-forge/noarch::requests-oauthlib==1.2.0=py_0
#   - conda-forge/noarch::rsa==3.4.2=py_1
#   - conda-forge/linux-64::sip==4.19.8=py36hf484d3e_1000
#   - conda-forge/noarch::sortedcontainers==2.1.0=py_0
#   - conda-forge/linux-64::sqlalchemy==1.3.3=py36h516909a_0
#   - conda-forge/noarch::tblib==1.4.0=py_0
#   - conda-forge/noarch::toolz==0.9.0=py_1
#   - conda-forge/linux-64::tornado==5.1.1=py36h14c3975_1000
#   - conda-forge/linux-64::urllib3==1.24.3=py36_0
#   - conda-forge/linux-64::websocket-client==0.56.0=py36_0
#   - conda-forge/linux-64::xorg-kbproto==1.0.7=h14c3975_1002
#   - conda-forge/linux-64::xorg-libice==1.0.9=h516909a_1004
#   - conda-forge/linux-64::xorg-libsm==1.2.3=h84519dc_1000
#   - conda-forge/linux-64::xorg-libx11==1.6.7=h14c3975_1000
#   - conda-forge/linux-64::xorg-libxau==1.0.9=h14c3975_0
#   - conda-forge/linux-64::xorg-libxdmcp==1.1.3=h516909a_0
#   - conda-forge/linux-64::xorg-libxext==1.3.4=h516909a_0
#   - conda-forge/linux-64::xorg-libxpm==3.5.12=h14c3975_1002
#   - conda-forge/linux-64::xorg-libxrender==0.9.10=h516909a_1002
#   - conda-forge/linux-64::xorg-libxt==1.1.5=h14c3975_1002
#   - conda-forge/linux-64::xorg-renderproto==0.11.1=h14c3975_1002
#   - conda-forge/linux-64::xorg-xextproto==7.3.0=h14c3975_1002
#   - conda-forge/linux-64::xorg-xproto==7.0.31=h14c3975_1007
#   - conda-forge/linux-64::yaml==0.1.7=h14c3975_1001
#   - conda-forge/noarch::zict==0.1.4=py_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.6.14
#   latest version: 4.7.5
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - networkx
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |             main           3 KB  defaults
#     ca-certificates-2019.6.16  |       hecc5488_0         145 KB  conda-forge
#     certifi-2019.6.16          |           py36_0         148 KB  conda-forge
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB  defaults
#     pip-19.1.1                 |           py36_0         1.8 MB  conda-forge
#     python-3.6.7               |    h357f687_1005        34.6 MB  conda-forge
#     readline-8.0               |       hf8c457e_0         441 KB  conda-forge
#     sqlite-3.28.0              |       hcee41ef_1         1.9 MB  conda-forge
#     tk-8.6.9                   |    hed695b0_1002         3.2 MB  conda-forge
#     wheel-0.33.4               |           py36_0          34 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        50.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#
# The following packages will be UPDATED:
#
#   ca-certificates                       2019.3.9-hecc5488_0 --> 2019.6.16-hecc5488_0
#   certifi                                   2019.3.9-py36_0 --> 2019.6.16-py36_0
#   libgcc-ng                                8.2.0-hdf63c60_1 --> 9.1.0-hdf63c60_0
#   pip                                           19.1-py36_0 --> 19.1.1-py36_0
#   python                                3.6.7-h381d211_1004 --> 3.6.7-h357f687_1005
#   readline                                7.0-hf8c457e_1001 --> 8.0-hf8c457e_0
#   sqlite                               3.26.0-h67949de_1001 --> 3.28.0-hcee41ef_1
#   tk                                    8.6.9-h84994c4_1001 --> 8.6.9-hed695b0_1002
#   wheel                                       0.33.1-py36_0 --> 0.33.4-py36_0
#
#
#
# Downloading and Extracting Packages
# sqlite-3.28.0        | 1.9 MB    | ##################################### | 100%
# tk-8.6.9             | 3.2 MB    | ##################################### | 100%
# readline-8.0         | 441 KB    | ##################################### | 100%
# _libgcc_mutex-0.1    | 3 KB      | ##################################### | 100%
# wheel-0.33.4         | 34 KB     | ##################################### | 100%
# certifi-2019.6.16    | 148 KB    | ##################################### | 100%
# pip-19.1.1           | 1.8 MB    | ##################################### | 100%
# libgcc-ng-9.1.0      | 8.1 MB    | ##################################### | 100%
# python-3.6.7         | 34.6 MB   | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
from operator import itemgetter
import networkx as nx
import matplotlib.pyplot as plt
from networkx.drawing.nx_agraph import graphviz_layout


def Kn(n):
    G = nx.Graph()
    a=range(n)
    G.add_nodes_from(a)
    Kn=[]
    for i in range(n-1):
        for j in range(n-i-1):
            k=j+i+1
            Kn.append((i,k))
    G.add_edges_from(Kn)
    return G

##print G.nodes()
##print G.edges()
##print G.number_of_nodes()
##print G.number_of_edges()

# Complete graph (my code)
# G = Kn(12)
# could also use
# G = nx.complete_graph(12)

# E-R is number of vertices and probability (any two vertices are joined by an edge)
# G = nx.erdos_renyi_graph(500, 0.005)
# G = nx.random_regular_graph(8, 30)

# Going for lattice stuff...
# G = nx.waxman_graph(100, 0.2)
G = nx.grid_2d_graph(3,6,periodic=False)

# This does not work on Azure as of 1/31/17
# might re-try it since I did install graphviz...
# nx.draw_graphviz(G,prog="neato",alpha=.75)

# nx.draw_circular(G, node_color='r',node_size=40,with_labels=False)
# nx.draw_random(G, node_color='r',node_size=50,with_labels=False)
# nx.draw_spectral(G, node_color='g',node_size=50,with_labels=False)
# nx.draw_shell(G, node_color='g',node_size=50,with_labels=False)
# nx.draw_planar(G, node_color='r',node_size=50,with_labels=False)
nx.draw(G)

# fig, ax = plt.subplots(figsize=(12,10))
# ax.plot(px, py)

# plt.axis('equal')
plt.show()

# plt.savefig("graph_name.png")

# %%
n = 20

from operator import itemgetter
import networkx as nx
import matplotlib.pyplot as plt
from networkx.drawing.nx_agraph import graphviz_layout
import numpy as np
import random as r

def Kn(n):
    G = nx.Graph()
    a=range(n)
    G.add_nodes_from(a)
    Kn=[]
    for i in range(n-1):
        for j in range(n-i-1):
            k=j+i+1
            Kn.append((i,k))
    G.add_edges_from(Kn)
    return G
    
def Circular(n):
    G = nx.Graph()
    a = range(n)
    G.add_nodes_from(a)
    C = []
    for i in range(n-1):
        C.append((i,i+1))
    G.add_edges_from(C)
    G.add_edge(n-1,0)
    return(G)

##print G.nodes()
##print G.edges()
##print G.number_of_nodes()
##print G.number_of_edges()

# Complete graph (my code)
# G = Kn(12)
# could also use
# G = nx.complete_graph(12)

# E-R is number of vertices and probability (any two vertices are joined by an edge)
# G = nx.erdos_renyi_graph(40, 0.1)
# G = nx.random_regular_graph(8, 30)
G=Circular(n)
# Going for lattice stuff...
# G = nx.waxman_graph(100, 0.2)
# G = nx.grid_2d_graph(3,6,periodic=False)
# G=nx.hypercube_graph(4)
# nx.draw(G,alpha=.75)
# nx.draw(G, pos=graphviz_layout(G), node_size=1600, cmap=plt.cm.Blues, node_color=range(len(G)))
#,prog='dot')

# print nx.adjacency_matrix(G)
# print nx.laplacian_matrix(G)
# print nx.laplacian_spectrum(G)
# print nx.algebraic_connectivity(G)
# print 'Euler'
# print dir(nx)


# eCirc = nx.hamiltonian_circuit(G)
# print eCirc.next()

nx.draw_circular(G, node_color='r',node_size=40,with_labels=False)
H=G
n_attempts = 0
n_additions = 0
while not nx.is_chordal(H):
    a = r.randint(0,n-1)
    b = r.randint(0,n-1)
    n_attempts += 1
    if a != b and not H.has_edge(b, a):
        H.add_edge(a,b)
        n_additions += 1
nx.draw_circular(H, node_color='k',node_size=20)
print(n_attempts, n_additions)
K=nx.complete_graph(n)
print(nx.is_isomorphic(H,K))
print(n*(n-1)/2)
print(H.number_of_edges())
print(H.number_of_nodes())

    


# nx.draw_random(G, node_color='r',node_size=50,with_labels=False)
# nx.draw_spectral(G, node_color='g',node_size=50,with_labels=False)
# nx.draw_shell(G, node_color='g',node_size=50,with_labels=False)


# fig, ax = plt.subplots(figsize=(12,10))
# ax.plot(px, py)

plt.axis('equal')
plt.show()

# plt.savefig("graph_name.png")
# Out:
# 707 167
# False
# 190.0
# 187
# 20

# %% [markdown]
# # Leech Trees
#
# Concerning a problem in graph theory that probably does not have a solution...
#
# Begin please by running the next cell down which sets up some necessary images.

# %%
# !curl https://raw.githubusercontent.com/robfatland/othermathclub/master/images/graphs/graphs2_002_Leech_trees.png -o /home/nbuser/graphs2_002_Leech_trees.png -s
from PIL import Image

# %% [markdown]
# ## Proof section
#
# Everything from here down is about proofs, not problems.
#
#
# ### Leech trees
#
#
# This is not a problem but rather a proof. You might read it like a story; and it concerns a kind of graph called a tree
# so you may wish to brush up on trees first by reading through Book 1 Chapter 12 and Book 2 Chapter 8.
#
#
# Each edge of a tree can be assigned a *weight* which, for example a number. You could just as easily make this
# number be the length of the edge between the two vertices. Normally we allow graph edges to be 'no particular
# length' so this is a new thing we are adding.
#
#
# Recall that trees are connected and they do not contain any cycles or loops. There is therefore one and only one
# path between any two vertices. On a weighted tree by noting the weights along a particular path we can accumulate
# a sum for that path.
#
#
# The proof given here concerns a question about weighted trees called Leech trees (after the inventor). We will get
# to the proof in a moment but first we should describe what a Leech tree is! Suppose there are $p$
# possible paths for a tree with $n$ vertices. The first question is what is $p$? If you like you may work this
# out before continuing.
#
#
# This question is equivalent to the question "Given a set of $n$ objects how many pairs of objects can be selected?"  The
# answer from combinatorics is *n choose 2* written mathematically as
#
#
# $$P = \binom{n}{2} = \frac{n\cdot(n-1)}{2!}=\frac{1}{2}(n^2-n)$$
#
#
# Now: If the tree is arranged in a particular way and the edges are assigned particular weights we can imagine that
# the $P$ path sums might be the numbers 1, 2, 3, 4, 5 and so on up to $P$. Such a tree is called a
# Leech tree. How many such trees are there? Only five have been found to date and this is an unsolved problem
# (as far as I can tell). Now however we know enough to read a proof concerning Leech trees. (This proof is recounted
# [here](http://www.cut-the-knot.org/arithmetic/combinatorics/LeechTrees.shtml) where I have borrowed
# their diagram of the five known Leech trees shown below.)

# %%
# Leech trees diagram: Please run this cell with Shift + Enter
# !curl https://raw.githubusercontent.com/robfatland/othermathclub/master/images/graphs/graphs2_002_Leech_trees.png -o /home/jovyan/graphs2_002_Leech_trees.png -s
from PIL import Image
Image.open("/home/jovyan/graphs2_002_Leech_trees.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=516x338 at 0x7F2C90378898>

# %% [markdown]
# #### A Proof Concerning Leech Trees
#
#
# Herbert Taylor published a proof that any Leech tree must have a number of vertices $n$ which is either a perfect
# square or a perfect square plus two. Notice that the perfect squares are 0, 1, 4, 9, 16 so that the allowed number
# of vertices in a Leech tree must be one of 1, 2, 3, 4, 6, 9, 11, 16, 18, 25, 27, ... and
# so on. The proof does not establish whether such Leech trees exist; only that if they do exist then
# their number of vertices will be one of these numbers. To put it another way: It is impossible to construct
# a Leech tree with 17 vertices because 17 is neither a perfect square nor a perfect square plus two.
#
#
# Before going any further let's sketch out the proof so that you can try it on your own. You may begin working
# on it directly without reading further of course! Or you can consider this outline as a starter kit; or you
# can simply read through the proof (which is what I did).
#
#
# - All edge weights are integers, are therefore even or odd
# - About half of the $P$ paths have odd path sums
# - Individual vertices can be divided into two sets A and B where...
# - ...paths between an A and a B have odd path sums
# - The total number of paths with odd path sums can be written in two different ways and set equal
# - The remaining arithmetic shows the total number of vertices $n$ to be either...
# - ...a perfect square or...
# - ...a perfect square plus two...
#
#
# #### A Computational Analysis of Leech Trees
#
# Leech trees with more than six vertices may or may not exist. One question we can ask at this point is 'Can
# we teach a computer to search for Leech trees?' The answer certainly 'yes' but we might be looking for a needle
# in an impossibly large haystack. It would be a good idea (before writing the program) to estimate just how
# big that haystack is.
#
#
# Notice that the five known Leech trees have 2, 3, 4, 4, and 6 vertices. These are all allowed numbers of vertices
# so it is a relief that this is consistent with Herbert Taylor's result! Let's consider a Leech tree with 16 vertices
# since L.Szekely determined (using a computer) that there are no Leech trees with 9 or 11 vertices. How long would
# it take to search all possible trees with 16 vertices? Well such a tree will have 15 edges but we can begin by
# constructing a "necessary tree" of three vertices o--------o--------o. (We don't know the weights yet but
# more on this in a little bit.)
#
#
# Now we have two edges so we must place 13 additional edges.
# Once these edges are placed we will have path sums 1, 2, 3, 4, ..., 120 since 16 choose 2 is 120.
# One of the edge weights will have to be 1
# and another will have to be 2 and a third will have to be 4. We don't have to have an edge with weight 3 because
# this can be done by placing the 1 and 2 edges next to one another. But the weights must be unique so the only
# way to get a path sum of 4 is to have a single edge with weight 4. We can continue to think about rules for
# the weights but let's pause on that for a moment just to arrive at a first estimate of the problem size.
#
# After 1, 2 and 4 there remain 12 more edge weights remaining to determine.
# If we use 3 and then manage use the 10 consecutive integers larger than 4: 5, 6, 7, ..., 14 then we notice that
# the very last path with path sum 120 would imply 106 as a maximum edge weight. If it were any greater it would
# connect along some path to the 14-weight edge and give a path sum greater than 120, not permitted. So the
# edge weights are in the range $[1, 104]$.
#
#
# Since we begin with 1, 2 and 4 and must choose 12 additional weights from the set { 3, 5, 6, 7, 8, ..., 106}
# we have $\binom{106}{12}$ which is about $2 \times 10^{15}$. Then we must distribute these
# numbers across one of the myriad possible 16-vertex trees... of which there are very many configurations.
# So this problem is computationally huge. It would be nice to have some additional constraints on the numbers
# we will use and the tree configuration in order to reduce the computation time to something less than
# the age of the universe.
