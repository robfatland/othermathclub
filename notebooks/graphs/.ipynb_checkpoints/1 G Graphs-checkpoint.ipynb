# %% [markdown]
# # Graphs
#
# <BR>
# <img src="../../images/graphs/graphs0002.png" style="float: left;" alt="drawing" width="600"/>
# <div style="clear: left"><BR>
#
#
#
# *a connected planar graph: everything connects to everything else*
#
#
# ### Friendly introduction
#
# The above diagram is a graph. Your turn: Draw one of these diagrams, if you please.
# Each little circle is a vertex. Each line between one vertex and another is an *edge*.
#
#
# We say: 'One *edge*; many *edges*. One *vertex*; many *vertices*.'
#
#
# Let's call the graph above the *bison graph*. Copy it into your notebook now, if you please, to bison time.
#
#
# The first rule of graphs is connections (*edges*) between things (*vertices*) matter.
# Less important: How the graph is drawn.
#
#
# This is definitely *not* like geometry (very precise diagrams and measurements).
#
#
# Here is a problem from graph theory...
#
#
# ## Difficult problem
#
#
# * Show that a graph of $2n$ vertices with $n^2+1$ edges contains a triangle.*
#
#
# ## Easy problem
#
# * Trace over the bison graph with as few repeats as possible.
#
#
# We talk about graphs using
# the language of *sets*; collections of *things*.
#
#
# If you are familiar with the story of Little Red Riding Hood you know there are at
# least two ways to get to Grandmother's house: The long way and the short cut. You
# can imagine that the bison has something to do with this. Perhaps it is a
# Big Bad Bison.
#
#
# Anyway: Graphs are related to probability and counting because graphs have many paths
# which are like possibilities.
#
#
#
# ### Terms
#
#
# To copy and explain to a partner:
#
#
# - **thing**: a thing is a thing. This is an un-definition; let's simply agree we know what things are
# - **element**: a more formal name for a thing, something that belongs in a set
# - **set**: a collection of elements in no particular order
# - **empty set**: a set with zero elements
# - **subset**: A set with elements taken from another set *only*
# - **graph**: A picture of vertices and edges
# - **graph**: Two sets V and E. The V set is a set of things. The E set is pairs of things from V.
#
#
# Now with that: Is the *empty set* a *subset* of a *set*? Yes! Because why? Because that's what we have agreed upon.
#
# Is a *set* also a *subset* of itself? Yes! Because why? Because that's what we have agreed upon.
#
# Suppose a set has one element. How many subsets does it have? The answer based on the above two lines is: $2$. Why?
#
# The simplest possible graph would be two empty sets. This is known as the *boring* graph. Here is a picture of it:
#
# <br>
# <br>
# <br>
#
#
# Here is a graph defined using sets...
#
#
# $G = V, E\;\;\;  \;\;\; V = \{ a, b \}\;\;\;\;\;\; E = \{ (a,b) \}$
#
#
# In language this reads 'A graph called $G$ consists of two sets called $V$ and $E$. The $V$ set has two elements
# and they are called $a$ and $b$. We call $a$ a *vertex* and $b$ a *vertex*; together they are two *vertices*.
# The $E$ set is edges and it has only one element which is a *pair* of elements from the $V$ set. This pair
# is the pair $(a, b)$. This means that the graph $G$ has one edge between vertices $a$ and $b$.
#
#
# See if you can draw a *picture* of this graph; the solution is given down below.
#
#
# Before continuing please run the following cell (in necessary) to make sure the pictures are available for this page.

# %% [markdown]
# <BR>
# <img src="../../images/graphs/graphs0001.png" style="float: left;" alt="drawing" width="600"/>
# <div style="clear: left"><BR>

# %% [markdown]
# *the bison graph modified*
#
#
# Here the bison has found an extra vertex.
#
#
# The graph is now disconnected: There is a vertex floating
# over at the right.
#
#
# The bison's head has become a loop. That is an edge connecting a vertex to itself.
#
#
# The shoulder has two edges between the same pair of vertices.
#
#
# This shows variations in how graphs can be constructed.
#
#
#
#
# ### Planar graphs
#
#
# Some graphs like the ones above can be drawn on a piece
# of paper with no edges crossing one another. These are *planar graphs*.
#
#
# ### Graphs as pictures and as sets
#
#
# Graphs are easy to see as pictures.
#
#
# Graphs are defined as two related sets.
#
#
#
# Sets in turn contain
# *things* or *elements* and we don't even *try* to define these except in a circular way.
# By the way the graph $G$ described above could be drawn like this: $a$ o---------o $b$
#
#
# Let's convert another *set definition* of a graph into a *diagram* of that graph.
# We begin with a set of vertices.

# %% [markdown]
# <BR>
# <img src="../../images/graphs/abcd_elements.png" style="float: left;" alt="drawing" width="400"/>
# <div style="clear: left"><BR>

# %% [markdown]
# This set has four *elements*. To make a *graph* we need a second set as well, the one that lists pairs of elements.
# We build a new version of $G$ like so:
#
#
# $G\;$ is the set $V=\{\; a,\; b,\; c,\; d\; \}\;$ together with the set $\;E=\{\; (a,b),\; (a,c),\; (b,c),\; (b,d)\; \}$
#
#
# That is: $G$ is a first set $V$ with four elements $a$, $b$, $c$, and $d$ plus a
# second set $E$ whose elements are pairs from the first set: $(a, b)$ and $(a,c)$ and $(b, c)$ and $(b, d)$.
#
#
# <br>${\Huge{\infty \;} \Large Challenge}$
#
# Draw $G$ as a diagram.

# %%
kilroy.Show('graphs','graphs0004.png', 400, 250)
# Out:
# <PIL.Image.Image image mode=RGBA size=400x250 at 0x7FB9FE9DF990>

# %% [markdown]
# <br><br>${\Huge \infty}$
#
#
# Describe the graph diagram using two sets.

# %%
kilroy.Show('graphs','graphs0005.png',500,350)
# Out:
# <PIL.Image.Image image mode=P size=500x350 at 0x7FB9FEA417D0>

# %% [markdown]
# ### Musical note
#
# A composer named Stravinski was asked to draw a representation of his music. This was the result.

# %%
kilroy.Show('graphs','graphs0006.png',600,250)
# Out:
# <PIL.Image.Image image mode=RGBA size=600x250 at 0x7FB9FEA41B90>

# %% [markdown]
# *Stravinksi draws a picture of his music*
#
#
# There may be other aspects of the world that could be represented as graphs.
#
# <br><br>${\Huge \infty}$
#
# Describe two things that you know about using graphs. Remember that *edges* are ways to connect *things*
# in some way. You are very talented at making connections.
#
#
# **Extra** There is a gallon puzzle presented on the **numbers** page. It involves a farmer getting water
# for some horses. Could this be represented as a graph?
# How about a board game like checkers: Could this be viewed as a graph?
#
#
# How about a hexaflexagon? This is discussed on the second page on **topology**.
# (There is a prize in omc for the first graph of all the configurations of a hexahexaflexagon.)
#
#
# ### Reviewing basics of graphs
#
#
# A *vertex* is (in the diagram) a dot of some sort. The plural of vertex takes a little getting used to;
# it is *vertices*. An *edge* has an easier plural: *edges*. As we have seen: Edges connect vertices in graphs.
# We have defined a couple of graphs using two sets. The first set was the vertex set; the second was the edge set.
# We write something like $G = (E, \; V)$.
#
#
# The diagram of a graph is fluid, squishy, rubbery. This is related to **topology**.
# A diagram of a graph places vertices and edges in relation; but we are free to draw this
# picture any way we like provided we preserve the connectivity.
# The diagram below illustrates *deforming* a graph.
#
# The first version of the diagram below, at the left, shows two edges crossing. By moving the green vertex
# we arrive at a version of the diagram at the lower right with no edges crossing. All four diagrams are the same graph.
# If it is *possible* to draw a graph with no edges crossing the graph is called a *planar* graph.

# %%
kilroy.Show('graphs','graphs0007.png',1000,400)
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x400 at 0x7FB9FE9DF610>

# %% [markdown]
# ### Edges and paths
#
# We may take a pen and run along edges to make a path through a graph. This graph below has five
# vertices and six edges. Two of the edges cross over one another as drawn. That is ok and
# it is important to realize those edges do not connect with one another.

# %%
kilroy.Show('graphs','graphs0008.png',250,250)
# Out:
# <PIL.Image.Image image mode=P size=250x250 at 0x7FB9FE9ED2D0>

# %% [markdown]
# <br><br>
# If we run along edges and they cross one another: We may not hop from one edge to another along the way.
# This pink path shown below is just fine. A path that connects four of the five vertices in the graph.

# %%
kilroy.Show('graphs','graphs0009.png', 250,250)
# Out:
# <PIL.Image.Image image mode=RGB size=250x250 at 0x7FBA148C07D0>

# %% [markdown]
# <br><br>
# The pink path shown below is not a proper path.  As you can
# see it hops from one edge onto another between vertices, just where the arrow is pointing.**This is not allowed.**

# %%
kilroy.Show('graphs','graphs0010.png',250,250)
# Out:
# <PIL.Image.Image image mode=RGBA size=250x250 at 0x7FB9FE9EDED0>

# %% [markdown]
# <br><br><br>
#
# ### Faces and worrying
#
# Below is a graph drawn twice: Once with vertex labels and once without.
# It has four vertices, four edges and two faces. Let's take a moment to describe
# what we mean by faces. A *face* on a graph is a region surrounded by edges.
# It is easy to see that the triangle gives us a face... so why do we say there are two faces?
#
# <br><br>${\Huge \infty}$
#
#
# Take a moment to guess what is meant by the second face.
#
#
# The second face is the *everything else* region that surrounds the graph. We could say that it goes
# off to infinity. It isn't so much surrounded by edges, this huge face. Rather *it* does the surrounding.
# Anyway it still counts as a face so this graph has two faces.
#
#
# Now about worrying... In the left diagram the vertices have labels so we know precisely
# what *things* they are: $\{\; A,\; B,\; C,\; D\; \}$.
# The edges are $\{\; (A, B),\; (B, C),\; (B, D),\; (C, D)\; \}$.

# %%
kilroy.Show('graphs','graphs0011.png',1000,250)
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x250 at 0x7FB9FEA41D10>

# %% [markdown]
# In the second diagram above, on the right: The labels are gone. This is more abstract.
# The structure of the graph is preserved in the second picture with no regard for vertex labels.
#
# Sometimes we worry about labels and sometimes we do not.
# For example the labels are important in a practical
# graph of a checker game or a hexaflexagon.
# Labels come in and out of the picture depending on what we're thinking about; but we are always
# free to add labels on vertices, on edges, and on faces as we like.
#
#
# ### Planar graphs
#
#
# We described planar graphs above. Let's do that again.
#
#
# Suppose you have a picture representation of a graph: Vertices and edges. If this picture can be
# drawn such that none of the edges cross over other edges the graph is called a *planar graph*.
# One way to determine if a graph is planar is by trial and error:  Move the vertices and edges
# around on the page, perhaps with some stretching and some bending of edges, to try and un-cross
# all the edges.
#
# <br><br>${\Huge \infty}$
#
# Which of the following three graphs is a planar graph?
#
# (Notice that making edges go through vertices is just confusing so let's agree to not do that in our diagrams.
# If an edge hits a vertex it must stop there.)

# %%
kilroy.Show('graphs','graphs0012.png',800,230)
# Out:
# <PIL.Image.Image image mode=P size=800x230 at 0x7FBA148C0C10>

# %% [markdown]
# The answer is that the left and middle graphs are planar and the right graph is not.

# %%
kilroy.Show('graphs','graphs0013.png',800,230)
# Out:
# <PIL.Image.Image image mode=P size=800x230 at 0x7FB9FE9EDE10>

# %% [markdown]
# The left graph is clearly a planar graph: No edges cross.
#
# The center graph is also a planar graph. I moved the crossing edge so that it still connects the same two vertices; but it no longer crosses other edges. Because this is possible the graph is planar.
#
# The right graph is not planar. I moved some of the edges around but it is not possible to rearrange them all so that none of the edges cross. Specifically neither of the two crossing interior edges can be relocated so as not to cross another edge. You can see
# how the vertex connections constrain what the edges do at their endpoints.
#
# ### Paths and Cycles and Circuits
#
# You can find many paths in a graph that travel along edges from one vertex to another.  A path that
# comes back to the vertex where it begins is called a cycle. Such a path, one that returns to where
# it begins, is not allowed to cross an edge more than once. Consequently we see that a cycle involves
# at least three vertices and at least three edges.
#
# <br><br>${\Huge \infty}$
#
# How many cycles are there in the graph shown below? One is shown in pink.

# %%
kilroy.Show('graphs','graphs0014.png',400,350)
# Out:
# <PIL.Image.Image image mode=RGBA size=400x350 at 0x7FB9FE9ED950>

# %% [markdown]
# This question is simple to ask but the answer is rather long. Before reading further
# you can take a moment to double-check your answer. There are $37$ cycles.
#
#
# #### A rather long answer
#
# How many cycles are there in this graph shown above? The graph has five vertices and
# the cycles must be distinct from one another. Let's count them all... but I will use
# the notation for combinations. If you are not familiar with this you can learn about
# it from the beginning on the **probability** page.
#
#
# Three vertices are necessary for a cycle. Since all possible edges are present
# in this graph the number of possible 3-vertex cycles is equal to the number of ways
# that $3$ things can be chosen from a set with $5$ elements. This is called "$5$ choose $3$"
# and is written $\binom{5}{3}$. It equals $10$.  A 3-cycle has no direction so we do not
# count it twice, like *forwards and backwards*. So there are 10 3-cycles.
#
#
# For a cycle visiting four of the five vertices: One vertex is always left out. Hence
# there are five such choices of four vertices. Let's call one of these $\{ A, B, C, D \}$.
# A cycle can be written as $ABCD$ since we know that $D$ connects back to $A$ to complete the
# cycle. We could also follow $ABDC$, $ACBD$, $ACDB$, $ADBC$ and $ADCB$ making a total of six.
# However notice that $ABCD$ and $ADCB$ represent the same cycle traversed in opposite directions;
# which again we take to be the same cycle. To avoid double-counting in this way we divide
# by two to get three possible cycles for a given choice of four vertices. Therefore since
# there are five such choices with three distinct cycles each: There are 15 4-cycles.
#
# Finally we have the Hamiltonian cycles that touch all five vertices. There is only one
# choice for the vertex set, ${ A, B, C, D, E }$. How many ways can we arrange these, being
# careful not to double-count the reverse direction cycle? Let's always choose $A$ as the
# starting vertex since $A$ is sure to be in there somewhere. Then there are four choices
# for the second vertex, three for the third, and two choices for the fourth. Only one choice
# will remain for the fifth vertex; for a total of 24 possible sequences. However as
# before this double-counts. For example the sequence $ACEDB$ is the reverse of $ABDEC$.
#
# This accounts for all possible cycles so the total is $10 + 15 + 12 = 37$.
#
# A graph that contains all possible edges, incidentally, is called a *complete
# graph*. This is usual written $K_n$ where $n$ is either abstract or is an actual
# number. For example in this case we have found the
# number of cycles in $K_5$ to be $37$.
#
#
# ### Extra
#
# If $n$ is some integer (abstract): How many cycles are there in $K_n$? Since $n$ could be anything
# the answer will depend in some way upon $n$, the number of vertices in the complete graph.

# %%
kilroy.Show('graphs','graphs0015.png',400,330)
# Out:
# <PIL.Image.Image image mode=P size=400x330 at 0x7FBA14173B50>

# %% [markdown]
# ### Hamiltonian circuits
#
# A path in a graph that touches all of its vertices is called a *Hamiltonian path*.
# A cycle in a graph that touches all vertices is a *Hamiltonian circuit*.
# Here is a graph (it is planar but not drawn to properly show this)
# with a Hamiltonian cycle shown in pink:

# %%
kilroy.Show('graphs','graphs0016.png',800,300)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x300 at 0x7FBA148C0C90>

# %% [markdown]
# <br><br>${\Huge \infty}$
#
# ### Questions
#
# Of the following graphs... which are also included in club resources on paper...
#
# * Which are planar?
# * Which have a Hamiltonian path?
# * Which have a Hamiltonian circuit?

# %%
kilroy.Show('graphs','graphs0017.png',900,400)
# Out:
# <PIL.Image.Image image mode=P size=900x400 at 0x7FB9FECADD50>

# %% [markdown]
# ### Extra
#
# There are some good introductory books on graph theory. Graphs are connected in our
# mathematical landscape to topology, probability, combinatorics, numbers, games and the theory of information.
#
# - Introduction to Graph Theory by Richard Trudeau, ISBN-10: 0486678709 (my favorite)
# - Mathematical Gems volumes 1 and 2 and 3 by Ross Honsberger (more advanced)
# - Introductory Graph Theory by Gary Chartrand
