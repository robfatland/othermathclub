# %% [markdown]
# # Activities and Lectures

# %% [markdown]
# ### References
#
# - The book _Solve This_
# - The book _Which Way Did The Bicycle Go?_
# - Honsberger, particularly Gems I II III (IV?)
#
#
# ## Activities
#
#
# - October 2 we wore *hats* that were black or red playing cards.
# - October 9 we were focused on getting the website cloned and the OneNote invites in place
# - October 16 we enacted Ms. Halfway
# - Oct 23 skip
# - Oct 30 the *plan* is to have two students be curly brackets, other students = things; count subsets and connect to binary
#
#
#
# ### Activity and Assignment Ideas
#
# - Bring me spiral counts
# - Prisoners with hats
# - Candy
#   - Everyone in a circle has an even number of wrapped pieces of candy. This varies randomly.
#   - Predict / try / write
#       - Give half your candy to the person on your left
#       - Receive a supply of candy from the person your right: simultaneously.
#       - Now recount your candy supply.
#       - If you now have an odd number of pieces take an extra from the reserve
#       - Repeat
#   - How many pieces of candy were there at the start?
#   - At the end?
#   - Instead: Eat odd pieces of candy to bring your pile back down to an even number?
#   - Give half your candy to the person on your left and the other half to the person on your right?
#
# - Expert Game
#   - logical fallacy
#     - *proof by assertion*
#     - *proof by appeal to authority*
#     - *disproof by questioning character*
#     - *proof by assuming the conclusion*
#   - Four participants: E, F, A and N.
#     - E is a genuine Expert who is usually right.
#     - F is a Failed Expert who holds ideas that can be shown to be wrong.
#     - A is Assertive: He claims to be right but his claims are untested.
#     - N is a normal person: She is presented by arguments from E, F and A.
#   - Presentation of $C$ will involve some research and preparation by E, F and A.
#     - Each of the three presenters has both a strategy and a method.
#     - The game proceeds in three rounds where the first round serves to set everything up:
#     - E is permitted to present $C$ but this is done without proof in the first round.
#     - F must present an alternative to $C$ that sounds much more plausible.
#     - A must either support E, support F or provide a third view.
#   - 1. E, F and A present arguments in a random order (or as chosen by N).
#     - N writes down which argument she believes is correct.
#   - 2. E, F and A provide a supporting statement.
#     - Again N writes down which argument she believes.
#     - She is welcome and encouraged even to change her mind.
#   - 3. E, F and A provide a revision statement.
#     - This statement is of the form "Since my last remarks some new evidence has come to light..."
#     - Followed by the revision or clarification.
#   - To set up the game our goal is to come up with a dubious claim that is nevertheless true. Call this claim $C$.
#       - E presents $C$ correctly.  Creative manipulation of $C$ makes the presentation doubtful.
# E is trying to get N to doubt the claim originally (by selecting one of the other two presenters)
# and then will try to get N to change their mind in stage 2 or stage 3.
# Therefore: Saying $C$ with a straight face is a good strategy, provided $C$ itself sounds
# outrageous and impossible. Ideally N does not believe E after round 1 but chooses F and/or A.
# In round 2 E is allowed to present a very short justification of why $C$ is true. E gets
# maximum score if N changes her mind after round 2. E gets fewer points if N changes her
# mind after round 3. In round 3 E is allowed to make a short supporting statement that
# must cite prior work. That is: Round 3 is an appeal to authority. The reason for this is
# that experts build on established ideas.
#       - F presents $C$ incorrectly; and should go to pains to make the claim sound very reasonable. F would like
# N to choose her argument first and continue to support that argument through to the end. F can either
# create false evidence or cite authority or resort to any other possibly unscrupulous means.
#       - A presents either support for F or support for N or a third idea. A gets maximum points if they
# can convince N to arrive at a wrong solution at the end of round 3; it does not matter what N
# decided in rounds 1 and 2.
#   - Example: E says "Humans are built from mistaken copies of a computer program made from four instructions."

# %% [markdown]
# ## Lectures
#
#
# ### Monte Carlo
#
#
# - Two famous mathematicians -- Ulam and Von Neumann -- invented a method of exploring called **Monte Carlo**.
# - The method takes advantage of the speed of computers; and it requires the computers to generate random numbers.
# - We can simulate Monte Carlo by handing out some dice and recording sums. This is a case where we can also solve exactly.
# - We are using this to show how an actual experiment gets progressively closer to a theoretical result.
# - This leads to special attention to the words **theory** and **experiment**: What do they mean?
# - Compare this to the words **abstract** and **definite**
# - What are some examples of random sampling as a way of exploring?
#
#
# ### Geometry
#
#
# - Let's talk only about lines, triangles and circles
# - We shall begin by drawing by hand... I will draw a figure and you do likewise in your notebook
# - A line grazes a circle. Is it possible to touch at only one point? What is the angle?
# - Two circles can touch at only one point? What is the angle?
# - What does it mean, the center of a triangle? There are three...
# - How do we get the area of a triangle?
# - What is $C/d$?
#
#
# ### Infinity
#
#
# * If all there was to infinity was $1\;+\;2\;+\;3\;+\;4\;+\;\cdots\;\;\;=\infty$ then this lecture would be over.
# * There are two important ideas about infinity that I would like to share with you.
#   * Infinities that go outward and get very large. You can count them perhaps... but you never finish.
#   * Infinities that go on forever but grow smaller and smaller... so they add to something *not* infinite.
#
#
# ### Graphs
#
#
# - Time to introduce you to a District of Mathematics called Graph Theory.
#   - It is behind this gate but notice that the gate is locked. So first we unlock the gate with some key ideas. Get it?
# - We begin by defining a thing
#   - A **thing** is a thing.
#   - (It can't be defined without using another word that is just a synonym for *thing*.)
# - A **set** is a collection of things.
#   - (We give them labels to keep them straight: $\{v_1, v_2, v_3, ..., v_n\}$)
# - A **graph** is two sets: A set of things we call V and a set of pairs of things from V we call E.
#
#
# $$G=(V,E)=(\{v_1, v_2, v_3, ...\}, \{(v_1, v_2), (v_3, v_5), ...\})$$
#
#
# - Together V and E sound terribly abstract and hard to do anything with.
#   - But good news: We can easily draw a picture of a graph $G = (V, E)$.
#   - See the bison up above
# - Notice that this *thing* here and this *thing* here are connected.
#   - So the first *thing* has a name $v_1$...
#   - ...but we can also point to it and say it is that *thing* connected to this other *thing*.
#   - Just as you know my *name* but you also know me as *acquaintance of Ms.H*.
# - There is an equivalence between writing out the sets and drawing the picture
#   - They correspond, no matter how we rearrange the picture
#     - Just as I can move around the room and Ms. H can move around the room...
#       - That does change that we are mutually acquainted.
# - Now we have just enough to say that the gates to Graph Theory are open.
#   - Let's step through, and the first thing we will do is attend a party...
#
# * Let's say an odd number of people are at the party. Can everyone shake hands an odd number of times? You may not
# refuse a handshake and you may not shake hands with yourself.
#
#
# ### Numbers and Diophantus
#
#
# - Write 'Diophantus 240 Fermat 1640 Wiles 1994' on the board
# - You know and I know that sometimes answers are 1.2 or 2/3... not whole numbers like 6 or 19
# - But did you know there are certain problems that *require* the answers to be whole numbers?
# - Suppose you survey a barnyard and notice there are only cows and chickens... and you count 42 legs and 42 ears.
# How many chickens are there? What does a negative chicken look like?
# - Ok let's review our sanity check -- do all problems play fair? -- and revise it to 100 legs and 42 ears. Now how many
# chickens are there?
# - Problems that have whole number solutions are called Diophantine problems, after Diophantus.
# - Diophantus wrote *Arithemetica* in AD240... a book of math problems and solutions...
# - ...and 1400 years later while reading a copy of this book Pierre de Fermat
# claimed that there are no positive integer solutions to $a^n+b^n=c^n$ for $n>2$...
#   - He said he had a proof but it would not fit in the margin
# - ...and this claim of Fermat was shown to be true in 1994 by Andrew Wiles, 354 years after Fermat suggested it
# - Meanwhile we have $n=2$ which looks thus and is related to the Pythagorean theorem for right triangles
# - So it is ok for Pythagoras... just not for bigger exponents, for positive integers
# - Let's make a couple more remarks about numbers
#   - We use base 10... with 10 symbols we write 471 with the idea of *place* but what is this in base 7 or base 2?
#   - We know that if $3 \cdot 8 = 24$ then $24$ is divisible by $8$ and by $3$ but $25$ is divsible by neither
#   - 1 is 1. 2 is prime. 3 is prime. 4 is composite. 5 is prime. And so on.
#     - After 1 you are either a prime or you can be factored into primes.
# - Once you have the basic terms down for numbers you can go quite far... let's do one problem
#   - What is an easy way of figuring out if some big number is divisible by 9?

# %% [markdown]
# ### Negative One Squared
#
#
# - Suppose I were to ask you what is $1 \times 1$  How about $1 \times -1$? $-1 \times 1$? $-1 \times -1$?
# - We can redefine **number** to be **anything that follows the rules of arithmetic**
# - In particular let us take regular numbers in pairs and call them **complicated numbers**
# - If we can come up with rules of addition and multiplication then we have an entirely new number system!
# - To make progress we will have to agree that there are four ways of writing these new numbers
#   - This is rather like graphs that have set notation as well as picture notation
# - The four ways are: $(a, b)$, $re^{i\theta}$, 'draw a dot on the plane', $a \;+\;ib$
# - Each of these has its uses but we will use the first two to define addition and multiplication
# - The final step is to notice that the real numbers are a part of the complex numbers.
#   - Therefore we can use complex multiplication to discover that $-1 \times -1 = 1$
