# %% [markdown]
# # Professor Plateaus Soap Films

# %%
# !curl https://raw.githubusercontent.com/robfatland/othermathclub/master/images/minecraft/seashell0002.png -o /home/nbuser/seashell0002.png -s
from PIL import Image
Image.open("/home/nbuser/seashell0002.png").resize((700,400),Image.ANTIALIAS)
# Out:
# <PIL.Image.Image image mode=RGB size=700x400 at 0x7FE08CC68FD0>

# %% [markdown]
# In the 19th century [Professor Joseph Plateau](https://en.wikipedia.org/wiki/Joseph_Plateau)
# solved the problem of how soap bubbles connect together.
#
# ### Terms
#
# As always copy out the boldface terms and their definitions. Then convince a friend you know what the other terms mean.
#
# - **mean curvature**: hoo boy
