# %% [markdown]
# # ${\Large \infty}$ Topology

# %%
# !curl https://raw.githubusercontent.com/robfatland/othermathclub/master/images/graphs/konigsberg_bridges.png -o /home/nbuser/konigsberg_bridges.png -s
from PIL import Image
Image.open("/home/nbuser/konigsberg_bridges.png").resize((600,300),Image.ANTIALIAS)
# Out:
# <PIL.Image.Image image mode=RGB size=600x300 at 0x7F2B5014EA50>

# %% [markdown]
# *bridges in the town of Konigsberg*
#
#
# ### Friendly introduction
#
#
# Topology is the study of shapes and curvature and donuts and coffee. To be honest I am learning
# topology now so I'm not terribly sure what it is... but I am pretty sure it involves donuts.
# Topology day at the Other Math Club will certainly involve donuts.
#
#
# Let's try again. Topology is about shapes that you can bend and stretch and even crumple... but you may
# not change these shapes using glue and you may not tear them. Everything is made (in our imagination)
# from rubber sheets or modeling clay so that we can *deform* our shapes as we like.
#
#
# In these notebooks we have another subject track on **graphs**.
# Graphs are related to topology:
# They can also be bent and stretched provided we do not change how they are connected together.
# Again: no glue, no tearing.
#
#
# The picture above features seven (red) bridges across the river.
# Can you find a path that crosses each bridge just once? That is a question that we could say
# belongs to topology (or graph theory) because it doesn't matter how you stretch or deform the map...
# as long as you keep the basic structure of the rivers and the bridges the same.
#
#
# Let's try another topology example. If you are not familiar with the mobius strip they look like this...

# %%
# !curl https://raw.githubusercontent.com/robfatland/othermathclub/master/images/topology/mobius_green_paper.png -o /home/nbuser/mobius_green_paper.png -s
from PIL import Image
Image.open("/home/nbuser/mobius_green_paper.png").resize((400,230),Image.ANTIALIAS)
# Out:
# <PIL.Image.Image image mode=RGB size=400x230 at 0x7F43F0189ED0>

# %% [markdown]
# Imagine that you are the size of an ant and able to walk along this mobius strip.
# You walk along near the edge but staying on the flat part. Would you
# eventually come back to where you began? This mobius strip by the way
# is an example of a *manifold*. A manifold is a shape that can be full of curves
# but when you zoom down very close and look at a tiny part of it: It is flat.
# The earth is a manifold for example.
#
#
# Now that we have mentioned the earth as a manifold and a mobius strip as a manifold we have
# time for just one more manifold in this introduction.
#
#
# Suppose we have a large sheet of paper. On this sheet of paper there live fish;
# and the sheet of paper is also extraordinary. You might suspect it is extraordinary because
# fish live on it... but no, that's not why. The fish are ordinary fish and they spend their time
# swimming about looking for food. What is extraordinary about this sheet of paper is that if a fish
# swims off the right side it immediately appears again on the left side. And vice versa.
# If a fish swims off the sheet of paper at the bottom it immediately reappears at the top, and vice versa.
# In fact for just a moment you can see its head at the top of the sheet and its tail at the bottom;
# but the fish never notices this. It is as if the top edge of the sheet is connected to the bottom edge
# and the left edge is connected to the right edge.
#
#
# Now in the world of flat sheets of paper this is just impossible. But fortunately you and I live in
# three dimensions and what I have just described is perfectly possible.
#
# <br><br>${\Huge \infty}$
#
# Your first challenge is imaginative: Lift that extraordinary sheet of paper up off the table into
# your three dimensional world and explain how it is that a fish can swim off one edge of the sheet
# and reappear on the other: Left-right *or* top-bottom. In your notebook, please!

# %% [markdown]
# ### Terms
#
# - **manifold**: a curved shape that is locally flat
# - **mobius strip**: a one-sided manifold that looks like it has two sides
#
#
# ### Hike
#
# One way of exploring manifolds is to use soap film. That's where this is going eventually, by means of
# a curvy path. We will also stay connected to graphs as we go along, particularly graphs that are *planar*.
# For more about graphs please visit the **graphs** track.
#
#
# ### Solution to the fish paper problem
#
#
# This is an example of an un-solved problem *here*. That is: It is solved but this notebook does not
# give a solution because you can solve it.

# %% [markdown]
# ### Kongisberg Bridges Problem
#
#
# The problem given above about bridges comes from a map of the city of Konigsberg, back in the 1700s.
# Euler solved it but pretended that it was not really a mathematical problem. This is because topology
# and graph theory had not been invented yet... but after he was done talking they were.
#
#
# In what follows: We restate the problem, give the answer, and then give a short version of Euler's solution.
#
# <br><br>${\Huge \infty}$
#
# Is there a path through the town of Konigsberg (map at top of this page) that crosses each bridge only once?
#
# <br><br><br>
# **Solution**: No.
#
#
# <br><br>${\Huge \infty}$
#
#
# Why is there no such path? That is: See if you can come up with a proof.
#
#
# **Euler's Solution** Notice that there are four pieces of land in the problem, each with an odd number
# of bridges connecting it with other pieces of land. Call these pieces of land $A$, $B$, $C$, and $D$.
# $A$ is the area at the lower left. $B$ is the island. $C$ is the large area at the top.
# $D$ is the area on the right. All are separated by the blue water; and then there
# are the seven bridges in red.
#
#
# A bridge crossing between two pieces of land can be described using two consecutive letters. If I cross a bridge
# from $A$ to $B$ I can write $AB$. If I go from $A$ to $B$ to $C$ to $D$ and back to $A$ that can be written
# in five letters as $ABCDA$. With five letters we describe crossing four bridges.
# Make sure this makes sense to you before continuing.
#
#
# Suppose there is a solution. That is: Imagine that some path crosses all seven bridges once.
# This path will cross a sequence of bridges and can be described using the letters $A$, $B$, $C$ and $D$.
# Since there are seven bridges this solution would be written using 8 letters.
#
# Notice that land area $A$ has three bridges so the letter A must appear twice in this solution. For
# example $ABAD$ would cross all three of these bridges once as part of the solution; and $A$ appears two
# times in $ABAD$.
#
#
# <br><br>${\Huge \infty}$
#
#
# Write in your notebook why the letter $B$ (for island $B$) must appear three times in a solution path.
#
#
# Regions $A$, $C$ and $D$ must appear twice each in a solution. $B$ must appear three times in a solution.
# That is: the various pieces of land must appear 2 + 3 + 2 + 2 = 9 times; so there must be 9 letters
# in the solution. However earlier we realized that a solution must be 8 letters long... so a 9-letter
# solution must have 8 letters... so there is no solution.

# %% [markdown]
# ### Mobius strip questions
#
#
# The mobius strip is actually a very important idea in topology (I learn). In fact it is sort of the topological
# equivalent of the number $1$.
#
#
# <br><br>${\Huge \infty}$
#
#
# - Count the number of sides of the surface at some location by flipping the paper over. How many? (I count $2$.)
# - Count the number of sides of the surface by tracing along it with your finger. How many? (I count $1$.)
# - Which of the above two answers do you consider correct? That is: How many sides does a mobius strip have?
# - Make, read, think, predict, cut, observe, write: Make a mobius strip out of paper.
# Cut the mobius strip in half down the middle -- carefully, using scissors -- after you predict
# the result of doing this.  What did you predict? What was the actual result? Please write this down.
# - Again read, think, predict, cut and write the results: Make another mobius strip and start 1/3 of the way across the width, again cutting parallel to the edge. Eventually you will run out of paper to cut. Write down the results.

# %% [markdown]
# ### Two clay rings
#
# Hold out one hand and make a ring with your thumb and forefinger. Do the same with your other hand. Now join them so
# that they are interlocking. (We won't watch in case you need to separate two fingers for a moment.) Let's call this
# configuration of you and your interlocking fingers '$\alpha$'.
#
#
# Now pull your hands apart but keep your two rings. Call this configuration '$\beta$'. You probably needed to disconnect
# at least two fingers for a moment to go from $\alpha$ to $\beta$. This is 'tearing and pasting' which is not permitted in
# a topological transformation. Not to worry; we just needed to establish configurations $\alpha$ and $\beta$.
#
#
# <br><br>${\Huge \infty}$
#
# Now suppose you have a clay model of yourself. It is a nice sort of clay that deforms easily and we'll say it is
# scaled down to be two feet tall. Since you can deform this clay as much as you like you could do quite a lot to
# this model. The question is: Can you make the model go from $\alpha$ to $\beta$ and back to $\alpha$
# without any tearing or pasting-back-together? The answer is of course 'yes' so then *How?*

# %% [markdown]
# ### Eulerian graphs
#
# If you are not familiar with graphs please see the Notebooks on this subject. The first is **1 G Graphs** and they
# continue from there. We use the terms *vertices* and *edges* here to extend the Konigsberg bridges problem.
#
#
# A *walk* through a graph begins at some vertex and ends at another; and it spells out the edges along
# the way. A *closed walk* ends back where it begins. For the Konigsberg bridges we wanted to know if
# we could cross each bridge once. This can be viewed as a graph problem where the four regions $A$, $B$, $C$ and $D$
# are represented as *vertices* and the bridges are *edges* connecting them.
#
#
# We can present any graph and ask the same problem: Is there a walk that crosses all the edges just once?
# We can make it more difficult by requiring that we wind up back where we started.
#
#
# <br>${\Huge \infty}$
#
#
# What is necessary for a connected graph to be Eulerian; in other words to have a closed walk that
# crosses along each edge once?
#
#
# **Solution** The solutions is given in the second **Topology** notebook along with a proof.
#
#
# **Hint** The solution is a rule for the degrees of the vertices. The degree of a vertex is simply how
# many edges connect to it. If your graph looks like a square then each vertex has degree $2$.
