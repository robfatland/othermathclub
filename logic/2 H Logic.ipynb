# %% [markdown]
# # Logic 2

# %%
# !curl https://raw.githubusercontent.com/robfatland/othermathclub/master/images/ocean/revelle.jpg -o /home/nbuser/revelle.jpg -s
from PIL import Image
Image.open("/home/nbuser/revelle.jpg").resize((850,500),Image.ANTIALIAS)
# Out:
# <PIL.Image.Image image mode=RGB size=850x500 at 0x7F259E1E1290>

# %% [markdown]
# Contenders
#
# - This is where prisoners with hats goes, to start with
#   - It goes up (even beyond) to 5 chairs and 6 hats.
#   - It raises the question: Is an arbitrary number of hats decidable?
#   - 'Decidable' itself ought to make an appearance here
#
# - After this let's return to Portia's caskets... and perhaps Bal and Da

# %%
import boto3
