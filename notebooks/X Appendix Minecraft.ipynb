# %% [markdown]
# # Minecraft
#
# ### Four challenges completed so far...

# %%
import kilroy
kilroy.Show('minecraft', 'seashell0002.png', 800, 420)
# Out:
# <PIL.Image.Image image mode=RGB size=800x420 at 0x7F98B47E3290>

# %% [markdown]
# *Rob says: I bet Rob cannot build a gigantic snail shell. This is a snail shell made of purple glass and gold,
# modeled after the shell of Sue the poisonous cone snail, mascot of the Other Math Club.*
#
# Keep scrolling down to see which challenges are completed.

# %%
kilroy.Show('minecraft', 'floating_water_stereo.png', 600, 270)
# Out:
# <PIL.Image.Image image mode=RGB size=600x270 at 0x7F989E136810>

# %% [markdown]
# *Challenge (Matt): Matt says: I challenge Rob to make one block of water in the middle of a 3x3 cube of air
# that lasts for 10 seconds. In the image above a single block of water floats in the air permanently.*
#
#
# Note: The double-image above is a stereo view. You can with practice seeing 'both' images at once (do not cross your
# eyes to do this) so that your brain interprets the result in three dimensions. It helps me to align the two stone pillars
# at right-center of the image.
#
# The code to do this looks like this... where '9' corresponds to 'still water'.
#
# ```
# from mcpi.minecraft import Minecraft
# mc = Minecraft.create()
# pos = mc.player.getPos()
# mc.setBlock(pos.x + 7, pos.y + 3, pos.z, 9)
#
# ```

# %%
kilroy.Show('minecraft', 'floating_sphere_stereo.png', 600, 230)
# Out:
# <PIL.Image.Image image mode=RGB size=600x230 at 0x7F989E136B50>

# %% [markdown]
# *Tristan says: 'I challenge Rob to make a perfect sphere.' Rob took this in the spirit of Minecraft blockiness.
# Furthermore he made the sphere shell very sparse so as to not crash the server with too many new blocks.
# This is another stereogram.*
#
#
# Here is the code that created the spherical shell shown above. I used blockType = diamond.
#
#
# ```
# def SparseSphereShell(mc, pos, radius, step, blockType):
#     minrad, maxrad, xc, yc, zc = radius - 1, radius, pos.x, pos.y, pos.z
#     for x in range(int(xc-radius-1), int(xc+radius+2), step):
#         for y in range(int(yc-radius-1), int(yc+radius+2), step):
#             for z in range(int(zc-radius-1), int(zc+radius+2), step):
#                 distance = np.sqrt((x-xc)*(x-xc)+(y-yc)*(y-yc)+(z-zc)*(z-zc))
#                 if distance > minrad and distance < maxrad:
#                     mc.setBlock(x, y, z, blockType)
# ```

# %%
kilroy.Show('minecraft', 'brick_universe.png', 300, 300)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F989E136F10>

# %% [markdown]
# *Aidan says: 'I challenge Rob to build a brick cube that spans across the whole entire world, from border to border (about 3 billion blocks by 3 billion blocks) is as tall as the build height.' Here you have it; and you can build it too. See below.*
#
# Here is the code. Unfortunately the resulting world is a bit dull. (Aidan also points out that the image is
# actually granite, not brick.)
#
# ```
# for i in range(-1500000000, 1500000001):
#     for j in range(0, 256):
#         for k in range(-1500000000, 1500000001):
#             mc.setBlock(i, j, k, 45)
# ```

# %% [markdown]
# <br>
# ${\Huge \infty}$
#
#
# If this code runs how many bricks would it create? How many disk drives would this fill if one brick requires 16 bytes
# of information and one disk drive can hold 4 terabytes of data? (One terabyte is one thousand billion bytes.)

# %% [markdown]
# ### Terms
#
#
# - **Python**: A computer programming language we use to create structures in Minecraft
#
#
# ### Hike
#
# If you have ever played the game Minecraft you probably realized that you can modify the world.
# It takes a lot of persistence if you want to create something big one brick at a time. Now Minecraft
# is a world of coordinates; and we can create and delete blocks in that world of many different types
# using a computer program. So we can build **big**.
#
#
# What we can create in Minecraft is no longer limited by size.
#
#
#
# ### Getting started
#
#
# - Get the book _Learn to Program With Minecraft_ by Craig Richardson
# (ISBN 9781593276706).
# - Go through Chapter 1 on setting up Minecraft and Python for your type of computer
#   - Purchase Minecraft and play it
#   - Install Python per the instructions. There are two popular versions: 2.7 and 3.5. I use 3.5.
#   - Install Java and Spigot as directed
#
#
# Start the IDLE editor and write some code. Run the code; and if everything works you will see changes in
# your Minecraft game that correspond to what your program did. Here is an example from the challenges above.
#
# ```
# from mcpi.minecraft import Minecraft
# mc = Minecraft.create()
# pos = mc.player.getPos()
# mc.setBlock(pos.x + 7, pos.y + 3, pos.z, 9)
#
# ```
