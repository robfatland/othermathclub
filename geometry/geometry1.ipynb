# %% [markdown]
# # ${\Large \infty}$ Geometry

# %%
import kilroy
kilroy.Show('minecraft', 'seashell0001.png', 1000, 500)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x500 at 0x7FB2F670D690>

# %% [markdown]
# This red and white minecraft structure was built by a Python program in a few seconds.
# It took much longer to write the program than it took for it to run.
#
#
# In two dimensions the triangle is a basic pointy shape and
# the circle is a basic curved shape. And a line is the perimeter of a circle
# whose center is infinitely far away.
#
#
# If a point has zero dimensions,
# a line one dimension, a plane two dimensions and a volume in space has three dimensions...
# might one continue onwards into four and
# five and six and one hundred dimensions?

# %%
kilroy.Show('geometry', 'construction_circle_background.png', 800, 400)
# Out:
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7FB30C0CCE10>

# %% [markdown]
# - Draw a circle and mark the center
# - Mark a point on the perimeter
# - Mark another point on the perimeter
# - Draw a line passing through these two points
# - Draw lines from these two points to the center of the circle

# %%
kilroy.Show('geometry', 'simple_construction.png', 300, 270)
# Out:
# <PIL.Image.Image image mode=RGB size=300x270 at 0x7FB30CD73A50>

# %% [markdown]
# Imagine you slide one of the two points along the perimeter of the circle towards the other one.
#
#
# - What becomes of the crescent?
# - When the two points meet is any part of the line still inside the circle?
#
#
# Even though pencil lines have some width we think of them as perfectly thin.

# %%
kilroy.Show('geometry', 'tetrahedra.png', 400,480)
# Out:
# <PIL.Image.Image image mode=RGB size=400x480 at 0x7FB2F6718110>

# %% [markdown]
# - Draw line A and point B not on A.
# - Make the compass *wider* than the shortest distance from B to A
# - Place the pivot point on B and mark two arcs on A. This gives two points on A: C and D
# - Place the pivot point on C and mark two arcs: One passing through B and one on the mirror side of A across from B
# - Do the same with the pivot point on D so the arcs cross in both places. One crossing is the point B and the other is the mirror point of B. Let's call it B'.

# %%
kilroy.Show('geometry', 'figure0_part1.png', 500, 400)
# Out:
# <PIL.Image.Image image mode=RGB size=500x400 at 0x7FB30CD8C690>

# %% [markdown]
# *Figure B in preparation: On the way to a line through B parallel to A*
#
# - Place the straight edge and draw a line through B and B' extending well beyond B
#   - **Claim**: This new line is perpendicular to A.
#   - Please write down why this is true. 'I'm not sure.' is a perfectly good answer in this case.
# - Place the compass pivot point at B and narrow the compass a bit
# - Mark arc points E and F on the line perpendicular to A
# - Extend the compass and place the pivot on E. Mark two arcs above and below B.
# - Do the same with the pivot point on F. The two E-arcs should cross the two F-arcs. Call these points G and H.

# %%
kilroy.Show('geometry', 'figure0_part3.png',500,400)
# Out:
# <PIL.Image.Image image mode=RGB size=500x400 at 0x7FB30CD8C110>

# %% [markdown]
# *Figure B almost complete*
#
# - Draw a line through G and H. It should also pass through B. Call it J. J is parallel to A and it passes through B.

# %%
kilroy.Show('geometry', 'figure0_part4.png',500,400)
# Out:
# <PIL.Image.Image image mode=RGB size=500x400 at 0x7FB2F66C1D10>

# %% [markdown]
# *Figure B completed, with line J parallel to line A*
#
#
# #### Hexagon
#
#
# - Draw a fairly large circle and be sure to not change your compass afterwards
# - Place the pivot point somewhere on the perimeter of the circle
# - Mark the perimeter of the circle twice with small arcs at a distance equal to the circle radius
# - Move the pivot point to one of these two marks
# - Again mark the perimeter of the circle at a distance equal to the circle radius
# - Continue in this way around the circle marking six points on the circumference
#   - Reflect: Why do six marks go around the circle exactly once?
# - Connect the six points on the perimeter with straight lines using the straight edge
# - The result should be a regular hexagon *inscribed* inside the circle

# %% [markdown]
# - Construct a larger hexagon circumscribed *outside* the circle; again touching at six points
#
#
# ### Angle and half-angle
#
#
# - Mark a point (I used the center of my circle) and draw two lines from it to create an angle
# - Set your compass to some distance and place the pivot point on your point
# - Draw two arcs that cross these two lines to mark two points
# - Place the pivot point on one of these two points and make an arc further out through the center of this angle
# - Place the pivot point on the other of these two points and make a second arc crossing the previous arc
# - The previous two arcs cross at one point. Draw a line from this point to your original point
#   - Why does this procedure *bisect* the angle (cut it in half)?

# %% [markdown]
# ##### Extra
#
#
# - Mathematically speaking how many angles are there in between the two sides of the angle you have drawn?
#
#
# ##### Perpendicular bisector
#
#
# The idea here repeats something we did in Figure B: Draw a line perpendicular to another line.
# Perpendicular means 'at right angles to'. We will draw a perpendicular to one of the six sides of
# the hexagon, cutting it in half. This is a *perpendicular bisector*.
#
#
# - Set your compass more than half the circle radius
# - Place the pivot point on one vertex (corner) of the hexagon and draw a circle
# - Place the pivot point at the next vertex of the hexagon and draw another circle
#   - These two circles should cross at two points
# - Using the straight edge draw a line through these two points
#   - This line should go through the center of the original circle and through the perimeter of that circle
# - Reflect: Why is this line perpendicular to the side of the hexagon?

# %% [markdown]
# ##### Tangent
#
#
# A tangent is something that just *barely* touches something else. The idea here is to draw a line
# that touches the original circle at only one point.
#
#
# - Draw a line radiating out from the center of the original circle through one of the vertices of the hexagon
#   - call this vertex $C$
# - Extend this line past the hexagon vertex by one circle radius. This will be the *radiating line* $R$
# - Set your compass to a little *less* than the circle radius
# - Place the pivot point on $C$
# - Draw two arcs that cross $R$: One near the circle center, the other opposite the first, so far from the center
#   - Let's call these points $X$ and $Y$
# - Extend the compass to about 1.5 times the circle radius
# - Place the pivot point on $X$ and draw a circle
# - Place the pivot point on $Y$ and draw a circle
# - These two circles cross at two points; so please use the straight edge to draw a line through them both
#   - This is the tangent line to the circle at $C$
#   - Reflect: Why does this line just barely graze the edge of your original circle?
#
#
# Compare your construction with Figure C below.

# %%
kilroy.Show('geometry', 'basic_constructions.png',800,560)
# Out:
# <PIL.Image.Image image mode=RGB size=800x560 at 0x7FB2F66C1850>

# %% [markdown]
# *Figure C completed*
#
#
# ### Figure D
#
#
# This is the most difficult yet! Why? Because there are no instructions on *how* to do this one.
#
#
# Figure D begins by drawing three points on a piece of paper. They should not be in a straight line.
#
#
# Now construct a circle that touches all three of these points. The result will be a triangle
# inscribed in a circle. Or we could say the result will be a circle circumscribed around a
# triangle.
#
#
# While it is easy to draw a circle and then select three points on that circle and make a triangle...
# it is more challenging to start with three points of a triangle and construct the circle that goes
# through all three of them.

# %% [markdown]
# ##### Extra
#
#
# - Draw a *circle* and then draw another circle that is *tangent* to it. They touch at one point.
# - Draw a third circle tangent to these first two circles
#
#
# ##### Repetitions
#
#
# For fun and/or practice you may wish to construct Figures B and/or C and/or D again.
#
#
# ##### Extra
#
#
# - How would you inscribe a circle inside a hexagon?
# - How would you divide a hexagon into six identical equilateral triangles?
# - How would you inscribe an equilateral triangle inside a circle?
# - How would you inscribe a square inside of a circle?
# - Create one or more new construction challenges for your fellow students
#
#
#
# <br><br><br>

# %% [markdown]
# ### Triangles
#
#
# This section does not involve constructions.
#
#
# There are four useful ideas about triangles we will use.
#
#
# #### First idea: Any side of a triangle may be considered as its *base*
#
#
# We are free to flip triangles around to change which of the three
# sides we call the base. On the diagram below the same triangle is show
# with each choice of base. The *height* of the triangle is shown relative
# to this base: From the corner opposite the base there is a dotted line
# that falls vertically to meet the base at a right angle. This is the *height*
# of the triangle. When the height does not touch the base: The base is
# extended outward along a line and the height then touches this line.

# %%
kilroy.Show('geometry', 'triangle_three_bases.png',600,200)
# Out:
# <PIL.Image.Image image mode=RGB size=600x200 at 0x7FB2F66C1C10>

# %% [markdown]
# *Figure E: Three drawings of the same triangle, using each side as the* base *with
# three corresponding versions of the* height
#
#
# Again: When the triangle *leans* to one side as in the center and right versions
# shown above in Figure E: The height is measured to a line extended from the base.
# The length of the base does not change in this case.
# The extending line is there so that the height can be drawn at right angles
# to (*perpendicular to*) the base.
#
#
# To reiterate: The height of a triangle is always placed at a right angle to
# (or *perpendicular to*) the base even if they do not meet.

# %% [markdown]
# #### Second idea: The hypotenuse side of a right triangle relates to the legs, the two shorter sides
#
#
# This is called the *Pythagorean theorem* or the *right triangle formula* or
# the *distance formula*. If the *hypotenuse* (the long side of the right triangle) is $c$
# and the other two sides -- the *legs* -- are $a$ and $b$ then
#
#
# $$a^2 + b^2 = c^2$$
#
#
# These letters $a$, $b$ and $c$ represent distances which are always positive or zero.
# Distances are not negative. This is in contrast to coordinates on the coordinate plane.
# We may say 'here is the x-axis, here is the y-axis, and this is a point at $(-2, +3)$
# so the $x$ coordinate is negative.' This is fine.  Coordinates may be positive or negative.
# However the lengths of the sides of triangles are considered *distances* and so they are
# *positive* numbers.
#
#
# We may use the distance formula to calculate one side of a right triangle when we know
# the other two. This formula uses the squares of $a$, $b$ and $c$; so here is an example
# of using the *square root* to arrive at a side length. (For more on square roots see
# the first page on **infinity**.)

# %%
kilroy.Show('geometry', 'right_triangle.png',400,230)
# Out:
# <PIL.Image.Image image mode=RGB size=400x230 at 0x7FB30CD8C210>

# %% [markdown]
# *A right triangle with one leg (a) and the hypotenuse (c) known; what is the other leg?*
#
#
# In the above figure we see one leg has a length of $a=5$ and the hypotenuse has a length of $c=13$. What is $b$?
#
#
# $$a^2+b^2=c^2$$
#
#
# $$5^2 + b^2=13^2$$
#
#
# $$25 + b^2=169$$
#
#
# $$b^2=144$$
#
#
# $$b=\sqrt{144}=12,\;not\;(-12)\;since\;b\;is\;a\;distance$$
#
#
# Now that we *have* the Pythagorean formula: How might we go about proving it is true? This question is
# addressed in the pages on **proof**.
#
#
# Solve for the missing side of the following right triangles
#
#
# - leg = 3, hypotenuse = 5
# - leg = 20, leg = 15
# - leg = 15, leg = 36
# - leg = 24, hypotenuse = 25
#
#
# **Extra** Prove or disprove that any odd number bigger than $1$ can be one leg of a right triangle
# with integer sides.

# %% [markdown]
# #### Third idea: The area of a triangle is equal to half the product of its base and its height
#
#
# This is the *area formula for triangles*. The area formula is true regardless of which side of the triangle
# is chosen as the base, from the **first idea** just above. It would be a pity if the area of a triangle
# changed depending on which side you chose as a base... because it is the same triangle.
#
#
# Write the area formula for triangles as an equation.
#
#
# **Solution**
#
#
# $$Area_{\;triangle} = \frac{1}{2}\;\cdot\;base\;\cdot\;height$$
#
#
# This formula is something that can be proven for all triangles and any choice of base; so let's do this
# in four steps.

# %% [markdown]
# - Make an argument that the area formula for triangles is true for a right triangle; given that the area of a rectangle with
# sides $q$ and $r$ is their product:
#
#
# $$Area_{\;rectangle}\;=\;q\;\times\;r$$
#
#
# - Make an argument that the area formula for triangles is true for a triangle whose height touches its base.
#   - Hint: Consider that the height is perpendicular to the base
#   - This triangle is shown for example as the left triangle of Figure D above
#
#
# - Make an argument that the area formula for triangles is true for a triangle whose height does not touch its base.
#   - No hint provided since this step is really fun and a hint would ruin the fun
#   - If you are puzzled by this step please discuss it with a partner
#     - If you discuss it during passing time between classes you may be late to class
#       - If you are late to class you may receive detention
#         - If you receive detention please note that you will have more time to work on this problem
#
#
# - Conclude your proof by pointing out that you have shown that the area formula for triangles is true for all possible triangles; and then draw a little box signifying 'the proof is now done'.
# I draw a box with a dot inside like this: $\boxdot$

# %% [markdown]
# #### Fourth idea: The sum of the three interior angles of any triangle is the same as the angle of a straight line
#
#
# What is 'the angle of a straight line'? Mark a point on a straight line. The line goes off
# in both directions. This makes a large angle that we can call 'the angle of a straight line'.
# If you learn angles using *degrees* this angle is $180$ degrees or $180^o$.
# If you learn angles using *radians* this angle is $\pi$ radians.
# (There is no little symbol for radians as far as I know.) You could make up your own angle units
# and call them *youzigberts* where perhaps the angle of a straight line is $17\;youzigberts$.
# The choice of units does not matter of course; it is always the same angle of a straight line.
#
#
#
# $$\angle{\;A} + \angle{\;B} + \angle{\;C} = \angle{(straight\;line)}=\pi\;radians=180^\circ=17\;youzigberts$$
#
#
# We go about proving this fourth idea on the next page of **geometry**.
#
#
#
# kilroy notes a figure would be appreciated here

# %% [markdown]
# **Extra** There are two particularly useful triangles that we will visit on the next page: The
# equilateral triangle and half-equilateral triangle. If you would like to jump ahead try solving
# for the sides and angles of the latter if the former has a side of $a$. We will tend to work in
# degrees for this.

# %% [markdown]
# ### Circles
#
# We have drawn some circles in the *construction* section and mentioned *tangents*. The *tangent* to a
# circle is a line that touches the circle at only one point. This section is a series of ideas about
# circles and tangents presented as questions. We return to these questions and some answers on the next page.
#
#
# In what follows the center of the circle is called point $O$ and tangent points are called $T$. A
# line between $O$ and $T$ has a length equal to the radius of the circle. This segment is called $OT$.
# Let's also say the radius of the circle is $r$.
#
#
# kilroy believes a diagram should go here

# %% [markdown]
# <br>${\Huge \infty}$
#
#
# For these questions you do *not* need to do constructions. Do so if you like but that is not the point.
# The point is the questions. You may certainly *sketch* or *imagine* as you like of course.
#
# - Suppose line $L$ is tangent to circle $C$ at point $T$.
#   - What is the angle made by $L$ and $OT$?
#
#
# - Given: Three points equally spaced on the perimeter of $C$.
#   - Draw tangents through all three; what is the resulting polygon?
#   - Can you calculate the area of this polygon?
#   - Can you break this polygon into three equal triangles by drawing line segments outward from $O$?
#
#
# - Given: Four points equally spaced on the perimeter of $C$.
#   - Draw tangents through all four; what is the resulting polygon?
#   - Can you calculate the area of this polygon?
#   - Can you break this polygon into four equal triangles by drawing line segments outward from $O$?
#
#
# - Given: Six points equally spaced on the perimeter of $C$.
#   - Draw tangents through all six; what is the resulting polygon?
#   - Can you calculate the area of this polygon?
#   - Can you break this polygon into six equal triangles by drawing line segments outward from $O$?
#
#
# - The above three polygons enclose the circle. (They are circumscribed about the circle.)
# All three polygons have areas.
#   - Which has the most?
#   - Which the least?
#   - Do any of them have an area less than the area of the circle?
#
#
#
# - Given: One thousand equally spaced points on the perimeter of $C$.
#   - Please do *not* actually do the drawing in the next step except in your imagination.
#   - Draw one thousand tangents; what is the resulting polygon?
#     - Answer: A one-thousand-gon. Can you think of a *better* name for it?
#
#
#
# - Given the trend above, from 3 to 4 to 6 to 1000 sides
#   - Reflect on how the area of the circle relates to circumscribed polygons.
#     - You may wish to refer to the number of sides abstractly as $n$
#
#
# - If we were able to create an infinite number of points on the perimeter of the circle...
#   - ...and could draw tangents through all of them...
#   - ... to make an ${\large \infty}$-gon...
#   - ... What would the difference be between the area of $C$ and the area of this ${\large \infty}$-gon?

# %% [markdown]
# ### Extra
#
#
# Construct a circle that touches all three corners of a randomly drawn triangle
#
#
# - Place three points randomly
# - Connect them in a triangle
# - Circumscribe a circle... somehow...
#
#
# Reflect: How do you imagine the figure at the top of the page was built from circles and triangles and time?

# %% [markdown]
# ### A problem about a point in a square
#
#
# This is from the competition math club. Specifically from **AMC 10a 2011 Problem # 25** courtesy of Tristan.
# The problem is challenging! I present it in its original language and then in a friendlier way.
#
#
# **Original version of the problem** Let $R$ be a square region and $n >= 4$ an integer. A point $X$ in the interior of $R$ is called n-ray partitional if there are rays emanating from $X$ that divide $R$ into $n$ triangles of equal area. How many points are 100-ray partitional but not 60-ray partitional?
#
#
# **Friendly version of the problem** Suppose you have a square (call it **R**) which is one unit on a side. We shall
# place it on the xy-plane because we will need a coordinate system for what follows. Let's choose the point $X\;=\;(1/2,\; 1/2)$
# which is in the center of the square; and let's draw four diagonals from $X$ to the four corners of the square.
#
#
# (kilroy image)
#
#
# What we have done here is we have cut the square into four triangles that all have the same area. This is called
# a *partition* of the square **R**. Notice that we drew four rays and this gave us four partitions. We'll call
# that a 4-partition. If we added four more lines out from $X$ to the centers of each side of the square we would
# have an 8-partition. We could continue in this way to make other partitions. We could also relocate $X$ from
# the center to somewhere else inside the square.
#
#
# Suppose you have some number $n$ that is 4 or larger: $n\;>=\;4$. A
# point $X$ is placed at some location inside the square (not necessarily at the center)
# in such a way that $n$ lines can be drawn outward from $X$ to the perimeter of the square
# to make an $n$-partition. That is, all $n$ triangles have the same area. $X$ is
# called *n-ray partitional*.
#
#
# Here at last is the question:
#
#
# How many 100-ray partitional points are *not* also 60-ray partitional points?
#
#
# **To make this more clear:** Take a point $X$ at (0.45, 0.62), inside the unit square.
# Suppose it is possible to draw $100$ lines from that point to the sides of the square that cut the
# square into triangles all with the same area. Then $X$ is a 100-ray partitional point.
#
#
# Now suppose that the same point $X$ is *not* 60-ray partitional. Then $X$ counts.
# On the other hand we *can* partition the square into 60 equal-area triangles:
# Then $X$ *is* 60-ray partitional. It does *not* count towards the answer.
#
#
# The problem is to count the number of such points inside the square.
#
#
# Whew!
#
#
# ### Solution
#
# My original solution was 56. But I made a mistake. Tristan solved it. I tried to follow his reasoning and
# in so doing I realized he was right and I had been in error. So I agree with his solution.
#
#
# Here is the start of a solution...
#
#
# Let's place the square $R$ at the origin in the first quadrant.
#
#
# Place $(x,\;y)=X$ within $R$.
#
#
# Draw rays from $X$ to the four corners dividing $R$ into four regions $A$, $B$, $C$ and $D$.
# Those rays must be part of the solution; otherwise we would include corners in our partition
# and those would not be triangles.
#
#
# Count $a$ rays from $X$ to evenly spaced points along the bottom of $R$ not including the final diagonal to $(1,\;0)$.
#
#
# Continue around counter-clockwise through regions $D$, $B$ and $C$ with ray counts $d$, $b$, $c$. Now if this
# is an $n$-ray partition then $a+b+c+d=n$. Furthermore all of the triangles must have the same area across
# those four edges of $R$.
#
#
# Assert: The location of the coordinate $y$ is independent of the location of $x$. Why?

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# methods for inversion work that follows

def angleC2C(ca, cb):
    if ca == cb: return 0.0
    dx = cb[0]-ca[0]
    dy = cb[1]-ca[1]
    return np.arctan2(dy, dx)

def lineC2C(someAxes, ca, cb, color):
    x0 = ca[0]
    x1 = cb[0]
    y0 = ca[1]
    y1 = cb[1]
    someAxes.plot([x0,x1],[y0,y1],color)
    return

def distanceC2C(ca, cb):
    if ca == cb: return 0.0
    dx = ca[0]-cb[0]
    dy = ca[1]-cb[1]
    return np.sqrt(dx*dx + dy*dy)

def distanceP2P(u, v):
    return np.sqrt((u[0]-v[0])*(u[0]-v[0])+(u[1]-v[1])*(u[1]-v[1]))

# invert a source circle sC through an inversion circle iC
# each circle is specified as a triple (x, y, r) where the center is at (x, y) and radius = r
#   these are accessed using tuple indices [0], [1], [2] respectively
def invertCircle(sC, iC):
    # this first part takes care of some non-typical situations
    if iC[2] <= 0.0: return (iC[0], ic[1], 0.0) # which is nonsensical; the inversion circle has no useful radius
    d = distanceC2C(iC, sC)
    r = iC[2]
    R = sC[2]
    if d == 0.: # the circles are concentric
        if R <= 0.0: return(iC[0], ic[1], 0.0) # nonsensical; the target circle has zero radius so blows up
        return (iC[0], ic[1], r*r/R)
    
    # Improvement: Check that the code works for all possible cases of sC and iC
    # For now: Proceeds for the 'typical' situation 
    # Along the radial line from iC to sC we cross the near and far edges of sC at (d-R) and (d+R)
    alpha = r*r/(d+R)        # distance from center of iC to inversion of (d+R)
    beta = r*r/(d-R)         # distance from center of iC to inversion of (d-R)
    Rprime = np.fabs((beta-alpha)/2.0)    # radius of the target circle
    gamma = np.fabs((alpha + beta)/2.0)    # distance from center of iC to center of target circle
    theta = angleC2C(iC, sC)
    x = iC[0] + gamma*np.cos(theta)
    y = iC[1] + gamma*np.sin(theta)
    return (x, y, Rprime)

# %%
# plt.subplots returns a tuple: A general-context figure and a list of sub-plots assigned to axes
fig, axes = plt.subplots(3, figsize=(10,30))
chartInversion = axes[0]
chartSymmetric = axes[1]    # I break the axes list apart into more identifiable names
chartEccentric = axes[2]
chartInversion.axis('equal')  # makes sure circles look like circles
chartSymmetric.axis('equal')
chartEccentric.axis('equal')

########
#
# Inversion chart section
#
########
# a circle is a tuple (x, y, r)
unit_circle = (0.0, 0.0, 1.0)
source_circle = (2.0, 0.0, 1.4)
chartInversion.set(xlim=(-1, 4), ylim=(-3,3))
chartInversion.set(xlabel='x axis', ylabel = 'y axis', title='inverting points on a circle produces a new circle')

cSrc = plt.Circle((source_circle[0], source_circle[1]), source_circle[2], color='blue', fill=False)
cInv = plt.Circle((unit_circle[0], unit_circle[1]), unit_circle[2], color='green', fill=False)
chartInversion.add_artist(cSrc)
chartInversion.add_artist(cInv)

# lines, remember, are given by a list of x coordinates, then a list of y coordinates
lineC2C(chartInversion, unit_circle, source_circle, 'r')

cInverse = invertCircle(source_circle, unit_circle)
cResult = plt.Circle((cInverse[0], cInverse[1]), cInverse[2], color='k', fill=False)
chartInversion.add_artist(cResult)

R = source_circle[2]
r = cInverse[2]
d = source_circle[0]
for i in range(36):
    theta = float(i)*2.0*np.pi/36.0
    xRel = R*np.cos(theta)
    yRel = R*np.sin(theta)
    s = np.sqrt((d+xRel)*(d+xRel)+yRel*yRel)
    sP = r*r/s
    alpha = np.arctan2(yRel,d+xRel)
    chartInversion.scatter([d+xRel], [yRel], color='g')
    chartInversion.scatter([sP*np.cos(alpha)], [sP*np.sin(alpha)], color='k')
    # uncomment the following line to see the connections between the points
    # chartSpare.plot([d+xRel,sP*np.cos(alpha)],[yRel,sP*np.sin(alpha)],'r')

chartInversion.annotate('source circle A', xy=(2.65, 1.25), xytext=(2.9, 1.6),arrowprops=dict(facecolor='black', shrink=0.01),)
chartInversion.annotate('inversion circle C', xy=(0.3, 0.95), xytext=(0.4, 1.4),arrowprops=dict(facecolor='black', shrink=0.01),)
chartInversion.annotate("inverted result A'", xy=(1.5, -0.55), xytext=(1.8, -1.05),arrowprops=dict(facecolor='black', shrink=0.01),)
chartInversion.annotate('evenly spaced green dots invert to (uneven) black dots', xy=(0.,0.), xytext=(-.3, -1.6),)


# Symmetric chart section
chartSymmetric.set(xlim=(-3, 7), ylim=(-5,5))  # Another way: ax.set_xlim(-7, 7)
chartSymmetric.set(title='symmetric')

thetaStart = 0.7
nCircles = 7
rSmall = 1.0
alpha = (2.0*np.pi) / (2.0*float(nCircles))
rOrbit = np.sin(alpha)*rSmall/(1.0-np.sin(alpha))
rLarge = rSmall + 2*rOrbit
cSmall = plt.Circle((0.0,0.0), rSmall, color='blue', fill=False)
chartSymmetric.add_artist(cSmall)
cLarge = plt.Circle((0.0,0.0), rLarge, color='red', fill=False)
chartSymmetric.add_artist(cLarge)
for i in range(nCircles):
    theta = thetaStart + 2.0 * alpha * float(i)
    xC = (rSmall + rOrbit)*np.cos(theta)
    yC = (rSmall + rOrbit)*np.sin(theta)
    cOrb = plt.Circle((xC, yC), rOrbit, color='black', fill=False)
    chartSymmetric.add_artist(cOrb)

# left off here fixing the inversion circle in the symmetric pane    
inverter = (5, 0, 2)
cInverter = plt.Circle((inverter[0],inverter[1]), inverter[2], color='green', fill=False)
chartSymmetric.add_artist(cInverter)

    
# Eccentric chart section
chartEccentric.set(xlim=(3, 5), ylim=(-1,1))
chartEccentric.set(title='eccentric')

# Repeat the drawing of the inversion circle
cIInv = plt.Circle((inverter[0],inverter[1]), inverter[2], color='green', fill=False)
chartEccentric.add_artist(cIInv)

cISmall = invertCircle((0.0,0.0,rSmall), inverter)
cILarge = invertCircle((0.0,0.0,rLarge), inverter)

cIS = plt.Circle((cISmall[0],cISmall[1]), cISmall[2], color='blue', fill=False)
chartEccentric.add_artist(cIS)
cIL = plt.Circle((cILarge[0],cILarge[1]), cILarge[2], color='red', fill=False)
chartEccentric.add_artist(cIL)

for i in range(nCircles):
    theta = thetaStart + 2.0 * alpha * float(i)
    xC = (rSmall + rOrbit)*np.cos(theta)
    yC = (rSmall + rOrbit)*np.sin(theta)
    cInvOrb = invertCircle((xC,yC,rOrbit),inverter)
    cOrb = plt.Circle((cInvOrb[0], cInvOrb[1]), cInvOrb[2], color='black', fill=False)
    chartEccentric.add_artist(cOrb)

# fig.savefig('plotcircles.png')
