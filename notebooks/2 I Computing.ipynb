# %% [markdown]
# # ${\Large \infty}$ Computing 2

# %%
# !curl https://raw.githubusercontent.com/robfatland/othermathclub/master/images/minecraft/gold_and_glass.png -o /home/nbuser/gold_and_glass.png -s
from PIL import Image
Image.open("/home/nbuser/gold_and_glass.png").resize((800,450),Image.ANTIALIAS)
# Out:
# <PIL.Image.Image image mode=RGB size=800x450 at 0x7F28C4D27B10>

# %% [markdown]
# *sculpture in gold and glass (Minecraft)*
#
#
# ### Friendly introduction
#
# To remind you: This is the subject of *computing* and it has three parts: automata, figure drawing and fractals.
#
#
# *Automata* is plural -- the singular is *automaton* -- and we have already seen what these creatures can do
# on the surface of a torus on the **topology** track. If you haven't read along there I will tell you a short
# summary to save you some time.
#
#
# Orbiting a distant star is a planet shaped like a donut called WaTor. A donut shape is also called a *torus*
# and the surface of the planet is covered by water two feet deep everywhere... so it is a kind of poor joke to call
# the planet WaTor...
#
# Anyway there are two kinds of creatures living on WaTor that we call sharks and fishes. The fishes eat
# plankton and the sharks... well you can guess what the sharks eat. It isn't plankton. We will put in place
# the rules for both fish automata and shark automata and see what happens over time.
#
#
# Figure drawing means using a computer to produce interesting charts and graphs and drawings. At the top
# of this page is a frame from Minecraft where
