# %% [markdown]
# * Unsolved chapter 1: 1.14, 1.20, 1.21, 1.22, 1.23, 1.24, 1.27, 1.28, 1.29.
# * Unsolved chapter 2: 2.5, 2.6, 2.8, 2.9, 2.12, 2.13, 2.15, 2.16, 2.17, 2.18, 2.19,
# 2.21, 2.22, 2.23, 2.24, 2.26, 2.27, 2.28, 2.29, 2.30, 2.31, 2.32, 2.33, 2.34, 2.35,
# 2.38, 2.39

# %% [markdown]
# # Apostol: Introduction to Analytic Number Theory
#
#
# ### On the unreasonable effectiveness of asking for help
#
#
# > Apocryphal story:
# A student of rock climbing was led by his instructor to a rock
# formation. 'Here is your problem: Climb
# to the top' the instructor said, pointing to a vertical cliff.
# Whereupon (the instructor departing)
# the student examined the cliff, finding it to be vertical, smooth
# and featureless, with not so much as a tiny handhold.
# The student sat upon the ground, staring at the cliff.
# A year later he returned to his instructor.
# 'I have not solved the problem yet' he reported.
# His instructor responded, 'Oh I assumed you had died.'
#
#
# This essay concerns independent study, specifically
# number theory as presented in Tom Apostol's
# _Introduction to Analytic Number Theory_.
#
#
# I had the privilege of attending Professor Apostol's
# lectures in person in 1983.
# My fellow classmates and I (spanning decades)
# affectionately referred to Tom Apostol *and* to his calculus
# textbooks both as '*Tommy*'.
# I can still see him in my mind's eye: He stands before I multi-panel
# blackboard in a Noyes Laboratory lecture hall, making an impossible claim,
# followed by a pause, followed by the portentous remark
# "Nobody can stop me from *making* this claim..." A chain of logic
# would follow, eventually proving the impossible claim to be true.
# To be sure, my enlightenment usually required additional staring
# at my notes thereafter. I would describe Tommy
# as a lecturer in one word as *inexorable*.
#
#
# This was a two-year course in introductory calculus.
#
#
#
# So how to characterize number theory, this
# mathematical landscape I hope to explore?
# The starting point of number theory is grade-school stuff:
# integers, arithmetic, divisibility; so far so good.
# From here matters accelerate rapidly. The narrative introduces
# new functions --
# *peculiar* functions like $\mu$ and $\Lambda$ that are
# defined only on positive
# integers. The positive integers in turn are categorized as being
# prime numbers, or as being composite numbers, or as being neither,
# which is to say being the number $one$. Portentous indeed.
# Proofs abound from the outset; and these often feature
# multiplication of some expression
# by a second expression that leaves it unchanged; that second
# expression being in some manner equal to that particular
# number $one$. While the local version of $one$
# may include parameters unknown, nevertheless by an early
# proof $one$ is known to exist. As ever the reasoning is
# nothing short of *inexorable*. The narrative continues
# at high speed, with parenthetical allusions to abelian groups
# and incomprehensible re-definitions of derivatives;
# and so on reformulating the familiar in strange new ways.
# But never the faintest hint of a simple harmonic oscillator;
# the mathematics is its own jet fuel.
# So **Introduction to Analytic Number Theory** begins,
# from the outset at once familiar and deeply puzzling.
# I wonder: Will number theory prove interesting in its continuation?
# Will it inspire?
# My historical conclusion was a resounding
# 'No, thanks ever so much!' That was the historical view;
# but now, in these modern times (to channel Tommy):
# Nobody can prevent me from *claiming* that number theory is
# beyond fascinating... After all I am writing this now,
# so I must have reason to be suspicious of
# my earlier conclusion.
#
#
# Recalling that epoch, some historical remarks:
# For many of us who passed through middle school and
# high school in the 1970s
# the best thing in the world was a window into a kind of
# mathematics that could not be found in textbooks.
# This window was delivered in monthly installments,
# courtesy of a mysterious, venerable figure named Martin Gardner.
# His 'Mathematical Games' column in Scientific American was
# nothing less than a miracle. It was not merely a static
# window, you understand.
# It was a window we could
# *open and climb through* (perhaps it was a looking glass
# that dissolved into mist) letting us into a world
# where original ideas not only mattered, but mattered in proportion to
# how strange and unfamiliar they were. Each new installment of
# Mathematical Games delivered two things. First, the subject matter would be
# in some way related to mathematics; and second the narrative would start
# in familiar territory and rapidly veer off
# into *ideas new and unexpected*.
# Gardner introduced us to myriads
# of logical puzzles, to paradoxes, to fractals,
# to the emergent exploratory power of the tireless computer,
# forays into geometry, ... and on and on. But in view of all
# of this remarkable
# treasure I could never fathom why Martin Gardner would
# now and again write about ordinary, pedestrian integers,
# and so so with
# considerable genuine enthusiasm. This was a
# paradox of a different sort: Martin Gardner came from
# a universe of interesting new ideas; but was pausing
# to touch upon arithmetic. A young person of that era
# might impatiently skip ahead at this point.
#
#
# Here we are, as it were, 'several days later' and as I say my
# view of this 'arithmetic' has brightened considerably. Number
# theory is interesting because it is *difficult*. My supporting
# evidence is baked into the pudding, the solutions given below.
# The commentary I provide in the notes thereby tries to capture
# the transitions, generally one per problem, from blank staring
# incomprehension to problem solved. This raises a touchy subject,
# the question of when it is appropriate to look at someone else's
# solution. Here the tractability of many calculus problems may
# have made us impatient.
#
#
#
#
#
#
#
# Professor Apostol paid his students the
# highest compliment in an interview he gave in 1997
# (Donald J. Albers (1997) An Interview with Tom Apostol, The College
# Mathematics Journal, 28:4, 250-270, DOI: 10.1080/07468342.1997.11973873).
# The interview is a worthwhile read and I feel it reinforces Martin
# Gardner's contention that there is something out there we can touch, given
# enough persistence and an adequate supply of pencils, scratch paper
# and staedtlers.
#
#
# "If anything has kept me at Caltech all these years, it has been the
# quality of the undergraduate student body." -Tom Apostol
#
#
# On starting to work through the book I found I
# understood theorems and proofs on the 'in the moment' sense;
# but internalizing them proved challenging.
# This is also touched on in the interview I mentioned above.
# This feeling that my comprehension is not quite there
# became more evident as I tried to work chapter one
# exercises with very little progress.
# Casting about about for guidance on the web I cam across
# solution sets published by both Sean Li and Greg Hurst.
# These proved extremely helpful; and as a consequence the solutions I'm
# writing here are frequently those of Messrs. Li and Hurst
# simply filtered through my interpretive lens. My versions
# sacrifice a great deal of their brevity for the sake of
# exposition.
#
#
#
# Thanks Sean and Greg.
#
#
# Thanks Tommy.

# %% [markdown]
# ## Solution style elements
#
#
# More than anything the key element to progress learning this material
# is time and patience (plus cash to buy scratch paper). In the sense of
# accumulating tools, the plan is to pick them up and internalize them
# in passing. I will give two examples; and for the record many many
# others can be found in Aigner and Ziegler's
# excellent **Proofs From The Book**.
#
#
# Example: It can be useful to 'multiply something by one'; and
# $c \cdot 1$ is fine as far as it goes. But your professional
# number theorist will take a given
# $(a, b) = 1$ and proceed to $c = c \cdot (ax + by)$
# for some $x$ and $y$.
#
#
# Example: $\alpha^n-1$ may suggest a factorization that uses the
# $- \; 1$ to telescope a product back to an original form.
# Your professional
# number theorist will go further, taking $\alpha^n + 1$ as an
# invitation to create a factorization that uses alternating
# signs $+ \; - \; + \; - \; \dots - \; +$ to collapse the telescope.
# (See problems **1.16** and **1.17**.)
#
#
# In computer programming there is a notion of *code golf* where a given
# piece of code is shortened as much as possible. *Solution golf* is a
# temptation in writing up answers to problems here. The result can be
# text that is tedious to parse. A dedicated mathematician might say
# this is the whole point: Stare at it until it comes into focus. I'm
# coming down on the softer side of that. Solutions expanded into a
# more conversational narrative might make the 'how' more accessible.
#
#
# On method: I've noticed *ducking the wave* is tempting for some
# problems. An intended elegant solution
# (see *hints*, for example) can be avoided through pedestrian means;
# drudgery, solving for a set of cases that span $Z$
# and so on. I often start working a problem by working
# examples; and resulting patterns can
# suggest *mechanical* solutions that duck the wave.
# Problem 2.5 is an example.
#
#
# On proofs: Nobody is checking my homework; so my idea of adequate
# proof in a proof is, I admit, vague at best. Nevertheless I venture an
# 'end of proof'
# symbol when I run out of things to say. The letters QED have
# given way typographically to 'tombstones', boxes that indicate
# the proof is complete.
# Various tombstones are available via Unicode. For example
# the filled tombstone: &#x220e; the outline: &#x1f78e;
# a large thin-line square: &#x2b1c; a medium square: &#x25fb;
# and what I will use, a heavier-line square: &#x2610;.
# The adequacy of what comes before is to be judged by someone else, not me.

# %% [markdown]
# ## Introduction to Analytic Number Theory Chapter 1
#
#
# ### Useful ideas:
#
#
# * 'a divides b' can be written as 'multiplication by some number':
# $a | b \implies b = a \cdot q$. I substitute this implied expression freely.
#
#
# * A second common substitution from the *gcd* of $a$ and $b$:
# $(a, b) = c \implies \exists \; x \textrm{ and } y \backepsilon c = xa + yb$.
# This means that $x$ and $y$ exist; not that *any* $x$ and/or $y$ suffice.
# As an intermezzo: There are two
# important qualifiers for any $x$ and $y$, i.e. for an
# arbitrary linear combination of $a$ and $b$.
#     * A linear combination $x \cdot a + y \cdot b$ can never be a positive
# common factor of $a$ and $b$ *less than* $(a, b)$.
#     * An arbitrary linear combination $xa + yb$ will
# always be a *multiple* of $(a, b)$.<BR><BR>
#
# In a sense, $c=(a,b)$ replaces $1$ with a new atomic unit $c$ that re-scales
# the number line. This atomic nature of the gcd is apparent in un-solvable gallon
# puzzles. For example,  'You have two containers with capacities four gallons
# and six gallons. The horses need precisely five gallons of water.' We may as
# well just give the horses six gallons of water and endure their
# disapprobation.
#
#
# * The linear combination for a gcd $c$ means that
# $x$ and $y$ exist and thus $ax + by$ can be substituted for $c$.
#
# * Corollary: The linear combination that yields $c$ is
# not unique. Suppose $x$ and $y$ are established definite
# values that yield $c$. There are any number of other pairs for
# $x$ and $y$ that yield this same gcd. Take for example $a=15$
# and $b=24$. Then $c=3=15\cdot(-3)+24\cdot(2)$. So $x=-3$ and
# $y=2$ give $c=3$. For any $n$ we have $n(8a-5b)=0$ so to generalize
# we have $x=-3+8n$ and $y=2-5n$ for any choice of $n$ will give $c=3$.
#
#
# For more on this gcd thought process see the remark in problem 1.2.
#
#
# Finally a remark on the obvious, one of many to follow. If $a | b$ and $a | (b + c)$
# then $a | c$. Makes sense. But check out how this is used in problem 1.18 where
# $c$ is prime (in this case $2$) and $a$ is the gcd of two numbers. This gives us
# the logical result that $a$ must be $1$ or $c$. I'm not sure this sort of thing
# is *obvious* obvious until it is introduced a bit.
#
#
# The **`examples`** notebook has some code for working through actual cases.

# %% [markdown]
# #### Problems 1--6: 'Prove the statements'

# %% [markdown]
# #### 1.1 Show: If $(a, b) = 1$ and $c|a$ and $d|b$ then $(c, d) = 1$.
#
#
# $a=cq$ and $b=dr$. Hence $1=ax+by=cqx+dry=(qx)c + (ry)d$ so $(c, d)=1.\;\;$ &#x2610;
#
#
# This argument uses the 'one and only one' nature of the gcd (see Theorem 1.3).
# How are the following statements related?
# Statement 1: There is a linear combination of $c$ and $d$ equal to $1$.
# Statement 2: $1$ must be the gcd of $c$ and $d$. More on this below.
#
#
# Sean Li solves this as a proof by contradiction: $(c, d) > 1$ is testable.
#
#
# > Assume that for some $n>1$ we have $(c, d) = n$.
# $a = c \cdot q = u \cdot n \cdot q$ and likewise $b = v \cdot n \cdot r$
# giving the contradiction that $n>1$ divides both $a$ and $b$.

# %% [markdown]
# #### 1.2 Show: If $(a,b) = (a,c) = 1$ then $(a, bc) = 1$.
#
# The inspiration here is to show that integers $q$ and $r$ exist where
# $a \cdot q + bc \cdot r = 1$. There is therefore no no *larger* value available
# to be the gcd of $a$ and $bc$. I return to this *exlusivity* after the arithmetic.
#
#
# $(a,b)=(a,c)=1 \implies 1 \cdot 1=(ax+by)\cdot(au+cv)$ for some $x, y, u, v$.
#
#
# Expanding: $1=a(aux+cvx+buy)+bc(yv)$. Let $q=(aux+cvx+buy)$ and $r=yv$..
# Then $aq + (bc)r = 1$ so $(a, bc) = 1$. &#x2610;
#
#
#
# ##### Intermezzo on divisors and greatest common divisors
#
#
# Two ideas here. First we have the idea of divisors of two numbers; for example 3 is a
# divisor of both 12 and 30. Second we have the idea that there is a largest element in
# the set of common divisors. For 12 and 30 that is 6.
#
#
# Theorem 1.2 states that a common divisor of $a$ and $b$ exists and can be
# expressed as a linear combination of $a$ and $b$: $gcd = ax + by$. So far so good.
# This is a building block idea: Both $a$ and $b$ are constructed of
# common divisor blocks in some quantity.
#
# It is when we compare $a$ and $b$ that we are forced into using the gcd
# building blocks. We can then take integer
# multiples of both $a$ and $b$, extending out until they differ by just one
# gcd block. Can't get differences any smaller than that. Differences that
# are multiples of the gcd are fine.
#
#
# A mistake to make: 'Any arbitrary linear combination of $a$ and $b$
# is a divisor of $a$ and $b$.' Take $(3, 7) = 1$ for example: $3\cdot3 + (-1)\cdot7=2$
# which is not a common divisor of $3$ and $7$.
#
#
# A correction of that mistake: 'Any arbitrary linear combination of $a$ and $b$
# is a multiple of the gcd of $a$ and $b$.'
#
#
# Getting a linear combination of $a$ and $b$ to equal an inferior common divisor
# can't be done because $a$
# and $b$ are always separated by some multiple of the gcd.
#
#
#
# Result: The gcd of $a$ and $b$ can be expressed as a linear combination of $a$
# and $b$; or some *multiple* of the gcd can be expressed this way; but nothing
# else. Let's take $a=18$ and $b=30$ with a gcd of 6. The linear combination
# $4\cdot a-2 \cdot b=72-60=12=2\cdot6$ is twice the gcd.
#
#
# A more general take on productiong *multiples* of the
# gcd: Multiply the gcd-specific "x and y"
# linear combination by any factor.
#
#
# $a=2 \cdot 3 \cdot 11$ and $b=2 \cdot 5 \cdot 7$.
#
#
# $(66, 70) = 2 = 66 \cdot x + 70 \cdot y$. Values for $x$ and $y$ that
# produce the gcd are $x=-18$ and $y=17$.
#
#
# Multiply the gcd expression by $3$ to arrive at a new linear combination of
# $a$ and $b$ equal to $6$, three times the gcd. This $6$ is not a common divisor
# of $66$ and $70$ but it *is* a linear combination that is less than both of them.
#
#
# This gives me a better handle on linear combinations in relation to
# *gcd*s.
#
#
# Additional observation:
# Suppose $(a, b) = d$; then the $x$ and $y$ values in
# $ax + by = d$ are not unique. They can be modified for example using a
# free parameter $n$:
#
#
# $$ax + by + nab - nab = d$$
#
#
# $$a(x + nb) + b(y - na) = d$$
#
#
# So there is
# an infinite range of workable $\{x, y\}$ pairs. This is used in
# problem 1.25.
#
#
# Additional observation: Any linear combination of $a$ and $b$ will be a multiple of $(a, b)$.
# so $(a,b)|(ax+by)$ for any $x$ and any $y$.
#
#
# Additional observation: 'How do I solve for $(a, b)$? Suppose I take a linear combination
# of $a$ and $b$ and arrive at some number $q$ less than both $a$ and $b$. Then I come up with
# another number $r$ less than $q$ from a different linear combination. This keeps lowering
# the upper bound on the gcd: Now it is $r$. And if $q$ is not a multiple of $r$ then they
# have some common divisor that is smaller still that would be the new upper bound. If this
# gcd of $q$ and $r$ happens to be $1$ then $a$ and $b$ are relatively prime.

# %% [markdown]
# #### 1.3 If $(a, b) = 1$ then $(a^n,b^k)=1$ for all $n \ge 1, \; k \ge 1$.
#
# Suppose $(a^n, b^k) > 1$. Then $\exists \textrm{ some } p
# \backepsilon p|a^n \textrm{ and }
# p|b^k$. This $p$ must therefore divide both $a$ and $b$, reaching a
# contradiction of the given that $(a, b) = 1.\;\;$ &#x2610;

# %% [markdown]
# #### 1.4 If $(a, b) = 1$ then $(a+b, a-b)$ is either $1$ or $2$.
#
# Since $1$ is the least of gcd values, and since I can provide
# an example with $a=10 \textrm{ and } b=7 \textrm{ where }(17,3)=1$:
# The value of $(a+b, a-b)$ can be 1. Similarly it might be $2$ by
# example, say $a=9 \textrm{ and } b=7$. Can $(a+b,a-b)$ be some $c>2$?
#
# If so: $a+b=c \alpha \textrm{ and } a-b=c \beta$.
# Their sum gives $2a=c(\alpha + \beta)$. That is,
# $c | 2a$. However $c \nmid a$ as if it did $c$ would also divide $b$
# since $c | (a + b)$. Also $c > 2 \textrm{ so } c \nmid 2$,
# a contradiction. Also excluded is the possibility that
# $\alpha = - \beta$ as this would imply $a=0$ and $(0, b) = |b|$.
# But again we have it from a reliable source that $(a, b) = 1$
# so $b=1$ and we have $(0 + 1, 0 - 1) = 1$.
#
#
# This excludes $c > 2$ and we are left with $(a + b, a - b) = 1 \textrm{ or } 2.\;\;$ &#x2610;

# %% [markdown]
# #### 1.5 Show that if $(a,b)=1$ then $(a+b, a^2-ab+b^2)$ is either $1$ or $3$.
#
#
# As in **1.4**: Suppose $(a+b, a^2-ab+b^2) = c$. $c = 1$ is the floor value; is it also
# demonstrable? Take $a=4 \textrm{ and }b=3: \; (7,13)=1$, so yes. How about $c=3$?
# Take $a=5 \textrm{ and } b=7 \textrm{: This results in }(12, 39)=3$. So both $c=1$ and $c=3$
# are possible gcd values. Are other gcd values possible? Let's suppose
# so for some $c > 1$. $c$ does not divide one of $a$ or $b$ since it would then divide
# the other (as it divides $a+b$) which would violate $(a,b)=1$.
#
#
# We write $'(a+b, a^2-ab+b^2) = c' \textrm{ as }a+b=c \alpha \textrm{ and }a^2-ab+b^2 = c \beta$.
# Squaring the first and subtracting the second gives $3ab=c(c \alpha^2 - \beta)$. In other words
# $3ab = c \gamma$, presuming $c > 1$.
#
#
# Let $p$ be ***any*** prime factor of $c$. Can this $p$ divide either $a$ or $b$?
# Suppose $p|a$.
# Because $c | (a+b)$ it is also the case that
# $p | (a+b)$. If $p|(a+b) \textrm{ and } p|a \textrm{ then } p|b \textrm{; but this
# violates }(a,b)=1$. Consequently $p \nmid a$ and by the same argument $p \nmid b$.
# Therefore $p=3$ is the only possibility and $c=p=3$ is
# the only alternative to $c=1.\;\;$ &#x2610;
#
#
# The same rationale used in the previous problem applies to setting $\gamma = 0$ where
# the end result is a gcd of $1$.
#
#
# I think the crux here is the transition from a hypothetical gcd $c$ to *any* of its prime
# factors in the reasoning. Not as successful: Thinking in terms of *some* single prime factor
# of $c$, call it $p$. This is muddier because it does not yield the clear implication
# that $c \nmid ab$.

# %% [markdown]
# #### 1.6 Show that if $(a, b)=1$ and $d|(a+b)$ then $(d,a)=(d,b)=1$.
#
# Set $(d,a)=c$. Then $d = c \alpha \textrm{ and } a = c \beta$.
# As $d|(a + b)$ it is also the case that $c | (a + b): \; c \gamma = a + b = c \beta + b.$
# Hence $b = c(\gamma - \beta) \textrm { meaning that } c|b$. So $c$, the gcd of $a$ and $d$,
# divides both $a$ and $b$.
# This means $(a, b) \ge c$ but we are given that $(a, b) = 1$ so $c = 1 = (d, a)$.
#
#
# As there is nothing special about starting with $(d, a)$ we can use the
# same argument to arrive at $(d, b) = 1.\;\;$ &#x2610;

# %% [markdown]
# > There is a thematic connection through problems 1.7, 1.13, 1.25, 1.26
#
#
# #### 1.7 If the sum of two reduced fractions is an integer, say $a/b + c/d = n$ where $(a,b)=(c,d)=1$, show that $|b|=|d|$.
#
# $n = \frac{ad + bc}{bd} \implies bdn = ad + bc \implies \textrm{ both } b|(ad+bc)$ and $d|(ad+bc)$.
#
#
# Now consider that $b$ divides a sum *and* it divides the second term $bc$.
# Therefore it must divide the first term as well, $ad$. So $b|ad$ but $(a, b) = 1$
# so $b|d$. By the same reasoning $d|b$ so we have $|b|=|d|.\;\;$ &#x2610;
#
#
# As noted this facilitates problem 1.13.

# %% [markdown]
# #### 1.8 A number is *square-free* if it is not divisible by the square of any prime. Prove that for every $n \ge 1$ there exist unique $a > 0$ and $b > 0$ such that $n = a^2 b$ with b *square-free*.
#
# The numbers $a$ and $b$ can be built by a decomposition of each
# $\alpha_{i}$ prime exponent of $n$ as
# $2 \cdot \lfloor {\alpha_i/2} \rfloor + \alpha_{i} \; mod \; 2$.
# We then have $a=\prod p_i^{\lfloor {\alpha_i/2} \rfloor} \textrm{ and }
# b=\prod p_i^{\alpha_{i} \; mod \; 2}$ so that $n=a^2b.\;\;$ &#x2610;
#
#
# To demonstrate this factorization is unique frankly I'd just
# cite the FTA. I suppose we could also say that any migration
# of a prime factors from $b$ to $a^2$ is impossible since $b$
# is squarefree; and likewise in the other direction.

# %% [markdown]
# #### 1.9 a) Show or give a counterexample: If $b^{2}|n$ and $a^{2}|n$ and $a^2 \le b^2$ then $a | b$.
#
# For $n = 36, a = 2, b = 3$ the conditions are met but $ 2 \nmid 3, \; \otimes$.
#
# #### 1.9 b) Likewise: If $b^2$ is the largest square divisor of $n$, then $a^2 | n$ implies $a | b$.
#
# True by decomposition: As in **1.8** we can manufacture $b$ from the prime factorization of $n$:
# $b = \prod {p_i}^{\lfloor \alpha_i / 2 \rfloor}$. As $a|n$ we have a factorization of $a$ that
# involves the same or fewer of the factors of $b$ so $a | b$.
#
#
# Proofs like this one proofs live somewhere in the grey area between *proof by it's obvious* and
# *proof by assertion*. Greg Hurst does a much better job being rigorous.

# %% [markdown]
# #### 1.10 Given $x$ and $y$, let $m = ax + by$ and $n = cx + dy$ where $ad - bc = \pm 1$. Prove $(m, n) = (x, y)$.
#
#
# Part 1: Looking ahead we need a general
# result, taking $q, r, s > 0$ to avoid absolute value clutter:
# If $q|r$ and $q|s$ then $q |(r, s)$. This is easy to
# show: $q|r \implies r = q \alpha$ and likewise $s = q \beta$.
# Then $(r, s) = (q \alpha, q \beta) = q (\alpha, \beta)$ from theorem 1.3c;
# so $q|(r,s)$.
#
#
# Part 2:
# The condition imposed on
# $a, b, c, \textrm{and} \; d$
# suggests the determinant of a 2D linear transform.
# From linear algebra: The inverse of a $2 \times 2$ matrix
# $
# A=\left[{\begin{array}{cc}
#    a & b \\
#    c & d \\
#   \end{array}}\right]
# \; \; \; $
# is
# $\; \; \; A^{-1} = \frac{1}{det A} \cdot \left[{\begin{array}{cc}
#    d & -b \\
#    -c & a \\
#   \end{array} }\right]$ with $det A = ad - bc$.
#
#
# Writing $x$ and $y$ as a column vector
# $\tilde{v}=\left[{\begin{array}{c}x\\y\end{array}}\right]$
# and the result of the transform as
# $\tilde{k}=\left[{\begin{array}{c}m\\n\end{array}}\right]$
# we have $A \tilde{v} = \tilde{k}$ and $\tilde{v}=A^{-1}\tilde{k}$.
#
# $\left[{\begin{array}{c}x\\y\end{array}}\right] =
# \frac{1}{det A} \cdot \left[{\begin{array}{cc}
#    d & -b \\
#    -c & a \\
#   \end{array} }\right]
# \left[{\begin{array}{c}m\\n\end{array}}\right] =
# \pm 1 \cdot \left[{\begin{array}{cc}
#    d & -b \\
#    -c & a \\
#   \end{array} }\right]
# \left[{\begin{array}{c}m\\n\end{array}}\right]
# $
#
# In rude mechanical terms
# $x = \pm (md-nb) \textrm{ and } y = \pm (na-mc)$.
# However we do not need to write this out as such.
# Rather say:
# $x$ and $y$ are linear combinations of $m$ and $n$
# so $(m, n)|x$ and $(m, n)|y$. This in turn (from part 1)
# means that $(m, n)|(x, y)$.
#
# In the problem statement we see $m$ and $n$ are linear combinations
# of $x$ and $y$. By the same argument then $(x, y)|(m, n)$.
# As $(x, y)|(m, n)$ and $(m, n)|(x,y)$ the two are equal,
# $(m, n)=(x,y).\;\;$ &#x2610;

# %% [markdown]
# #### 1.11 Prove $n^{4}+4$ is composite for $n > 1$.
#
#
# An approach would be to factor this expression, for example: $n^{4}+4 = (n^2+an+2)(n^2+bn+2)$.
# Happily this works out using $a=2$ and $b=-2$. Both resulting factors are positive
# for all values of $n > 1.\;\;$ &#x2610;

# %% [markdown]
# ***In 12, 13 and 14 we have $a, b, c, m, n$ denoting positive integers.***

# %% [markdown]
# #### 1.12 a) Prove or provide a counterexample: $a^n | b^n \implies a | b$
#
#
# For $n = 1$ the assertion is true. Continuing with $n > 1$:
# $a^n | b^n \implies a \cdot a^{n-1} \cdot c = b \cdot b^{n-1}$ with $c > 0$.
# This means that either $a | b$ or $a | b^{n-1}$.
# If $a | b$ the assertion is true. Taking $a \nmid b$
# implies $a \ne 1$ and this
# leads to a contradiction when we continue casting out factors of $b$ to reduce
# the exponent to $0$: $a$ must divide in succession:
# $b^{n-2},\; b^{n-3},\; \dots \; b^{1}, \; 1$.
# This last step $a|1$ implies $a=1.\;\;$ &#x2610;

# %% [markdown]
# #### 1.12 b) Prove or provide a counterexample: $n^n | m^m \implies n | m$.
#
#
# This assertion is false. The premise implies $n \le m$. Suppose that $n \nmid m$ even though all
# the prime factors of $n$ are also prime factors of $m$. For example $25$ and $55$.
# That statement concerns $n$ and $m$ without exponentiation.
#
#
# Now let's transition to $m^m$. This can stack up a lot of prime factors, eventually reaching or exceeding
# the number of prime factors found in $n^n$. Whereupon it will be the case that $n^n | m^m$.
# Calculations follow for three examples. In the first case $4 \nmid 10$ but $10^{10}$ contains
# $10$ factors of $2$ exceeding the $8$ found in $4^4$; so $4^4 \mid 10^{10}$ and
# this is a counterexample. $\otimes$
#
# See the **`examples.ipynb`** notebook.

# %% [markdown]
# #### 1.12 c) For $n > 1$ show $a^n | (2b^n) \implies a|b$.
#
#
# If $a$ is odd we have $a^n|b^n$ and **1.12a** establishes the implication $a|b$.
#
#
# If $a$ is even then suppose $a=2^s \cdot d$ and so $2^{ns} \cdot d^n | 2 \cdot b^n$. Dividing out one $2$ we have for some $m$:
#
#
# $$b^n = 2^{ns-1}\cdot d^n \cdot m = 2^{ns-n+n-1}\cdot d^n \cdot m = 2^{n(s-1)+(n-1)}\cdot d^n \cdot m$$
#
#
# Now the finesse: $b$ is raised to the $n$ so the right side must be *something* raised to the $n$. $d$ is odd so as
# 2^{n(s-1)+(n-1)} is not some power of two raised to the $n$ (because $n-1 > 0$) we must conclude that $m$ is even.
# Moving a factor of two from $m$ to the $2$ expression we have
#
#
# $$b^n = 2^{ns} \cdot d^n \cdot m/2$$
#
# Taking the $n$'th root of $m/2$ is not a problem; we could reverse it and require $m = 2 \cdot q^n$ for some $q$.
# So at this point we can take the $n$'th root of both sides to arrive at $b = a \cdot q$ and so $a | b.\;\;$ &#x2610;

# %% [markdown]
# #### 1.13 a) If $(a, b)=1$ and $(a/b)^m=n$ show that $b=1$.
#
# In problem 1.7 we show that if the sum of two reduced fractions is an integer then their denominators are the same (or negatives).
# In this case we have $\frac{a^m}{b^m}-\frac{n}{1}=0$ and since $b$ is positive we have $b^m=1$ and therefore $b=1.\;\;$ &#x2610;

# %% [markdown]
# #### 1.13 b) If $n$ is not the $m$th power of a positive integer, show that $n^{1/m}$ is irrational.
#
# Requiring $n > 1$ let us suppose the contrary, that $n^{1/m}=a/b$, a rational number.
# Equivalently $n = \frac{a^m}{b^m}$. From 1.13a we have $b=1$ and $n=a^m$. Thusly
# $n$ *is* the $m$th power of a positive integer, a contradiction.$\;\;$ &#x2610;
#
#
# I think I'll use the null set symbol &#x2205;
# in the sense of "There is no *there* here (no self-consistent narrative)"
# as shorthand for "*a contradiction*", to wit:
#
#
# *Thusly $n$ is and is not the $m$th power of a positive integer,* &#x2205; &#x2610;

# %% [markdown]
# #### 1.14 Unsolved If $(a, b) = 1$ and $ab=c^n$ show that $x$ and $y$ exist such that $a=x^n$ and $b=y^n$. [Hint: Consider $d=(a,c)$.]
#
#
# $d = (a,c) = au + cv$ and $e = (b,c) = bq + cr$.
#
#
# $c^n = \left( \frac{d-au}{v} \right)^{n} = ab$.

# %% [markdown]
# #### 1.15 Show that every $n \ge 12$ is the sum of two composite numbers.
#
# $n$ even can be written $n = 4 + (n - 4) = 2\cdot 2 + 2 \cdot (\frac{n}{2}-2)$, a sum of two composites.
#
# $n$ odd can be written $n = 9 + (n - 9)$ and noting $n - 9$ is even we have $n = 3\cdot 3 + 2\cdot(\frac{n-9}{2})$, again a sum of two composites.
#
# This works for $n=13$ and $n=14$ and up.$\;\;$ &#x2610;

# %% [markdown]
# #### 1.16 Show that if $2^n-1$ is prime, $n$ is prime.
#
# The appearance  of $x^\alpha-1$ is
# suggestive of a telescoping factorization.
# Factors in term imply composite; so this proceeds by way of
# contradiction. Assume $n$ is *not* prime, $n = ab$
# for $a, b > 1$. Factor $2^{ab}-1$ establishing that both factors
# are greater than one, the requisite contradiction;
# hence $n$ must be prime.
#
#
# $2^{ab}-1 = (2^a-1)(2^X + 2^{X-1} + 2^{X-2} + \dots + 2^{1} + 2^{0})$.
#
#
# What must $X$ be in order for the product of the two first terms
# $2^a \cdot 2^X$ to be $2^{ab}$?
# $X = ab - a = a(b-1)$. Now all the other product terms arising from $2^a$
# cancel those from $(-1)$ but for the last, $-1 \cdot 1 = -1$ and the telescoping
# factorization is ok. As $a>1$ the first factor is greater than $2$. Likewise
# $a(b-1)>1$. 'Both factors greater than one' implies the
# contradiction that $2^n-1$ is not prime if $n$ is not prime.$\;\;$ &#x2610;

# %% [markdown]
# #### 1.17 Show that if $2^n + 1$ is prime, $n = 2^k$ for some $k \ge 0$.
#
# This follows a similar approach to that used in **1.16** above; with the
# telescoping factorization relying on alternating signs in the second factor.
# Here we suppose $n=2^k\cdot b$ with $b$ an odd number. The contradiction
# is reached by assuming $b \ge 3$ and factoring $2^n+1$ so as to imply it is
# composite. The conclusion is then that $b = 1$ and $n$ is simply $2^k$.
#
#
# Begin by presuming a factorization:
#
#
# $2^n+1 = 2^{2^{k}b}+1=(2^{2^{k}}+1)\cdot(Y^X - Y^{X-1} + Y^{X-2} - \dots - Y^{1} + Y^{0})$
#
#
# Now to sort both $Y$ and $X$; noting that the second factor must have
# an odd number of terms for the alternating signs to resolve the telescope properly.
# Noting the 'counting down' exponents $X, X-1, \dots, 1$: $X$ must
# be even.
#
#
# First term product of these factors is $2^n$ so
# $2^n = 2^{2^{k}b} = 2^{2^{k}}\cdot Y^X$ so $Y=2^{2^{k}}$ and $X=(b-1) \ge 2$.
# $b$ is odd so $X$ is even as required in the factorization. Both
# factors are greater than one; where the right factor might
# require some staring. One approach is to pair the terms of the sum
# as $positive + negative$ with a decreasing exponent.
# Example $Y^8-Y^7$ where $Y$ is a positive integer. The result is
# that each pair has a net positive sign; plus the trailing $1$
# giving a total $> 1$.
#
#
# As a result the factorization arrives at the
# contradiction that $2^n+1$ is composite.$\;\;$ &#x2610;

# %% [markdown]
# #### 1.18 If $m > n$ compute the gcd $g = (a^{2^{m}} + 1, a^{2^{n}} + 1)$ in terms of $a$.
#
# > To do: Don't use letter $\varphi$ here because it is bespoke for the Totient in chapter 2.
#
#
# [***Hint: Define $A_n = a^{2^{n}}+1$ and show that $A_n | A_m - 2$.***]
#
#
# That's a good hint. This write-up will rely on two points: First that $m > n \ge 1$ and that consequently $2^m$ can be divided by
# $2^n$ an even number of times, in fact $2^{m-n}$ times. I state the obvious as I had tremendous difficulty working with the double
# exponential term $a^{2^{n}}$; so I proceed by trying to stay in a 'self-evident' line of thinking. The telescoping product
# that follows echoes machinery in problem 1.16 above.
#
#
# The key idea here is to set up the divisibility hint: $A_m - 2 = A_n \cdot \varphi$.
# Anticipating a telescoping product
# let's presume $\varphi$ will be a sequence of alternating-sign terms
# and arrive at a (presumed) factorization.
#
#
# $A_m-2 = a^{2^m} - 1 = A_n \cdot \varphi = (a^{2^n} + 1) \cdot (A - B + C \dots + Y - Z)$
#
#
# From here we can state some 'must be' from the telescope logic. That is, the $a^{2^n}$ multiplied
# by term $K$ will be the negative of the $+1$ multiplied by term $J$ so they sum to $0$.
#
#
# It must be that $a^{2^n} \cdot A = a^{2^m}$, the non-telescoping lead term.
#
# Likewise $a^{2^n} \cdot B = A \cdot 1$, the first telescoping pair.
#
# Also $a^{2^n} \cdot C = B$
#
# ...und so weiter to the end...
#
# $a^{2^n} \cdot Z = Y$
#
# and finally $Z = 1$, the second non-telescoping term, which will be the $-1$ of $A_m - 2$.
#
# This result $Z = 1$ gives $a^{2^n} = Y$. Hence the multiplying factor to go from one term
# to the next in $\varphi$ must be $\frac{1}{a^{2^n}}$. I'll write this as $a^{-2^n}$.
#
# From above: $A=\frac{a^{2^m}}{a^{2^n}} = a^{2^m} \cdot a^{-2^n} = a^{2^m-2^n}$. This is the first term of $\varphi$.
#
# Likewise $B=\frac{A}{a^{2^n}}=a^{2^m-2 \cdot 2^n} \textrm{ and } C=\frac{B}{a^{2^n}}=a^{2^m-3 \cdot 2^n}$.
#
# That is, each term in $\varphi$ is the prior term scaled down by $a^{2^n}$; and as noted this
# produces an even number of terms. As the terms alternate sign and start positive the even
# count ensures the final $1$ is negative as required. Now the end is in sight.
#
#
# We have gcd $g=(A_n, A_m) \textrm{ so } g|A_m$. While $A_n \nmid A_m$ we do have
# $A_n | A_m - 2$ and therefore $g | A_m - 2$ as well. So $g|A_m \textrm{ and } g|A_m-2$.
# Hence $g$ can only be $1$ or $2$. If $a$ is odd then $A_n$ and $A_m$ will be even
# and $g=2$. If $a$ is even then $A_n$ and $A_m$ will be odd and $g=1.\;\;$ &#x2610;

# %% [markdown]
# #### 1.19 Prove for the Fibonacci sequence that $(f_{n}, f_{n+1}) = 1$.
#
# Note Theorem 1.1c) implies that $(a, b) = (a, b + na)$; so $(a, a + b) = (a, b)$.
# For the first several Fibonacci numbers 1, 1, 2, 3, 5, 8 etcetera the assertion is true.
# This is an opportunity for induction proof. Assume the assertion is true up to
# $(f_{n-1}, f_{n})=1$. Then $(f_{n}, f_{n+1}) = (f_{n}, f_{n} + f_{n-1}) = (f_{n}, f_{n-1}) = 1.\;\;$ &#x2610;

# %% [markdown]
# #### 1.20

# %% [markdown]
# #### 1.21

# %% [markdown]
# #### 1.22

# %% [markdown]
# #### 1.23

# %% [markdown]
# #### 1.24

# %% [markdown]
# > In the last group of problems all integers are positive.
#
# > Problems 1.25 and 1.26 are thematically connected to 1.7 and 1.13
#
# #### 1.25 Show that if $(a, b)=1 \;\; \exists \;\; x > 0, y > 0 \;\;\backepsilon\;\; ax-by=1$
#
#
# This works from the intuition that $ax + by = 1$ (existence guaranteed by $(a,b)=1$) is going
# to need either $x$ or $y$ be negative. This problem gives us the minus sign and then
# stipulates that $x$
# and $y$ both be positive. Here I simply recapitulate Greg Hurst's sensible solution.
#
#
# - For $a=1$ set $y = 1$ and $x = 1 + b$: $ax - by = 1$.
# - For $a>1, b=1$ set $y = a - 1$ and $x = 1$: $ax - by = 1$.
# - For $a>1, b>1$ observe for a workable $x$ and $y$:
#     - $\neg (x = 0 \cup y = 0)$
#     - $\neg \bigl( (x < 0 \cap y < 0) \cup (x > 0 \cap y > 0) \bigr)$
#
#
# For the established $x$ and $y$ where $ax+by=1$: If $x > 0$
# and $y < 0$ then define $y' = -y$ (positive) to arrive at
# $ax - by'=1$ as desired.
#
#
# The remaining case for $a>1, \; b>1$ is $x < 0, \; y > 0$. The strategy:
# Begin with $x$ and $y$ from $ax + by = 1$ and modify them.
#
#
# To recapitulate this case: $(a,b)=1$ so $x$ and $y$ exist such that
# $ax + by = 1$; and
# $x < 0, \; y > 0$.
#
#
# $$ax + by = ax + by + nab - nab$$
#
#
# $$a(x + nb) + b(y - na) = 1$$
#
#
# Here $n$ is a free parameter
# so choose it large enough that $(x + nb) > 0$ and by
# implication $(y - na) < 0$. As above: Define $y' = -(y - na)$
# which is now positive; and $x' = x + nb$ also positive.
# $ax' - by' = 1.\;\;$ &#x2610;

# %% [markdown]
# #### 1.26 Show from $(a, b) = 1$ and $x^a=y^b$ that for some $n$ we have $x=n^b$ and $y=n^a$
#
#
# From problem 1.25 $c$ and $d$ exist such that $ac - bd = 1$.
#
#
# $$x^a = y^b$$
#
#
# $$(x^a)^d = (y^b)^d$$
#
#
# $$x^{ad} = y^{bd} = y^{ac-1}$$
#
#
# Take the $a$'th root:
#
#
# $$x^{d} = y^{\frac{ac-1}{a}} = \frac{y^{c}}{y^{\frac{1}{a}}}$$
#
#
# $$y^{\frac{1}{a}} = \frac{y^c}{x^d}$$
#
#
# This right-hand side is a rational number. Consequently (Problem 1.13)
# $y$ is the $a$'th power of some number $n$: $y=n^a$. Returning to the
# problem statement: $x^a = y^b = (n^a)^b = n^{ab}=(n^b)^a \textrm{ so }x = n^b.\;\;$ &#x2610;

# %% [markdown]
# #### 1.27

# %% [markdown]
# #### 1.28

# %% [markdown]
# #### 1.29

# %% [markdown]
# ##### 1.30 If $n>1$ prove $\sum_{k=1}^{n}{\frac{1}{k}}$ is not an integer.
#
#
# This sum is called the [nth Harmonic number](https://en.wikipedia.org/wiki/Harmonic_number).
#
#
# There are two proofs easily found on the web: The *Bertrand Conjecture proof*
# and the *2-adic proof*.
#
#
# Bertrand's Postulate aka Chebyshev's Theorem I remember using:
#
#
# > *Chebyshev said it*<br>
# > *I'll say it again*<br>
# > *There's always a prime*<br>
# > *Between $n$ and $2n$.*
#
#
# The following is a rewrite of Anton Geraschenko's 'Bertrand' proof mentioned in passing in an online post dated to 2010.
#
# Take $p>n/2$ to be the largest prime less than $n>3$. Then $\sum_{i=1}^{n}\frac{1}{i}=\frac{1}{p} + \frac{a}{b}$,
# using $\frac{a}{b}$ as a collective 'sum of everything else'.
# The key idea is that the factors of the common denominator $b$ are all primes less than $p$.
# Suppose $\frac{1}{p} + \frac{a}{b}$ is an integer;
# then this number multiplied by $b$ is likewise an integer; but *that* number would be $\frac{b}{p} + a$ and
# as $(b,p)=1$ the fraction $\frac{b}{p}$ is not an integer, a contradiction. $\;\;$ &#x2610;
#
#
# The 2-adic proof was given by [JÓZSEF KÜRSCHÁK](https://en.wikipedia.org/wiki/J%C3%B3zsef_K%C3%BCrsch%C3%A1k)
# in a Hungarian Math/Physics journal; see ***A Harmonikus Sorról, Mat. és Fiz. Lapok, 27 (1918), 299--300***.
# One approach to stating this (mentioned by Anton Geraschenko) is to substitute the largest possible
# $2^s < n$ for $p$
# in the above argument.

# %% [markdown]
# ## Chapter 2
#
#
# ### Some useful ideas
#
#
# - I use $k$ for the number of unique prime factors of $n$. This is called $\nu(n)$ in problem 2.5.
#
#
# - The detachment of $\varphi(a \cdot b)$ into $\varphi(a) \cdot \varphi(b)$ is 'to be wished'; so showing that $(a, b) = 1$ can be a good strategy.
#
#
# - Greg tends to present high-level comprehension solutions. I often need to work up from
# low-level cases. For a good example of this see problem 2.13.

# %% [markdown]
# #### 2.1 Three parts: Find $n$ for which (a) $\varphi(n) = \frac{n}{2}$; (b) $\varphi(n) = \varphi(2n)$; (c) $\varphi(n) = 12$.

# %% [markdown]
# **(a)** $\varphi(n) = \frac{n}{2}$. For $n=1$ we have
# $\varphi = 1$ (not a solution) and $\varphi(2) = 1$ (a first solution);
# so let's proceed to $n > 2$, the regime where $\varphi(n)$ is always even
# to find more $\varphi(n) = \frac{n}{2}$.
# Combine these to conclude $n$ is a multiple of $4$
# so taking $\alpha > 1$ we have
#
# $$n = 2^{\alpha} \cdot \prod_{p \; odd}{p_i}^{a_i}$$
#
# Observing $(2^\alpha, \Pi) = 1$ gives us the second equality in
#
# $$\varphi(n) = \varphi(2^\alpha \cdot \Pi) = \varphi(2^\alpha) \cdot \varphi(\Pi) = 2^{\alpha-1} \cdot \varphi(\Pi) = \frac{n}{2}$$
#
# Powers of two are relatively prime to the odd numbers so $\varphi(2^d)=2^{d-1}.$
# Now to use $\varphi(n) = n$ only for $n=1$:
#
# $$2^{\alpha-1} \cdot \varphi(\Pi) = 2^{\alpha-1} \cdot \Pi \implies \Pi = 1$$
#
# Consequently $n = 2^\alpha = \{ 2, 4, 8, \dots \}$.

# %% [markdown]
# **(b)** Useful observation: $\varphi(2^s)=\varphi(2^{s+1})$ only for $s=0$.
# Taking $n=2^s\cdot d$ we want $n$ for which $\varphi(n) = \varphi(2n)$.
# As in part (a): $\varphi(2^s)\cdot\varphi(d)=\varphi(2^{s+1})\cdot\varphi(d)$.
# Hence $d$ is any odd number and $s=0$; so $n = \{1, 3, 5, 7, 9, \dots\}$.

# %% [markdown]
# **(c)** $\varphi(n)=12$
#
#
# This innocuous-looking problem caused me considerable emotional distress.
# It is easy enough to see that $n=13$ is a solution; and another matter
# to conclude that all solutions are found.
# This writeup depends upon two product forms
# of the Totient function where
# $n$ has $k$ distinct prime factors, each with its $\alpha$ exponent:
#
#
# $$12 = 2 \cdot 2 \cdot 3 = \varphi(n) = n \prod_{p|n} \frac{p_i-1}{p_i}$$
#
#
# $$12 = 2 \cdot 2 \cdot 3 = \varphi(n) = \prod_{p|n} \bigl( p_i^{\alpha_i} - p_i^{\alpha_i - 1} \bigr)$$

# %% [markdown]
# In the upper format the denominator product is cancelled by the leading $n$.
# What remains is a product of some integers.
# A solution for $n$ with $k = 4+$ distinct prime factors will have at least three distinct
# odd prime factors; and each will contribute a factor of two to the product
# owing to the "$-1$". As only two $2's$ are permitted
# (factorization of $12$) I conclude that $k \ge 4$ is not permitted.
# As $k = 1, 2, \textrm{ or }3$ I will take these in sequence, using
# the simpler notation of $p, q, r$ with corresponding exponents $\alpha, \beta, \gamma$.
#
#
# Let's presume the prime factors of $n$ are ordered $p < q < r$. Each, according to
# the second form above, contributes a factor to the product. For $k=1$ we have only
# $(p^\alpha - p^{\alpha-1})$. For $k=2$ we have $(p^\alpha - p^{\alpha-1})\cdot(q^\beta - q^{\beta-1})$ and for $k=3$ this extends once more to
# $(p^\alpha - p^{\alpha-1})\cdot(q^\beta - q^{\beta-1})\cdot(r^\gamma - r^{\gamma-1})$.
#
#
# The idea is to set up a table of these factors from which we can
# read off all possible answers.
#
#
# The column headers of this table are primes; the row labels the exponents.
# The values in the table are the only the values of
# $\bigl( p^{\alpha} - p^{\alpha - 1} \bigr)$ that divide $12$.
#
# |  |  p:      | 2 | 3 | 5 | 7 | 11 | 13 |
# | :---| ---:| ---:| ---:| ---:| ---:| ---:| ---:|
# | **$\alpha$:** | **1** $\;$ | 1 | 2 | 4 | 6 | &#x1f78c;  | 12
# | | **2** $\;$ | 2 | 6 |  &#x1f78c; | &#x1f78c;  |  &#x1f78c; |   &#x1f78c; |
# | | **3** $\;$ | 4 |  &#x1f78c; |  &#x1f78c; |  &#x1f78c; | &#x1f78c;  |   &#x1f78c; |
#
#
# Now to read off solutions: Begin with $k=1$: Find a single prime $p$ with
# table value $12$. That would be $p=13$ with a corresponding $\alpha=1$. So
# sensibly the prime one above the target value $12$ is a solution. There are
# no other single-prime solutions as the empty cells continue forever.
#
#
# Now to continue to $k=2$. Begin at the left with $p=2$ and choose the smallest
# $\alpha$. This gives a starting point: A table value of $1$. Choose a $q$ that
# has a table value of $12$ so that the product of the two table values is $12$.
# This would be $q=13$ with a corresponding $\beta$ exponent of $1$. This is
# a second solution consistent with $\varphi(n_{odd}) = \varphi(n_{odd} \cdot 2)$.
#
#
# Proceed through the table entries looking for $p \; q$ pairs and exponents
# that produce a table-value product of $12$. Always
# $p$ and $q$ must be distinct with $p < q$; trying each value of $\alpha$
# to exhaust all possibilities. As an example, $p = 3; \; \alpha = 1$ works
# with $q = 7; \; \beta = 1$. There are four $k=2$ solutions for $n$.
#
#
# Finally for $k=3$ there
# is just one $p, q, r$ triple that works, namely $2, 3, 7$, all with
# exponent $1$. The exhaustive solution is $n = \{13, 26, 36, 28, 21, 42 \}$.

# %% [markdown]
# #### 2.2 Prove or find counterexamples $\otimes$ for...
#
#
# (a) Show $(m,n) = 1 \implies (\varphi(m), \varphi(n))=1$.
# Choosing $m=3,\;n=4$ both give $\varphi = 2$, a counterexample. $\otimes$
#
#
# (b) Show $n \; composite \; \implies (n, \varphi(n)) > 1$.
# Choose $n = 15$ and check: $(15, 8) = 1$, a counterexample. $\otimes$
#
#
# (c) If the same primes divide $m$ and $n$ then $n\cdot\varphi(m) = m\cdot\varphi(n)$.
#
#
# $\frac{\varphi(m)}{m}=\prod_{p|m}{1-p^{-1}}$. Since all $p$ that divide $m$ also divide $n$
# the product on the right is also equal to $\frac{\varphi(n)}{n}$.
#
#
# This part (c) is very concise so I will expand a little bit. Writing the product form of
# the totient function $\varphi(s)$ introduces a factor of $s$; so divide both sides
# by $s$ to get $\varphi(s)/s$ on one side and the product on the other. Here
# this product will be identical for two distinct numbers $m$ and $n$ that share the same
# set of prime factors; so their totient-to-self ratios are equal.  $\;$ &#x2610;

# %% [markdown]
# #### 2.3 Show that $\frac{n}{\varphi(n)}=\sum_{d|n}\frac{\mu^2(d)}{\varphi(d)}$
#
#
# This problem is fairly quick and very cool. It begins with a useful observation
# from the rules of multiplicative functions, that $f * g$ is multiplicative if
# both $f$ and $g$ are (**Theorem 2.15**).
# Since the problem includes a Dirichlet product-like element,
# $\sum_{d|n}\frac{\mu^2(d)}{\varphi(d)}$, the insight is to invoke $u(n)=1$
# in $\frac{\mu^2}{\varphi}*u$.
# The composite function
# $\frac{\mu^2}{\varphi}$ is constructed from multiplicative functions
# $\mu$ and $\varphi$. This is all a bit imprecise; see the remarks
# below the solution. Thematically the idea is to support the decomposition
# of $n$ into its set of divisors by means of the $k$ primes that divide $n$.
#
#
# Plan: Operate on the right side of the above expression.
# Two points are needed: First the usual prime decomposition of $n$
# in terms of exponents $a_i > 0$; and second the consequent expression
# for building out all divisors of $n$ as a product of sums:
#
#
# $$\sum_{d|n}\frac{\mu^2(d)}{\varphi(d)} =
# \frac{\mu^2(n)}{\varphi(n)} * u(n) =
# \prod_{i=1}^k \Bigl( \sum_{j=0}^{a_i}
# \frac{\mu^2(p_{i}^{j})}{\varphi(p_{i}^{j})} \Bigr)$$
#
#
# From here we can make use of features of $\mu$ and $\varphi$.
# First *inside the sum* the function $\mu^2(q)$ has value
# $1$ when $q$ is either $1$ or a prime,
# and zero otherwise. Second, $\varphi(1)=1$ and $\varphi(p)=p-1$.
# As a result the summation over powers of the prime factor $p_i$
# simplifies into just the $j=0$ and $j=1$ cases:
#
#
# $$\sum_{d|n}\frac{\mu^2(d)}{\varphi(d)} =
# \prod_{i=1}^k \Bigl( 1 + \frac{1}{p_i-1} \Bigr) =
# \prod_{i=1}^k \Bigl( \frac{p_i}{p_i-1} \Bigr) =
# \prod_{p|n} \frac{1}{1-p^{-1}} =
# \frac{n}{\varphi(n)}.$$
#
#
# The last step is from the product form of the totient function; and there we are. $\;$ &#x2610;
#
#
# ***Further elaboration:*** At many points in chapters 1 & 2 the problems
# depend on some form of "multiply by 1". In this arithmetic function space
# the idea of $1$ is present in two forms *prima facia*: The identity function
# $I(n) = \bigl[ \frac{1}{n} \bigr]$ and the unit function $u(n)=1$. In this case
# the latter is invoked in Greg's solution sort of 'in passing' for the sake
# of the subsequent algebraic manipulation of $\frac{\mu^2}{\varphi}$.
#
#
# I think the key signpost here is simply the presence of $\sum_{d|n}$
# invoking the Dirichlet product. The real utility, the real value of the
# problem, is in the decomposition of $d|n$ into products of sums of
# powers of primes where $(p_a, p_b)=1$ gives us the necessary running room
# in the context of multiplicative functions. To put that in reverse order:
# The condition of being a multiplicative function gives us decomposition
# of functions of prime products into products of functions of primes.
#
#
# Finally to beat this to pieces one more time: There is an important
# property in the text concerning the decomposition of the totient of a product
# of two numbers $m$ and $n$ (see **Theorem 2.5 b)** and **c)**). This
# is that $\varphi(m \cdot n) = \varphi(m) \cdot \varphi(n)
# \textrm{ when } (m, n) = 1$. This resonates with the definition of
# multiplicative functions.

# %% [markdown]
# #### 2.4 Show that $\varphi(n) > \frac{n}{6} \; \forall \; n $ with $k \le 8$ prime factors.
#
#
# This is an example of proof by calculation.
#
#
# Taking $\varphi(n) = n \cdot \prod_{p|n}\frac{p-1}{p}$ the goal is to show the
# product $\prod < \frac{1}{6}$. Calculate $\prod$ for
# the first eight primes: $\{\frac{1}{2} \cdot \frac{2}{3} \cdot \cdots \cdot \frac{18}{19}\}$.
# The result is a number greater than $1/6$. Choosing any other set of eight (larger)
# primes results in factors *closer* to 1, yielding a bigger product. Likewise choosing
# numbers with fewer than eight unique prime factors results in a larger resulting
# product: There are fewer factors where each is less than one. In both cases, therefore,
# the product above is a lower bound.$\;\;$ &#x2610;

# %% [markdown]
# #### 2.5 Incomplete: Show $f = \mu * \nu$ is 0 or 1 where $\nu(n)$ is the number of distinct prime factors of $n$.
#
#
# Here $f$ is a Dirichlet product and observe that $\nu(1)=0$ (so it is not multiplicative).
#
#
# ##### Intermezzo on alternating sign sums involving binomial coefficients
#
#
# Define two sums that involve binomial coefficients, this first $A_0$ unweighted
# and the second $A_1$ weighted by index (starting at zero):
#
#
# \begin{equation}
# A_0(k) = \sum_{i=0}^{k} {-1}^i \cdot \binom k i
# \end{equation}
#
#
# \begin{equation}
# A_1(k) = \sum_{i=0}^{k} {-1}^i \cdot \binom k i \cdot i
# \end{equation}
#
#
# Then $A_0(0) = 1$, $A_0(k>0) = 0$. This is easy to prove for example using induction
# or the symmetry of binomial coefficients.
#
#
# ***Could insert comment on sum of Mobius of d|n***
#
#
# Also $A_1(0) = 0$, $A_1(1) = -1$, $A_1(k>1) = 0$.
#
#
# ***Could insert comment on proving this***
#
#
# ##### Returning to problem 2.5
#
#
# After noting $f(1) = 0$ we consider $n > 1 \textrm{ where we can write the usual } n = \prod_{i=1}^{k \ge 1} {p_i}^{a_i}$.
#
#
#
# Let $m$ be the number of prime factors of $n$ with $a_i \ge 2$; primes present as at least squares.
# For example $360 = 2^3 \cdot 3^2 \cdot 5^1$ has $m=2$.
# This parameter is motivated by terms in the Dirichlet convolution sum where
# a divisor $d$ of $n$ includes a
# prime factor ${p_i}^1$ with a corresponding $a_i \ge 2$. In this case $p_i$ is present both
# in the argument in $\mu(d)$ and in the argument in $\nu(\frac{n}{d})$. That is: There are at least two $p_i$ factors, $\mu(d)$ ... to do finish this explanatory ...

# %% [markdown]
# As these $m$ squarish primes must be factors of both $d$ and $n/d$ they impact both
# $\mu(d)$ and $\nu(n/d)$. Only square-free
# divisors $d$ have non-zero Mobius value. These we choose to group by number of
# prime factors. If there were five values of $d$ that each have four prime factors:
# Each contributes a Mobius function value of $\mu(d) = 1$.
#
#
# For each of these groups we then want to add up the total number of
# prime factors in the complementary divisor; add all of the $\nu(n/d)$ values.
#
#
# Notice this product enumerates all non-square factors of $n$:
#
#
# \begin{equation}
# \prod_{i=1}^{k}(1+p_i)=1 + p_1 + p_2 + \dots + p_k + p_1 \cdot p_2 + \dots + p_{k-1} \cdot p_{k} + \dots + p_1 \cdot p_2 \cdot p_3 \cdots p_k.
# \end{equation}
#
#
# Grouping the factors $d$ by the number of prime factors in each:
#
#
# - group 0: no prime factors (i.e. $\{ 1 \}$): one element
# - group 1: individual primes: $\{ p_1, p_2, \dots, p_k \}$: $k$ elements
# - group 2, pairs of primes $\{ p_1 \cdot p_2, p_1\cdot p_3, \dots, p_{k-1} \cdot p_{k}\}$: $\binom{k}{2}$ elements
# - $\dots$
# - group $g$: $\binom{k}{g}$ elements
# - $\dots$
# - group $k$: $\{ p_1\cdot p_2 \cdot \cdots \cdot p_k \}$: one element.
#
#
# Write the Dirichlet convolution with the outer sum over these $k+1$ groups:
#
#
# \begin{equation}
# f = \mu * \nu = \sum_{g=0}^{k} \sum_{i=1}^{\binom k g} \mu(d_{g,i}) \cdot \nu(\frac{n}{d_{g,i}})
# \end{equation}
#
#
# When $m = 0$ the number $n$ is square-free, a product of a set
# of distinct primes. Here for group $g$ the function $\nu(n/d)$
# will be $(k - g)$: The number of remaining prime factors from $k$
# total after $g$ of them are multiplied to produce $d$.
# The above sum becomes
#
#
# \begin{equation}
# f = \mu * \nu = \sum_{g=0}^{k} {\binom k g} \cdot ({-1}^g) \cdot (k - g)
# \end{equation}

# %% [markdown]
# With $k = 1$: $n$ is prime and $f(n_{prime}) = (1 \cdot 1 \cdot 1) + (1 \cdot -1 \cdot 0) = A_1(1) = 1$.
#
#
# With $k > 1$, still retaining the square-free condition ($m=0$),
# we have equivalence by symmetry to $A_1(k > 1)$ give or take a factor of $-1$.
# In this case the sum is $f(n) = 0$.
#
# $$
# f(n_{squarefree}) = \mu * \nu = \sum_{g=0}^{k} {\binom k g} \cdot ({-1}^g) \cdot (k - g) = 0.
# $$
#
#
# For $m > 0$ the value of $\nu(\frac{n}{d})$ will vary for elements within a group.
# However only $d$ values that are squarefree give non-zero values of $\mu$.

# %% [markdown]
# #### 2.6 Incomplete: Divisor power sums of Mobius functions
#
#
# a) Show $\sum_{d^2|n}\mu(d)=\mu^2(n)$
#
#
# b) Show $\sum_{d^k|n}\mu(d) = 0$ if $m^k|n$ for some $m>1$; $= 1$ otherwise.

# %% [markdown]
# #### 2.7 Divisor sum of a Mobius product
#
#
# Abbreviate $\mu((p, d))$ as $\mu(p,d)$. Confirm these three outcomes for some prime $p$: The sum
# $\sum_{d|n}\mu(d)\cdot\mu(p,d)=1$ if $n=1$; $=2$ if $n=p^\alpha$; $=0$ otherwise.
#
# Case 1: $n=1$: $d=1$, and the sum becomes $\mu(1) \cdot \mu(1) = 1$, first result confirmed.
#
#
# Case 2: $n=p^\alpha$.
#
#
# Recall for a number $s$ that is *not* squarefree: $\mu(s)=0$. In this case, then, only two
# terms remain in the sum: $d=1$ and $d=p^1$. The sum becomes
#
#
# $$\sum = \mu(1) \cdot \mu(p, 1) + \mu(p) \cdot \mu(p,p) = 1\cdot 1 + (-1) \cdot (-1) = 2$$.
#
#
# Second result confirmed.
#
#
# Case 3a: $n$ does not have $p$ as a prime factor: $n = \prod q_i^{\beta_i}$.
#
#
# Now the sum over divisors of $n$ only includes first powers of the primes $\{ q_i \}$.
# The Mobius function will give powers of $-1$ for $\mu(d)$ and $\mu(p, d)$ will always be $1$.
# As a result we have the alternating sign sum of binomial coefficients
# (see solution to 2.5 above), which is zero.
#
#
# Case 3b: $n$ *does* include $p$ as a prime factor (say to some power $\alpha$).
#
#
# As in (3a) only squarefree divisors of $n$ will contribute to the sum. Divisors of $n$
# that do not include $p$ are covered above in (3a), summing to zero. That same set of
# divisors is now replicated where each has an additional factor of $p$. This gives the
# same alternating-sign binomial coefficient sum multiplied by (-1) owing to the added
# factor $p$; so the sum is still zero provided the second factor $\mu(p,d)$ does not
# change matters. In fact the second factor in the sum is $\mu(p,d) = \mu(p) = -1$. This new set of
# divisors involving $p$ therefore also sums to zero.
#
# Third result confirmed. $\;\;$ &#x2610;

# %% [markdown]
# #### 2.8 Incomplete: Show $\sum_{d|n}\mu(d) \cdot log^m d = 0$ if $m>0$ and $n$ has $k > m$. (Hint: Induction)
#
#
# Again $k$ is the number of unique prime factors of $n$.
#
#
# Let's get a sense of this working for $k=3$ and $m = 1$, then again with $m = 2$. Take $n=60=2^2\cdot3\cdot5$.
# The set of $d|n$ is $\{1, 2, 3, 4, 5, 6, 10, 12, 15, 20, 30, 60 \}$.
#
#
# To begin evaluating the sum: Toss out factors containing squares ($\mu$) and $1$ since $log \; 1 = 0$: $\{2, 3, 5, 6, 10, 15, 30\}$.
#
#
# Corresponding $\mu$ values for these seven remaining divisors are respectively $\{-1, -1, -1, 1, 1, 1, -1 \}$.
# In the case where $m=1$: Break down each log(divisor)
# in terms of factors. The sum is then $-\log 2 - \log 3 - \log 5 + \log 2 + \log 3 + \log 2 + \log 5 + \log 3 + \log 5 - \log 2 - \log 3 - \log 5 = 0$ as proposed.
#
#
# Trying this for $m=2$:
#
#
# $$\sum = -log^2(2) - \dots - (log(2) + log(3) + log(5))^2 = \textrm{ everything cancels } = 0.$$

# %% [markdown]
# #### 2.9 Incomplete: Extending the totient $\varphi$ for $x \in \mathbb{R}$
#
# If $x \in R$, $x \ge 1$: Let $\varphi(x, n)$ denote the number of positive integers $\le x$
# that are relatively prime to $n$.
#
#
# a) Show $\varphi(x, n) = \sum_{d|n} \mu(d) \left[ \frac{x}{d} \right]$.
#
# b) Show $\sum_{d+n} \varphi(\frac{x}{d}, \frac{n}{d}) = \left[ {x} \right]$.

# %% [markdown]
# #### In 2.10, 2.11, 2.12: $d(n)$ denotes the number of positive divisors of $n$.
#
#
# #### 2.10 Show $\prod_{t|n} t = n^{\frac{d(n)}{2}}$
#
#
# There is a thinking angle to this problem: Suppose $n$ has a
# bunch of divisors, $d$ of them.  Actually no forget that; suppose $n$ is prime
# so $d=2$; the smallest $d$ for $n > 1$. Then the right side is $n^{\frac{d=2}{2}}$.
# The left side product is $1 \cdot n$
# so everything is fine. But the *insight* relates to the story about Euler asked by a teacher
# to add the numbers from $1$ to $100$ to keep him busy; and he finishes the task in no time
# by adding pairs of numbers $1 + 99$ and so on. Here we have a
# breakdown of $t$ values into pairs with product $n$, in this prime case just $1$ and $n$.
#
#
# Returning to some $n$ with a lot of divisors: Pairwise breakdowns persist. For example for $n=60$
# will have product $(1 \cdot 60) \cdot (2 \cdot 30) \cdot \dots \cdot (6 \cdot 10)$. While $d$ is
# $12$ this is $6$ products, each one equal to $60.$ Half of $d$ is the proper exponent of $n$.
# ***Except...*** what about squares? Consider $n=25$. Now we have $1 \cdot 5 \cdot 25 = 125$.
# In this case $d=3$ and the pairing argument hits a bump. But no worries: This is explicitly pairs
# multiplied together as before (but not quite as many) multiplied by one more number that is the
# square root of $n$. So we have $\sqrt{n} \cdot n^{\frac{d_{odd}-1}{2}}$ and here again we arrive
# at $n^{\frac{d}{2}}$.
#
#
# Now for Greg's very elegant cut to the chase solution:
#
#
# $$n^d = \prod_{t|n}n = \prod_{t|n} t \cdot \frac{n}{t} = \prod_{t|n}{t} \cdot \prod_{t|n}{\frac{n}{t}} = \Bigl\{ \prod_{t|n} t \Bigr\}^2$$
#
#
# #### 2.11 Show if $n$ has an odd number of divisors $n$ is a square.
#
#
# Consider for a moment the question 'How many subsets are there from a set of $n$ elements?'
# This can be readily seen by lining up all elements in $n$ in some order with a binary bit
# placed below each. For a given subset each bit is either on or off; so there are $2^n$ subsets.
#
#
# Similarly for divisors: If $n=\prod{p_i^{a_{i}}}$ then each prime factor $p_i$ will
# be present in a particular divisor of $n$ as $p_i$ raised to some power
# $\{ 0, 1, \dots , a_i \}$. Instead of a 1-or-0 bit this prime number has $a_i + 1$
# possible states (exponents) within some factor of $n$.
# The number of divisors $d$, i.e. the number of subsets of these prime factors raised to all
# possible powers is
# $d = (a_1 + 1)\cdot(a_2 + 1)\cdot \dots \cdot(a_k + 1)$.
#
#
# Suppose $d$ is odd.
# Each factor in the above expression is then odd.
# Therefore each $a_i$ is even ($> 0$): The sum of two equal integers.
# This partition of all prime factors of $n$ into the product of two equal
# numbers means that $n$ is a square.$\;\;$ &#x2610;

# %% [markdown]
# #### 2.12 Incomplete: Show that $\sum_{t|n} d(t)^3 = \bigl( \sum_{t|n} d(t)\bigr)^2.$

# %% [markdown]
# &#x1f989;
#
#
# $\Huge \varphi \backepsilon$

# %% [markdown]
# #### 2.13 Incomplete: *Product form of the Mobius inversion formula*
#
#
# If $f(n) > 0$ for all $n$ and if $a(n)$ is real, $a(1) \ne 0$, prove that
#
#
# $$g(n) =  \prod_{d|n}f(d)^{a(\frac{n}{d})} \;\; \textrm{ if and only if } \;\; f(n)=\prod_{d|n}g(d)^{b(\frac{n}{d})},$$
#
#
# where $b=a^{-1}$, the Dirichlet inverse of $a$.

# %% [markdown]
# This problem seems to me rather mystifying... so I need a plan.
#
#
# **Plan**: First let's review the summation form of the MIF. Then let's make
# an observation on a transition to a product form. Then let's look at
# Greg Hurst's solution with trepidation. Then let's work examples to
# build an experiential understanding of the premise to be shown.
# Then let's see where things stand.

# %% [markdown]
# #### 2.14 Incomplete: On functions of a rational x on $[0, 1]$ and roots of unity
#
#
# Let $f(x)$ be defined for all rational $x$ in $0 \le x \le 1$. Define two functions $F(n)$ and $F^*(n)$:
#
#
# $$F(n) = \sum_{k=1}^n f \Bigl( \frac{k}{n} \Bigr), \;\;\; F^*(n)=\sum_{\;\;k=1; \newline(k,n)=1}^n f \Bigl( \frac{k}{n} \Bigr).$$
#
#
# (a) Show $F^* = \mu * F$.
#
#
# $$\mu * F = \sum_{d|n}\mu(d) \cdot F(n/d) = \sum_{d|n} \Biggl( \mu(d) \cdot \sum_{k=1}^{n/d} f \Bigl( \frac{k}{n} \Bigr) \Biggr)$$
#
#
# (b) Show that $\mu(n)$ is the sum of the primitive $n$th roots of unity
#
#
# $$\mu(n) = \sum_{\;\;k=1; \newline(k,n)=1}^n e^{2 \pi i k/n}.$$
#
#
#
#
# #### 2.15 Generalized totient proof (Suggestion: Use **2.14**)
#
#
# Let $\varphi_k(n)$ denote the sum of the $k$th powers of the numbers $\le n$ and relatively prime to $n$. Note $\varphi_0(n) = \varphi(n)$.
# Show that
#
#
# $$\sum_{d|n} \frac{\varphi_k(d)}{d^k} = \frac{1^k + \cdots + n^k}{n^k}.$$
#
#
# #### 2.16 Invert the formula in **2.15** to obtain, for $n > 1$,
#
#
# $$\varphi_{1}(n)= \frac{1}{2} \cdot n \cdot \varphi(n),$$
#
#
# and
#
#
# $$\varphi_{2}(n) = \frac{1}{3} \cdot n^2 \cdot \varphi(n) + \frac{n}{6} \prod_{p|n}(1-p).$$
#
#
# Derive a corresponding formula for $\varphi_3(n)$.

# %% [markdown]
# #### 2.17 Incomplete:
#
#
# #### 2.18 Incomplete:
#
#
# #### 2.19 Incomplete:
#
#
# #### 2.20 Incomplete:
#
#
# #### 2.21 Incomplete:
#
#
# #### 2.22 Incomplete:
#
#
# #### 2.23 Incomplete:
#
#
# #### 2.24 Incomplete:

# %% [markdown]
# #### 2.25 (a) For $f$ a multiplicative function: Show the Dirichlet inverse $f^{-1} = \mu f$ for all square-free $n$.
#
#
# Here conversationally $f$ has a Dirchlet inverse "whatsomever" for $n>0$; but
# the proposition is *specific* to
# the subset of square-free $n$: For square-free $n$ this $\mu f$ formula
# is in fact the inverse of $f$.
#
#
# For $n=1$ we have $f^{-1} = 1$ (see proof of theorem 2.8) and the proposed inverse is correct.
#
#
# For $n > 1$: Pairs of divisors of $n$ of the form
# $\{ d, \frac{n}{d} \}$ will have $(d, n/d)=1$ (as otherwise $n$ would not be square-free).
# Therefore the multiplicative nature of $f$ gives $f(d)\cdot f(n/d) = f(n)$.
#
#
# Continuing for $n>1$ we must show
#
#
# $$0 = f^{-1}(n) * f(n) = \sum_{d|n} \mu(d) \cdot f(d) \cdot f(\frac{n}{d}) = f(n)\sum_{d|n}\mu(d)$$
#
#
# The divisors of $n>1$ can be generated from
# $(1 + p_1)\cdot(1 + p_2) \dots (1 + p_i)$.
#
#
# This resolves the sum:
#
#
# $$\sum_{d|n}\mu(d) = \mu(1) + \binom{i}{1} \cdot \mu(p_1) + \binom{i}{2} \cdot \mu(p_1\cdot p_2) + \dots + \mu(p_1 \cdot p_2 \dots p_i) = \sum_{k=0}^{i} {-1}^k \binom{i}{k} = 0.$$
#
#
# (Last step: See solution to 2.5 above.)
#
#
# Therefore the product $f(n) \cdot \sum_{d|n}\mu(d) = f(n) \cdot 0 = 0 = I(n>1)$.
# This shows that $\mu(n)f(n) * f(n) = I(n) = {1, 0, 0, \dots}\;\;$ &#x2610;

# %% [markdown]
# #### 2.25 (b) Again with $f$ multiplicative: Show for any prime $p$ that $f^{-1}(p^2)=f(p^2)-f(p)^2$
#
#
# Semantic note: This condition $n = p^2$ applies to a subset of the
# integers $\{ 1, 2, 3, 4, \dots \}$.
# That is, $f$ is multiplicative and is therefore arithmetic and is therefore defined on *all*
# integers; but the problem only concerns the proposed inverse for
# the subset $n = \{ 4, 9, 25, 49, \dots\}$. Again
# we can begin with $f(1)=1$ and $f^{-1}(1)=1$ as in **2.25(a)**. And now for $n>1, \; n=p^2$
# the Dirichlet product $f_{proposed}^{-1} * f$ must again be zero.
#
#
# $$f_{proposed}^{-1}(p^2) * f(p^2) = \sum_{d|n} = \sum_{d\in\{1,p,p^2\}}(f(d^2)-f(d)^2)\cdot f(\frac{n}{d})$$
#
#
# Elaborating the three terms in the sum:
#
#
# $$f_{proposed}^{-1} * f = \bigl( f(1)-f(1)^2 \bigr) \cdot f(p^2) +
#                           \bigl( f(p^2)-f(p)^2 \bigr)\cdot f(p) +
#                           \bigl( f(p^4) - f(p^2)^ \bigr) \cdot f(1). $$
#
#
# $$f_{proposed}^{-1} * f = 0 \cdot f(p^2) +
#                           f(p^2) \cdot f(p) - f(p)^2 \cdot f(p) +
#                           f(p^4) - f(p^2)^2. $$
#
#
#
# $$f_{proposed}^{-1} * f = f(p^4) - f(p^2)^2 = 0.$$
#
#
# This final couple steps make use of Theorem 2.13b: $f(p^a)=f(p)^a.\;\;$&#x2610;

# %% [markdown]
# #### 2.26 Incomplete: For $f$ multiplicative: Proceed to show $f$ is *completely* multiplicative if and only if $f^{-1}(p^a)=0$ for all primes $p$ and all integers $a \ge 2$.
#
#
# - One approach to 'if and only if' proof is to show both $A \implies B$
# and $B \implies A$.
#
#
# - I write the Dirichlet inverse of $f$ as $g$, easier than $f^{-1}$.
#
#
# - For $n=p^a$ we have the Dirichlet sum divisors $d \in \{ 1, p, p^2, \dots, p^a \}$.
# Furthermore $f(1) = g(1)=1$.
#
#
# - Question: Under what circumstances do we have $f(p^a)=f(p)^a$?
#
#
# - Remark: Greg uses Thm 2.17 to go from the premise of
# $f$ completely multiplicative to the expression for the inverse $g$ as
# $g(n) = \mu(n) \cdot f(n)$ noting this is zero for $n=p^a$ with $a > 1$
# since $\mu$ is then given a squareful argument.
#
#
# - Taking $f$ to be completely multiplicative for integers $1, 2, \dots$ let us proceed
# to the implication that $g(p^a)=0$, where $a > 1$.
#
#
# - Consider $g(p)$: The Dirichlet sum has just two
# terms so we have $f(p) + g(p) = 0$. That is, $g(p) = -f(p)$.
# Now to increase the prime exponent from $1$ to $2$.
#
#
# $$g * f |_{p^2} = g(1) \cdot f(p^2) +
# g(p) \cdot f(p) +
# g(p^2) \cdot f(1) = f(p)^2 - f(p)^2 + g(p^2) = 0.$$
#
#
# - This gives us $g(p^a)=0$ for $a=2$.
# Assuming $g(p^a)=0$ for $a=2, \dots, n-1$. How about for $a=n$?
#
#
# $$g * f|_{p^n} = 1 \cdot f(p^n) + (-f(p)) \cdot f(p^{n-1}) + g(p^2) \cdot f(p^{n-1})
# + \dots + g(p^n) = 0 + g(p^n) = 0.$$
#
#
# - That is an induction proof that 'completely multiplicative' implies $g(p^a)=0$.
#
#
# - In the opposite direction we want $g(p^a)=0$ for $a \ge 2$ to imply $f$ is
# completely multiplicative.
#
#
# - If $g(p^a)=0$ then as a special case $g(p^2)=0$ and by 2.25b:
# For any prime $p$ this is $f(p^2)-f(p)^2$;
# so the two terms are equal: $f(p^2)= f(p)^2$.
#
#
#
#
#
#
#
#
#
#
# Not quite &#x2610;

# %% [markdown]
# #### 2.27 (a) If $f$ is completely multiplicative, prove that $f \cdot (g*h) = (f \cdot g) * (f \cdot h)$ for all arithmetic functions $g$ and $h$.
#
# Here $f \cdot g$ denotes a simple product: $(f \cdot g)(n) = f(n) g(n)$.

# %% [markdown]
# #### 2.27 (b) If $f$ is multiplicative and if the relation in (a) above holds for $g=\mu$ and $h=\mu^{-1}$, prove that $f$ is completely multiplicative.

# %% [markdown]
# #### 2.28 (a) Incomplete:

# %% [markdown]
# #### 2.28 (b) Incomplete:

# %% [markdown]
# #### 2.29 Incomplete:

# %% [markdown]
# #### 2.30 Incomplete:

# %% [markdown]
# #### 2.31 Incomplete:

# %% [markdown]
# #### 2.32 Incomplete:

# %% [markdown]
# #### 2.33 Incomplete:

# %% [markdown]
# #### 2.34 Incomplete:

# %% [markdown]
# #### 2.35  Incomplete:

# %% [markdown]
# #### Mobius functions of order $k \ge 1$
#
# Define $\mu_k(n)$:
#
#
# Case 1: $\mu_k(1) = 1$;
#
#
# Case 2: $\mu_k(n) = 0$ when $p^{k+1}|n$ for some prime $p$;
#
#
# Case 3: $\mu_k(n) = (-1)^r$ if $n=p_1^k\cdot p_2^k \cdot \dots \cdot p_r^k
# \prod_{i>r}p_i^{a_i}$ for $0 \lt a_i \lt k$;
#
#
# Case 4: $\mu_k(n) = 1$ otherwise.
#
#
# In comparative language (relative to $\mu(n)$) we have the same $\mu_k(1)=\mu(1)=1$.
# $\mu(n)=0$ when $n$ has a square divisor; and $\mu_k(n)=0$ when
# $n$ has a *power-$(k+1)$* divisor. So far so good, now the more complicated bit.
#
#
# Suppose $n$ has $r$ divisors that are $k$-powers of some primes (and $n$ may
# have some additional prime divisors present as strictly less-than-$k$ powers):
# Then $\mu_k(n)=(-1)^r$. (These
# additional divisors are inconsequential in the definition of $\mu_k$ and they
# do not appear in $\mu(n)$ as it is equivalen to $\mu_{k=1}$.
#
#
# Finally (as an extension of $\mu(1)=1$) if $n$ has no divisors that are $k$-powers
# or higher: $\mu_k(n)=1$.
#
#
# The concluding five problems concern properties of $u_k$.

# %% [markdown]
# #### 2.36 Show that for $k \ge 1$ we have $\mu_k(n^k) = \mu(n)$
#
#
# Clearly $\mu_1(n^1) = \mu(n)$ so taking $k > 1$ in what follows:
#
#
# Case 1: $\mu_k(1^k) = \mu(1) = 1$: ok.
#
#
# Case 2: Suppose $n$ has a divisor that is a prime $p$ raised to a square-or-more power,
# say $p^{q \ge 2}$. In this case $\mu(n)=0$. Then $p^{nq} | n^k$ so $\mu_k(n^k) = 0$
# as well: ok.
#
#
# Case 3: Suppose in contrast to Case 2 that
# $n$ is the product of $r$ primes raised to the $1$ power,
# $n = \prod_{i=1}^r p_i$. Then $n_k = \prod_{i=1}^r p_i^k$ and we have
# $\mu(n) = (-1)^r = \mu_k(n^k)$: ok.
#
#
# Case 4: All prime divisors of $n$ are present in $n^k$ in powers of $k$.
# That is, $n^k$ has no lower-than-k-power prime factors. This means the
# fourth case where $\mu_k = 1$ will not occur for $n^k$: ok. $\;\;$ &#x2610;
#
#
# Greg's solution is an induction proof on $k$ which feels pretty rigorous;
# whereas my solution is a 'cases' argument based on possible structure for $n$.
# The extension from $\mu$ to $\mu_k$ and from $n$ to $n^k$ seems ok to me;
# but not sure about adequate rigor. Maybe I can find a
# mathematician to look it over.

# %% [markdown]
# #### 2.37 Show that $\mu_k(n)$ is multiplicative.
#
#
# This follows a program similar to **2.36** above, taking case by case for numbers $m$ and $n$. Note that $\mu_k$ is not
# *completely* multiplicative (regardless of $k$) by counterexample: Take $m=p^a$ and $n=p^b$ with $a, b > 0$ and $a+b=k$.
#
#
# When either $m$ or $n$ is $1$ we have $\mu_k(m\cdot n) = \mu_k(m)\cdot\mu_k(n)$, self-apparent. Continuing to
# $m, n>0$ and $(m, n) = 1$ we have another self-evident multiplicative result when either $m$ or $n$ is
# divisible by $p^{a>k}$ as $\mu_k$ evaluates to zero.
#
#
# Finally the last two cases ($k$-powers and no-$k$-powers) can be considered together. We have
# $\mu_k(m) = 1$ or $(-1)^r_1$ respectively for absence / presence of $k$ powers of primes dividing $m$.
# The general expression for $m$ is $m=p_1^k\cdot p_2^k \cdot \dots \cdot p_{r_1}^k \prod_{i>r_1}p_i^{a_i}$
# with all residual $a_i < k$. Similarly for $n$ substituting $r_2$ and $q_i$ for the prime factors.
# The sets $\{p\}$ and $\{q\}$ are mutually exclusive by virtue of $(m, n) = 1$. This gives the
# necessary result $\mu_k(m \cdot n) = (-1)^{r_1 + r_2} = \mu_k(m) \cdot \mu_k(n).\;\;$ &#x2610;
#
#
# As another example of greater rigor, Greg points out that if $p^{k+1}$ divides $m$
# then it divides $m \cdot n$ to cover the $\mu_k=0$ case.

# %% [markdown]
# ####  2.38  Incomplete: Show that if $k \ge 2$ then
#
#
# $$\mu_k(n) = \sum_{d^k|n} \mu_{k-1}\bigl( \frac{n}{d^k} \bigr) \mu_{k-1}\bigl( \frac{n}{d} \bigr).$$
#
#
# #### 2.39  Incomplete: Show that if $k \ge 1$ then
#
#
# $$\bigl| \mu_k(n) \bigr| = \sum_{d^{k+1}|n}\mu(d).$$

# %% [markdown]
# #### 2.40 Show that for each prime $p$ the Bell series for $u_k$ is given by
#
#
# $$(\mu_k)_p(x) = \frac{1-2x^k+x^{k+1}}{1-x}.$$
#
#
# This is interesting as the choice of prime $p$ evaporates from the end result.
#
#
# The Bell series of $\mu_k \textrm{ mod } p$ is defined in this case
#
#
# $$(\mu_k)_p(x) = \sum_{n=0}^{\infty} \mu_k(p^n)x^n.$$
#
#
# What follows is valid for $k=1$ but is written more in the spirit of $k>1$.
# The argument of the infinite sum becomes zero when $n$ exceeds $k$
# so the sum can be truncated at $k$; and then rewritten in a more concrete form:
#
#
# $$(\mu_k)_p(x) = \sum_{n=0}^{k} \mu_k(p^n)x^n = 1 + x + \sum_{n=2}^{k} \mu_k(p^n)x^n.$$
#
#
# The prime $p$ is raised to a value less than $k$ for most of this sum, i.e. $\mu_k = 1$;
# and the final term $n=k$ resolves to $(-1)^1$:
#
#
# $$(\mu_k)_p(x) = \sum_{n=0}^{k} \mu_k(p^n)x^n = 1 + x + \sum_{n=2}^{k-1} x^n - x^k.$$
#
#
# Observing the pattern:
#
#
# $$k=1: (\mu_k)_p(x) = 1-x$$
#
#
# $$k=2: (\mu_k)_p(x) = 1 + x - x^2$$
#
#
# $$k=3: (\mu_k)_p(x) = 1 + x + x^2 - x^3$$
#
#
# $$k=4: (\mu_k)_p(x) = 1 + x + x^2 + x^3 - x^4$$
#
#
# $$k:(\mu_k)_p(x) = 1 + x + x^2 + \dots + x^{k-1} - x^k$$
#
#
# In the spirit of a telescoping series: Multiply the last (general) expression above by $1-x$:
#
#
# $$(1-x) \cdot (1 + x + x^2 + \dots + x^{k-1} - x^k) =
# 1 + x + x^2 + \dots + x^{k-1} - x^k - x - x^2 - x^3 - \dots - x^{k-1} - x^{k} + x^{k+1} = 1 - 2x^k + x^{k+1}.$$
#
#
# So the general expression can be written
# $1 + x + x^2 + \dots + x^{k-1} - x^k = \frac{1 - 2x^k + x^{k+1}}{1-x} = (\mu_k)_p(x).\;\;$ &#x2610;

# %% [markdown]
# Well that was certainly a long road! On to chapter 3.
