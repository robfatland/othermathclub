# %% [markdown]
# # ${\Large \infty}$ Computing

# %%
# !curl https://raw.githubusercontent.com/robfatland/othermathclub/master/images/misc/violin_circuit.png -o /home/nbuser/violin_circuit.png -s
from PIL import Image
Image.open("/home/nbuser/violin_circuit.png").resize((600,450),Image.ANTIALIAS)
# Out:
# <PIL.Image.Image image mode=RGB size=600x450 at 0x7F15400E3E90>

# %% [markdown]
# *a violinist after a collision with a computer*
#
#
#
# ### Friendly introduction
#
#
# As you probably know: Violinists may get tired but computers never do (so long as they have
# electrical power). To be sure: Computers misbehave sometimes but they will happily
# perform calculations over and over again millions of times for us when they are being good.
#
#
# This track concerns recent (20th century) mathematics that requires calculation.
# We mention this in the **Monte Carlo** subject and the first example *there* is directly
# related to our first topic *here*. This first topic concerns small creatures, many
# many of them, who follow simple rules. These creatures are called **automatons**.
#
#
# As if the little creatures weren't enough... let's also take a few minutes to see how
# a diagram is drawn using a computer program. We will draw a figure called Ulam's spiral.
# This is named after Professor Ulam.
#
# Then at last we have a third story that will take some time to tell.
# This story begins with the question 'What do we mean by *numbers*?'
# I'll tell you a little about this...
#
#
# Remember when you learned to count? And one day they turned the page of a book
# and it was a picture of a sheep and they asked you 'How many cows are there?'
# You had no idea. There was just the sheep. You looked up and said 'That's a *sheep*.'
#
#
# Then they got a goofy smile on their face and they said 'Surprise! It is Zero cows!'
#
#
# Well that wasn't very nice, introducing a new number like that. And then they
# one day they added fractions... and another day they added negative numbers...
# and decimals... and irrationals... and if they haven't done it yet some day they
# will talk to you about *transcendental* numbers... it never seems to end.
#
#
# So... let's outfox them by getting ahead of the game. We will redefine numbers
# not as a list of examples but in terms of how numbers *work*. What does this mean?
#
#
# Suppose you define a *car* to be something that transports you from Point **A**
# to Point **B**. Done. Now all of a sudden a *bike* is a type of *car*. As is a
# *camel* as is a *tardis*. If you don't know what a tardis is: Don't worry; it is just
# another kind of *car*. Now let's go back to numbers.
#
#
# Numbers like $-3, 0, 1, 19, 3.141593, \frac{22}{7}, \sqrt{2}, -1.11111$
# can be used in arithmetic. Let's define a number as 'something you can do
# arithmetic with'. This defines a number based on *how it works*.
#
#
# The third part of the **computing** track will pretend to invent a new type of
# number including all of the rules of arithmetic. Of course these numbers have already
# been invented, but never mind that. The purpose of our hike into the world of these
# numbers is to continue our journey into fractals. We began with the even/odd pattern
# of **Meru Prastarah** and with the Serpinski gasket painted by Egon in the
# **Monte Carlo** pages. Here we hope to wind up understanding something about Julia sets
# and instability.
#
#
#
# ### At the end of this track you should...
#
#
# - have an idea when a computer might help solve a problem
# - understand how computers manage to do a lot of calculations using loops
# - recognize some of the syntax of the Python computer programming language
# - be able to modify parameters and re-run programs to try out experiments
#
#
# ### Terminology
#
#
# - **automaton**: a small creature who follows simple rules, often as one of many
# - **code**: instructions for a computer written in a language understandable to (skilled) humans
# - **Python**: a computer programming language
# - **loop**: a structure in a computer program that performs a task multiple times

# %% [markdown]
# ### How Computing Works
#
# Let's start by baking a cake. We know we will need some flour and some sugar... is that it? We better look up
# a recipe. Then note down what we don't have. Then go to the store and buy those ingredients. Then come back.
# Then tidy up the kitchen. Then get out the bowls and the mixer. We know we will need those. And then we will
# return to the recipe.
#
# Oh look: The recipe calls for three eggs. We better buy some eggs because we do not have any on hand.
#
# (some time passes... we do all these things... now we are going through the recipe)
#
# Ok now it is time to add the eggs... well this is very curious. The directions are as follows:
#
#
# - write the number 1 on a little post-it note
# - place the little post-it note just below this line
#
# <br><br>
#
#
# - break open an egg and add it to the cake batter
# - mentally add one to the number on the post-it note above; call this the New Number
# - if the New Number is 4 skip the next instruction
# - go back up to the post-it note, scratch out the old number, write in the New Number and continue with the instructions from there
# - measure out 1/3 cup vegetable oil and add that to the batter
#
#
# Now let's do the same thing using a computer program. Just like with the cake there is a bunch of stuff
# we have to do before we can start making the program. And then this program just *pretends* to make the cake.
# Well... you could make a real cake and bring it to a club meeting and then we would be in business.
#
# But for now here is the program.
# Think of it as a recipe that proceeds from the top instruction to the bottom but -- just
# like with the post-it-note -- it can jump backwards to do something (add an egg) over and over.

# %%
how_many_eggs = 3

# This is a comment. When the program runs it does not do anything. It is for people to read.

print ''

post_it_note = 1

# Now I have a bucket labeled 'post_it_note'. Inside the bucket is the number 1
# That is: I need to add egg number 1; and I am tracking this in my post_it_note bucket.

print 'I just wrote down the number 1 on my egg-counter post-it note'
print ''

adding_eggs_now = True

# 'while' will do everything indented below as long as 'adding_eggs_now' is True

while adding_eggs_now:
    print 'I just added egg number', post_it_note, 'to the batter'
    if post_it_note == how_many_eggs:
        adding_eggs_now = False
        print '  ... ok I added enough eggs, better stop!'
        print ''
    post_it_note = post_it_note + 1

# And now we continue onward
print 'I just added 1/3 cup vegetable oil to the batter'
print ''
# Out:
# I just wrote down the number 1 on my egg-counter post-it note
#
# I just added egg number 1 to the batter
# I just added egg number 2 to the batter
# I just added egg number 3 to the batter
#   ... ok I added enough eggs, better stop!
#
# I just added 1/3 cup vegetable oil to the batter

# %% [markdown]
# ### Why this is remarkable
#
# The program above pretends to make a cake... but we are no closer to having any cake to eat.
# But whether this seems remarkable to you or not: The program does an action over and over again
# without getting tired. That is the real point here.
#
#
# What follows does not try and teach programming. That is another club; or a book or a class. But we do
# include enough comments to help you follow what is happening.
#
#
# Notice that the very first line of the program sets the number of eggs. Try changing it to 7 eggs
# to be sure that it works as you expect. Try 1,000. Don't go much higher than that though; it might
# lock up your window.
#
#
# From here forward the computer programs are something you can
# puzzle over or simply use, up to you.
#
#
# The next program is still being fixed... but it does produce a spiral pattern of numbers, only the
# primes, where the idea is to look for diagonals. It is called the **Ulam spiral**.

# %%
start_value = 41
square_side = 41

dotsize = 3000*100/(square_side*square_side)
if dotsize < 1: dotsize = 1
print square_side, dotsize

dotsize = 4

if square_side > 500: square_side = 500
print_numbers = True
if square_side > 40: print_numbers = False

n_numbers = square_side * square_side
numberRange = range(start_value, start_value + n_numbers)
(scale_x, scale_y) = (1.0/float(square_side), 1.0/float(square_side))
(x0, y0) = (0., 0.)
(x_current, y_current) = (x0, y0)

# it would be tricky to use isPrime() to extend an initial list of primes but 
#   this does not play well with a big starting number like 41

def isPrime(n):
    if n < 2: return False
    floor_sqrt = int(np.floor(np.sqrt(float(n))))
    for i in range(2, floor_sqrt + 1):
        if n % i == 0: return False
    return True

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %pylab inline

prime_x = []
prime_y = []
prime_p = []
c = []
dxdy = [(scale_x,0),(0,scale_y),(-scale_x,0),(0,-scale_y)]
dxdyIndex = 0
dxdyModulus = 4
dxdyRun = 1
dxdyCounter = 0
dxdyBit = 0

# return coordinates based on a = cell (x) and b = row (y)
figdim = 12
fig, ax = plt.subplots(figsize=(figdim,figdim))
ax.axis('equal')
ax.set(xlim=(-0.54, 0.54), ylim=(-0.54,0.54))

for i in numberRange:
    if isPrime(i):
        prime_x.append(x_current)
        prime_y.append(y_current)
        prime_p.append(str(i))
        plt.text(x_current, y_current, str(i), fontsize='8')
    x_current += dxdy[dxdyIndex][0]
    y_current += dxdy[dxdyIndex][1]
    dxdyCounter += 1
    if dxdyCounter >= dxdyRun:
        dxdyCounter = 0
        dxdyIndex = (dxdyIndex + 1) % dxdyModulus
        dxdyBit += 1
        if dxdyBit > 1:
            dxdyBit = 0
            dxdyRun += 1


plt.scatter(prime_x, prime_y, s=dotsize, marker='.', color='b')
plt.show()
# Out:
# 41 178

# %% [markdown]
# ### Cause and effect
#
#
# Now that we have seen some complicated programs (above) let's work on some simple pieces.
# The idea is not to teach you to be a Python programmer (although you could do this if you like).
# Rather the idea is for you to experience firsthand the consequences of writing code.
#
#
# The problems that follow require you to type in a program, run it, and then modify it
# to see what the changes do.
#
#
# <br>${\Huge \infty}$
#
# ### You make a list
#
# Write a program in the cell below using these pieces:
#
# ```
# a=range(3)
# print a
# ```

# %% [markdown]
# That object called **a** is a *list*, as you can see: A list of three numbers.
# The computer program remembers it in--you guessed it--its *memory*.
# The second line is called a *print statement*. It simply prints the contents of **a** on the screen for you.
#
#
# <br>${\Huge \infty}$
#
# ### You modify the list
#
# You can change the list. Instead of '3' make it '7'. What happens? Instead of 7 make it two numbers separated
# by a comma, as in $5,9$. What happens?

# %% [markdown]
# <br>${\Huge \infty}$
#
# ### You modify the print
#
# You can separate things you print by commas. Add a comma to the second line and then type your name in single quotes
# like this: 'kilroy'. What happens?

# %% [markdown]
# <br>${\Huge \infty}$
#
# ### You add a loop
#
# Let's make the list above be all the numbers from 5 to 12. Write in your notebook how you did this.
#
#
# Next add a third line to your program that looks like this:
#
#
# ```
# for i in a: print i
# ```
#
# What happens?

# %% [markdown]
# The third line 'for i in a: print i' can be translated into our language as follows:
#
# > Create a loop where a little bucket labeled **i** takes on the values in the list **a**.
# > Each time the loop runs: Print the value of **i**.
#
#
# <br>${\Huge \infty}$
#
# ### You modify the loop
#
# Modify the third line of your program, 'for i in a: print i', to include your name in what is printed.

# %% [markdown]
# <br>${\Huge \infty}$
#
# ### You break the loop into two lines
#
# Modify the third line of your program as follows: Place your cursor right after the colon ':' and hit Enter.
# The rest of the line is now on its own line below. It should be indented four spaces automatically. Make
# sure your program still runs properly.

# %% [markdown]
# ### Extra
#
# Try and 'break' your program by adding a second colon ':' after the first one. Then run the program.
# You should get an error message. You have introduced a *bug* in your program. Congrats!
