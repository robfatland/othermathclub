# %% [markdown]
# # Infinity 4

# %%
import kilroy
kilroy.Show('astronomy', 'star_cluster.png', 800, 400)
# Out:
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7F9C46220F90>

# %% [markdown]
# *...and beyond the infinite...*
#
# ${\Huge \ngtr}$
#
#
# Here is where the sidewalk ends at the moment.

# %%
kilroy.Show('people', 'where_the_sidewalk_ends.png', 600, 300)
# Out:
# <PIL.Image.Image image mode=RGB size=600x300 at 0x7F9C64F24050>

# %% [markdown]
# ### This page is not yet written
#
#
# kilroy notes...
#
#
# #### Finishing a/b
#
# - clock backwards: 1/2/3 ... n ... inf legs
# - a > b case
# - make sense to go back to the beginning of time?
# - Are the numbers from $1$ to $\infty$ just mirror reflections (in time?) of the numbers from $0$ to $1$?
#
#
#
# #### Next
#
# - We are just getting started
# - The next step however requires you to move like a bishop: two subjects sideways and two squares back.
# - Do: Page 1 of Monte Carlo if you have not already.
#   - P(Serp), A(Serp)
#   - P(Koch), A(Koch)
#   - P(Koch-involute), A(Koch-involute)
#   - In 3 dimensions?
#   - In $n$ dimensions?
#
# Egon carries out a certain two-dimensional version of Mister a/b by rolling his dice,
# moving half-way to a paint can and painting a dot. Please reflect on the following question...
